# %% [markdown]
# <a href="https://colab.research.google.com/github/snwnkang/CS171_Final_vis_Marathon/blob/main/Data%20Combining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from IPython.display import HTML
import html

# %%
berlin = pd.read_csv("https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/berlin_data/Berlin_All_2014_to_2023.csv")

# %%
berlin
# Out:
#       place  bib last_name first_name       club country sex division  \
# 0       1.0    2   kimetto     dennis      Kenia     KEN   M       30
# 1       2.0    3     mutai   emmanuel      Kenia     KEN   M       30
# 2       3.0   12      kuma      abera  Äthiopien     ETH   M        H
# 3       4.0    8  kamworor   geoffrey      Kenia     KEN   M        H
# 4       5.0    6  kiptanui      eliud      Kenia     KEN   M        H
# ...     ...  ...       ...        ...        ...     ...  ..      ...
# 2951    NaN  NaN   hawkins       ruth        NaN     GBR   F      NaN
# 2952    NaN  NaN  bridwell    jourdan        NaN     USA   F      NaN
# 2953    NaN  NaN    o'kill    rebecca        NaN     GBR   F      NaN
# 2954    NaN  NaN  nakamura       mika        NaN     JPN   F      NaN
# 2955    NaN  NaN     jones      shara        NaN     GBR   F      NaN
#
#       division_result  net_time finish_time    year  gender_result  \
# ...

# %%
columns_to_keep = ['place', 'bib', 'last_name', 'first_name', 'country', 'division', 'sex', 'finish_time', 'seconds', 'year']

# Drop all columns except the ones specified
berlin = berlin[columns_to_keep]

# Now boston2019 contains only the columns you want to keep
print(berlin.head())
# Out:
#    place bib last_name first_name country division sex finish_time  seconds  \
# 0    1.0   2   kimetto     dennis     KEN       30   M    02:02:57     7377
# 1    2.0   3     mutai   emmanuel     KEN       30   M    02:03:13     7393
# 2    3.0  12      kuma      abera     ETH        H   M    02:05:56     7556
# 3    4.0   8  kamworor   geoffrey     KEN        H   M    02:06:39     7599
# 4    5.0   6  kiptanui      eliud     KEN        H   M    02:07:28     7648
#
#      year
# 0  2014.0
# 1  2014.0
# 2  2014.0
# 3  2014.0
# 4  2014.0

# %%
berlin.head
# Out:
# <bound method NDFrame.head of       place  bib last_name first_name country division sex finish_time  \
# 0       1.0    2   kimetto     dennis     KEN       30   M    02:02:57
# 1       2.0    3     mutai   emmanuel     KEN       30   M    02:03:13
# 2       3.0   12      kuma      abera     ETH        H   M    02:05:56
# 3       4.0    8  kamworor   geoffrey     KEN        H   M    02:06:39
# 4       5.0    6  kiptanui      eliud     KEN        H   M    02:07:28
# ...     ...  ...       ...        ...     ...      ...  ..         ...
# 2951    NaN  NaN   hawkins       ruth     GBR      NaN   F    03:04:50
# 2952    NaN  NaN  bridwell    jourdan     USA      NaN   F    03:04:54
# 2953    NaN  NaN    o'kill    rebecca     GBR      NaN   F    03:04:54
# 2954    NaN  NaN  nakamura       mika     JPN      NaN   F    03:04:55
# 2955    NaN  NaN     jones      shara     GBR      NaN   F    03:04:57
#
#       seconds    year
# 0        7377  2014.0
# 1        7393  2014.0
# ...

# %%
berlin
# Out:
#       place  bib last_name first_name country division sex finish_time  \
# 0       1.0    2   kimetto     dennis     KEN       30   M    02:02:57
# 1       2.0    3     mutai   emmanuel     KEN       30   M    02:03:13
# 2       3.0   12      kuma      abera     ETH        H   M    02:05:56
# 3       4.0    8  kamworor   geoffrey     KEN        H   M    02:06:39
# 4       5.0    6  kiptanui      eliud     KEN        H   M    02:07:28
# ...     ...  ...       ...        ...     ...      ...  ..         ...
# 2951    NaN  NaN   hawkins       ruth     GBR      NaN   F    03:04:50
# 2952    NaN  NaN  bridwell    jourdan     USA      NaN   F    03:04:54
# 2953    NaN  NaN    o'kill    rebecca     GBR      NaN   F    03:04:54
# 2954    NaN  NaN  nakamura       mika     JPN      NaN   F    03:04:55
# 2955    NaN  NaN     jones      shara     GBR      NaN   F    03:04:57
#
#       seconds    year
# 0        7377  2014.0
# 1        7393  2014.0
# 2        7556  2014.0
# ...

# %%
# df['Year'] = year

# %%
berlin['year'] = berlin['year'].astype('Int64')
# Out:
# <ipython-input-8-7d8934142009>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   berlin['year'] = berlin['year'].astype('Int64')

# %%
rename_columns = {
    'last_name': 'Last Name',
    'first_name': 'First Name',
    'place': 'Overall Place',
    'bib': 'BIB',
    'country': 'Country',
    'sex': 'Gender',
    'finish_time': 'Time',
    'seconds': 'Seconds',
    'year': 'Year',
    'division': 'Division'
}

berlin.rename(columns=rename_columns, inplace=True)
# Out:
# <ipython-input-9-f276b8493c58>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   berlin.rename(columns=rename_columns, inplace=True)

# %%
berlin
# Out:
#       Overall Place  BIB Last Name First Name Country Division Gender  \
# 0               1.0    2   kimetto     dennis     KEN       30      M
# 1               2.0    3     mutai   emmanuel     KEN       30      M
# 2               3.0   12      kuma      abera     ETH        H      M
# 3               4.0    8  kamworor   geoffrey     KEN        H      M
# 4               5.0    6  kiptanui      eliud     KEN        H      M
# ...             ...  ...       ...        ...     ...      ...    ...
# 2951            NaN  NaN   hawkins       ruth     GBR      NaN      F
# 2952            NaN  NaN  bridwell    jourdan     USA      NaN      F
# 2953            NaN  NaN    o'kill    rebecca     GBR      NaN      F
# 2954            NaN  NaN  nakamura       mika     JPN      NaN      F
# 2955            NaN  NaN     jones      shara     GBR      NaN      F
#
#           Time  Seconds  Year
# 0     02:02:57     7377  2014
# 1     02:03:13     7393  2014
# 2     02:05:56     7556  2014
# ...

# %%
new_column_order = [
    'Last Name', 'First Name', 'Division', 'Country', 'BIB', 'Overall Place',
    'Time', 'Seconds', 'Year', 'Gender'
]

berlin = berlin[new_column_order]

# %%
unique_country = berlin['Country'].unique()
unique_country
# Out:
# array(['KEN', 'ETH', 'JPN', 'USA', 'BEL', 'GBR', 'FIN', 'ITA', 'DEU',
#        'ESP', 'PRT', 'MEX', 'CAN', 'CZE', 'DNK', 'ARG', 'RUS', 'FRA',
#        'NOR', 'PER', 'SVN', 'CHE', 'NLD', 'POL', 'ZAF', 'SWE', 'IRL',
#        'AUT', 'AUS', 'BGR', 'ISR', 'ISL', 'VEN', 'BRA', 'CHN', 'MAR',
#        'ERI', 'LTU', 'GEO', 'ECU', 'HUN', 'GRC', 'UZB', 'EST', 'LSO',
#        'LIE', 'LVA', 'LUX', 'HRV', 'HKG', 'JOR', 'SVK', 'NZL', 'TWN',
#        'TUR', 'DZA', 'UKR', 'SUI', 'NED', 'GUI', 'GER', 'GRE', 'DEN',
#        'COL', 'POR', 'CHI', 'MAS', 'PUR', 'CPV', 'ROU', 'SIN', 'CRC',
#        'LES', 'DOM', 'LAT', 'KOR', 'GUA', 'MGL', 'ZAM', 'RSA', 'SUD',
#        'EGY', 'SLO', 'IRI', 'BUR', 'THA', 'TRI', 'KAZ', 'URU', 'RWA',
#        'CYP', 'TUN', 'BUL', 'TAN', 'ALG', 'LBN', 'SRB', 'PAR', 'BLR',
#        'SGP', 'INA'], dtype=object)

# %%
berlin
# Out:
#      Last Name First Name Division Country  BIB  Overall Place      Time  \
# 0      kimetto     dennis       30     KEN    2            1.0  02:02:57
# 1        mutai   emmanuel       30     KEN    3            2.0  02:03:13
# 2         kuma      abera        H     ETH   12            3.0  02:05:56
# 3     kamworor   geoffrey        H     KEN    8            4.0  02:06:39
# 4     kiptanui      eliud        H     KEN    6            5.0  02:07:28
# ...        ...        ...      ...     ...  ...            ...       ...
# 2951   hawkins       ruth      NaN     GBR  NaN            NaN  03:04:50
# 2952  bridwell    jourdan      NaN     USA  NaN            NaN  03:04:54
# 2953    o'kill    rebecca      NaN     GBR  NaN            NaN  03:04:54
# 2954  nakamura       mika      NaN     JPN  NaN            NaN  03:04:55
# 2955     jones      shara      NaN     GBR  NaN            NaN  03:04:57
#
#       Seconds  Year Gender
# 0        7377  2014      M
# 1        7393  2014      M
# ...

# %%
berlin
#up to here is the full data
berlin.to_csv(f"berlin_2014-2023_full.csv")

# %%
london = pd.read_csv("https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/combined_data/London_Marathon2014-2023.csv")
chicago = pd.read_csv("https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/combined_data/chicago_marathon_2014-2023.csv")
newyork = pd.read_csv("https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/combined_data/ny_marathon_2014-2023.csv")
berlin = pd.read_csv("https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/combined_data/berlin_2014-2023_full.csv")
boston = pd.read_csv("https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/combined_data/boston_2014-2023_update.csv")

# %%
berlin
# Out:
#       Unnamed: 0 Last Name First Name Division Country  BIB  Overall Place  \
# 0              0   kimetto     dennis       30     KEN    2            1.0
# 1              1     mutai   emmanuel       30     KEN    3            2.0
# 2              2      kuma      abera        H     ETH   12            3.0
# 3              3  kamworor   geoffrey        H     KEN    8            4.0
# 4              4  kiptanui      eliud        H     KEN    6            5.0
# ...          ...       ...        ...      ...     ...  ...            ...
# 2951        2951   hawkins       ruth      NaN     GBR  NaN            NaN
# 2952        2952  bridwell    jourdan      NaN     USA  NaN            NaN
# 2953        2953    o'kill    rebecca      NaN     GBR  NaN            NaN
# 2954        2954  nakamura       mika      NaN     JPN  NaN            NaN
# 2955        2955     jones      shara      NaN     GBR  NaN            NaN
#
#           Time  Seconds    Year Gender
# ...

# %%
london
# Out:
#       Unnamed: 0   Last Name First Name Division Country   BIB  Overall Place  \
# 0              0      Duncan     Nicola    18-39     IRL   426             69
# 1              1     Briscoe      Julie    18-39     GBR   374            191
# 2              2        Bird       Sara    18-39     GBR   521            197
# 3              3        Munn     Hayley    18-39     GBR   273            208
# 4              4    Fletcher      Shona    18-39     GBR   410            370
# ...          ...         ...        ...      ...     ...   ...            ...
# 1995          95     Hendrix     Austin    18-39     USA  6083             96
# 1996          96  Harradence     Oliver    40-44     GBR  1594             97
# 1997          97       Poole   Jonathan    40-44     GBR  1824             98
# 1998          98     Hurrell      James    18-39     GBR  1875             99
# 1999          99      Horman      James    40-44     GBR  1409            100
#
# ...

# %%
chicago
# Out:
#       Unnamed: 0 Last Name First Name Division Country    BIB  Overall Place  \
# 0              0    Dibaba       Mare    20-24     ETH    103             50
# 1              1  Kiplagat   Florence    25-29     KEN    102             53
# 2              2    Dibaba    Birhane    20-24     ETH    106             61
# 3              3  Hastings        Amy    30-34     USA    107             62
# 4              4  Santucci      Clara    25-29     USA    108            101
# ...          ...       ...        ...      ...     ...    ...            ...
# 1795        1795  Salvador     Xavier    25-29     USA  19110            111
# 1796        1796      Mora     Connor    25-29     USA    681            112
# 1797        1797   Trimble       Luke    30-34     USA   7039            113
# 1798        1798   Keinath     Moritz    30-34     SUI   5073            114
# 1799        1799   Furcich     Justin    25-29     USA  18127            115
#
#           Time  Seconds  Year Gender
# ...

# %%
newyork
# Out:
#       Unnamed: 0             Last Name  First Name Division Country   BIB  \
# 0              0                  Mary     Keitany    30-34     KEN   104
# 1              1                Jemima     Sumgong    25-29     KEN   106
# 2              2                  Sara     Moreira    25-29     POR   116
# 3              3                Jelena  Prokopcuka    35-39     LAT   103
# 4              4               Desiree      Linden    30-34     USA   109
# ...          ...                   ...         ...      ...     ...   ...
# 1975        1975                 David    Scherrer    20-24     USA  1638
# 1976        1976               Killian       Nolan    35-39     IRL  1543
# 1977        1977  Temesgen Habtemariam      Bekele    30-34     ETH   553
# 1978        1978                Andrea   Fraquelli    35-39     GBR   529
# 1979        1979                  Eric   Reitinger    35-39     USA  1094
#
#      Overall Place     Time  Seconds  Year Gender
# ...

# %%
boston
# Out:
#       Unnamed: 0 Last Name First Name Division Country   BIB Overall Place  \
# 0              0    Benson    Kipruto      NaN     NaN   NaN             1
# 1              1      Lemi    Berhanu      NaN     NaN   NaN             2
# 2              2     Jemal      Yimer      NaN     NaN   NaN             3
# 3              3    Tsedat      Ayana      NaN     NaN   NaN             4
# 4              4   Leonard   Barsoton      NaN     NaN   NaN             5
# ...          ...       ...        ...      ...     ...   ...           ...
# 1795        1795   Rebekah  Battaglia    25-29     USA  1502          1595
# 1796        1796  Madeline    Jenkins    25-29     USA  8163          1611
# 1797        1797  Cristina      Lowry    30-34     USA  3023          1659
# 1798        1798     Grace      Bowen    25-29     USA  2977          1674
# 1799        1799    Danika   Simonson    25-29     USA  2440          1723
#
#           Time  Seconds    Year Gender  year
# ...

# %%
london = london.drop(columns=['Unnamed: 0'])
chicago = chicago.drop(columns=['Unnamed: 0'])
newyork = newyork.drop(columns=['Unnamed: 0'])
boston = boston.drop(columns=['Unnamed: 0'])
berlin = berlin.drop(columns=['Unnamed: 0'])

# %%
boston = boston.drop(columns=['year'])

# %%
boston['Year'] = boston['Year'].astype(int)

# %%
boston
# Out:
#      Last Name First Name Division Country   BIB Overall Place      Time  \
# 0       Benson    Kipruto      NaN     NaN   NaN             1  02:09:51
# 1         Lemi    Berhanu      NaN     NaN   NaN             2  02:10:37
# 2        Jemal      Yimer      NaN     NaN   NaN             3  02:10:38
# 3       Tsedat      Ayana      NaN     NaN   NaN             4  02:10:47
# 4      Leonard   Barsoton      NaN     NaN   NaN             5  02:11:11
# ...        ...        ...      ...     ...   ...           ...       ...
# 1795   Rebekah  Battaglia    25-29     USA  1502          1595   2:54:25
# 1796  Madeline    Jenkins    25-29     USA  8163          1611   2:54:32
# 1797  Cristina      Lowry    30-34     USA  3023          1659   2:54:49
# 1798     Grace      Bowen    25-29     USA  2977          1674   2:54:57
# 1799    Danika   Simonson    25-29     USA  2440          1723   2:55:23
#
#       Seconds  Year Gender Marathon
# 0      7791.0  2021      M   Boston
# ...

# %%
london['Marathon'] = "London"
chicago['Marathon'] = "Chicago"
newyork['Marathon'] = "New York"
berlin['Marathon'] = "Berlin"
boston['Marathon'] = "Boston"

# %%
lonchinyber = pd.concat([london, chicago, newyork, berlin, boston], ignore_index=True)

# %%
lonchinyber
# Out:
#      Last Name First Name Division Country   BIB Overall Place     Time  \
# 0       Duncan     Nicola    18-39     IRL   426            69  2:33:28
# 1      Briscoe      Julie    18-39     GBR   374           191  2:39:43
# 2         Bird       Sara    18-39     GBR   521           197  2:39:55
# 3         Munn     Hayley    18-39     GBR   273           208  2:40:35
# 4     Fletcher      Shona    18-39     GBR   410           370  2:44:59
# ...        ...        ...      ...     ...   ...           ...      ...
# 9903   Rebekah  Battaglia    25-29     USA  1502          1595  2:54:25
# 9904  Madeline    Jenkins    25-29     USA  8163          1611  2:54:32
# 9905  Cristina      Lowry    30-34     USA  3023          1659  2:54:49
# 9906     Grace      Bowen    25-29     USA  2977          1674  2:54:57
# 9907    Danika   Simonson    25-29     USA  2440          1723  2:55:23
#
#       Seconds    Year Gender Marathon
# 0      9208.0  2014.0      F   London
# ...

# %%
lonchinyber.to_csv("londonchicagonyberlinboston_combined.csv")

# %%
missing_values = lonchinyber.isnull()

# Count the number of missing values in each column
missing_counts = missing_values.sum()

# Display the columns with missing values and their respective counts
print(missing_counts[missing_counts > 0])
# Out:
# Last Name           3
# First Name          1
# Division         1030
# Country           801
# BIB              1628
# Overall Place     828
# dtype: int64

# %%
l_year_m = london['Year'].isnull()
n_year_m = newyork['Year'].isnull()
c_year_m = chicago['Year'].isnull()
b_year_m = berlin['Year'].isnull()

# %%
l_miss = l_year_m.sum()
n_miss = n_year_m.sum()
c_miss = c_year_m.sum()
b_miss = b_year_m.sum()

# %%
l_miss
# Out:
# 0

# %%
n_miss
# Out:
# 0

# %%
c_miss
# Out:
# 0

# %%
b_miss
# Out:
# 628

# %%
berlin = berlin.dropna(subset=['Year'])

# %%
berlin
# Out:
#      Last Name First Name Division Country  BIB  Overall Place      Time  \
# 0      kimetto     dennis       30     KEN    2            1.0  02:02:57
# 1        mutai   emmanuel       30     KEN    3            2.0  02:03:13
# 2         kuma      abera        H     ETH   12            3.0  02:05:56
# 3     kamworor   geoffrey        H     KEN    8            4.0  02:06:39
# 4     kiptanui      eliud        H     KEN    6            5.0  02:07:28
# ...        ...        ...      ...     ...  ...            ...       ...
# 2951   hawkins       ruth      NaN     GBR  NaN            NaN  03:04:50
# 2952  bridwell    jourdan      NaN     USA  NaN            NaN  03:04:54
# 2953    o'kill    rebecca      NaN     GBR  NaN            NaN  03:04:54
# 2954  nakamura       mika      NaN     JPN  NaN            NaN  03:04:55
# 2955     jones      shara      NaN     GBR  NaN            NaN  03:04:57
#
#       Seconds    Year Gender Marathon
# 0        7377  2014.0      M   Berlin
# ...
