# %% [markdown]
# <a href="https://colab.research.google.com/github/snwnkang/CS171_Final_vis_Marathon/blob/main/NY_Marathon_Scraper_general.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from IPython.display import HTML
import html

# %%
raw_html2014 = """<html data-ng-app="RmsApp" ng-controller="layoutController" class="ng-scope"><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
    <base href="/"> <!-- This is to fix issue with trailing slash -->
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0">
    <meta name="description" content="NYRR Races Results - 11/02/2014 - TCS New York City Marathon 2014">
    <title ng-bind="layoutScope.title" class="ng-binding">Individual Results - TCS New York City Marathon 2014</title>
    <link rel="shortcut icon" type="image/ico" href="/favicon.ico">
    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="">
    <link href="https://fonts.googleapis.com/css2?family=Inter:wght@400;500;800&amp;display=swap" rel="stylesheet">



        <link href="/bundles/site.min.css?v=QKROQGtGMmZotdpHRfZYQRc9njkvv6wJozgn-wB5gEA" rel="stylesheet" type="text/css">


<meta property="og:title" content="New York Road Runners Official Race Results">
<meta property="og:image" content="https://results.nyrr.org/images/logo.png">
<meta property="og:url" content="http://results.nyrr.org">
<meta property="og:description" content="I just completed a NYRR race. See my official results here.">
</head>
<body refresh-page-on-orientation-change="" refresh-page-on-device-change="" share-tool="" ng-class="{ 'races-body-background': layoutScope.isFreeTextSearch, 'home-body-background': homeBodyBkg || racesBodyBkg, 'request-correction-body-background': requestCorrectionBodyBkg, 'text-contrasted': layoutScope.isTextContrasted }" style="overflow: auto;">
    <a class="back-to-top" style="">&nbsp;</a>


<!-- Google Tag Manager -->
<noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-WJ5SWH"
height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
<script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-5VFDGE476X&amp;cx=c&amp;_slc=1"></script><script type="text/javascript" id="www-widgetapi-script" src="https://www.youtube.com/s/player/2be84af7/www-widgetapi.vflset/www-widgetapi.js" async=""></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-T6CGMVSVCZ&amp;cx=c&amp;_slc=1"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js"></script><script src="//www.youtube.com/iframe_api" async=""></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-WJ5SWH"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
'//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
})(window,document,'script','dataLayer','GTM-WJ5SWH');</script>
<!-- End Google Tag Manager -->



    <div class="shell" name="top">
        <div class="shell__inner">
            <div id="header">
    <div class="mobile_nav_overlay@medium-" data-behavior="MobileNav">
        <div class="desktop_header@large+ mobile_nav@medium- bg-invert@large+">
            <a href="/" class="desktop_header@large+__logo mobile_nav@medium-__logo close-menu-after" id="logo">
                <img alt="NYRR" class="initial loading" src="/images/NYRR_RaceResults_Logo.svg">
            </a>
            <div class="desktop_header@large+__body mobile_nav@medium-__body">
                <nav class="visible-big-size mobile_nav@medium-__bottom">
                    <div class="desktop_header@large+__util mobile_nav@medium-__bottom__lists">
                        <div class="desktop_header@large+__util__list mobile_nav@medium-__bottom__lists__list" data-behavior="NavOverflow">
                            <ul id="left-menu-header" class="desktop_header@large+__util__list__inner">
                                <li class="tfk-menu-item">
                                    <div class="dropdown dropdown-nyrr">
                                        <a href="#top" role="button" id="dropdownMenuLink" type="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                                            <span class="dropdown-menu-text">NYRR</span>
                                            <svg class="icon icon--arrow_down small_dropdown_icon">
                                                <use xlink:href="/images/icons.svg#icon--arrow_down">
                                                    <svg viewBox="0 0 18.09058 10.60718" id="icon--arrow_down" xmlns="http://www.w3.org/2000/svg">
                                                        <title>NYRR</title>
                                                        <path fill="lightsteelblue" d="M9.045 10.607L0 1.03 1.091 0l7.954 8.423L17 0l1.091 1.03-9.046 9.577z"></path>
                                                    </svg>
                                                </use>
                                            </svg>
                                        </a>
                                        <div class="dropdown-menu dropdown-menu-nyrr" aria-labelledby="dropdownMenuLink">
                                            <a class="dropdown-item-nyrr" href="https://www.nyrr.org">NYRR Home</a>
                                            <a class="dropdown-item-nyrr" href="https://www.nyrr.org/about">About NYRR</a>
                                        </div>
                                    </div>
                                </li>
                                <li class="visible-big-size tfk-menu-item" style="">
                                    <a class="c-subtle--with_hover@large+ f-small" href="https://www.nyrr.org/tcsnycmarathon">
                                        TCS NYC Marathon
                                    </a>
                                </li>
                                <li class="visible-big-size tfk-menu-item" style="">
                                    <a class="c-subtle--with_hover@large+ f-small" href="https://www.nyrr.org/runcenter">
                                        <i>RUN</i>CENTER
                                    </a>
                                </li>
                                <li class="visible-big-size tfk-menu-item" style="">
                                    <a class="c-subtle--with_hover@large+ f-small" href="/" style="border-bottom: 1px solid #ccc;">
                                        Results
                                    </a>
                                </li>
                                <li class="visible-big-size tfk-menu-item" style="">
                                    <a class="c-subtle--with_hover@large+ f-small" href="https://runwithtfk.org" target="_blank">
                                        Team for Kids
                                    </a>
                                </li>
                                <li class="visible-big-size tfk-menu-item" style="">
                                    <a class="c-subtle--with_hover@large+ f-small" href="https://nyrr.org/media-center">
                                        Media Center
                                    </a>
                                </li>
                                <li class="visible-big-size tfk-menu-item" style="">
                                    <a class="c-subtle--with_hover@large+ f-small" href="https://nyrr.org/community">
                                        Community
                                    </a>
                                </li>
                                <li id="moreMenuLinkContainer" style="display: none; width: 0;">
                                    <div class="dropdown dropdown-nyrr">
                                        <a href="#" role="button" id="moreMenuLink" type="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                                            <span class="dropdown-menu-text">More</span>
                                            <svg class="icon icon--arrow_down small_dropdown_icon">
                                                <use xlink:href="/images/icons.svg#icon--arrow_down">
                                                    <svg viewBox="0 0 18.09058 10.60718" xmlns="http://www.w3.org/2000/svg">
                                                        <title>arrow down</title>
                                                        <path fill="lightsteelblue" d="M9.045 10.607L0 1.03 1.091 0l7.954 8.423L17 0l1.091 1.03-9.046 9.577z"></path>
                                                    </svg>
                                                </use>
                                            </svg>
                                        </a>
                                        <div id="moreMenuLinkItems" class="dropdown-menu dropdown-menu-nyrr" aria-labelledby="moreMenuLink">
                                        </div>
                                    </div>
                                </li>
                            </ul>

                        </div>
                        <div class="desktop_header@large+__util__list mobile_nav@medium-__bottom__lists__list">
                            <ul id="right-menu-header" class="desktop_header@large+__util__list__inner">
                                <li class="visible-big-size">
                                    <a class="c-subtle--with_hover@large+ f-small" href="https://www.nyrr.org/getinvolved/donate">
                                        Donate
                                    </a>
                                </li>
                                <li class="visible-big-size">
                                    <a class="c-subtle--with_hover@large+ f-small" href="http://www.surveygizmo.com/s3/3306032/RMS-Feedback" target="_blank">
                                        Feedback
                                    </a>
                                </li>
                                <li class="visible-big-size">
                                    <a class="c-subtle--with_hover@large+ f-small" href="https://help.nyrr.org/s/topic/0TO1C000000Xk7TWAS/results-scoring-and-awards">
                                        Help
                                    </a>
                                </li>
                            </ul>
                        </div>
                    </div>
                </nav>
                <header class="desktop_header@large+__main  mobile_nav@medium-__top" data-behavior="DesktopHeaderSearch">
                    <div class="mobile_nav@medium-__top__header">
                        <div class="mobile_nav@medium-__top__header__inner">
                            <div class="mobile_nav@medium-__top__header__actions">
                                <a href="https://www.nyrr.org/races-and-events" id="calendar-menu" class="mobile_nav@medium-__top__header__close hide@large+">
                                    <svg role="img" aria-label="Calendar" class="icon icon--calendar-2">
                                        <title>Calendar</title>
                                        <use xlink:href="/images/icons.svg#icon--calendar-2">
                                            <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 18 20" id="icon--calendar-2" width="100%" height="100%">
                                                <title>Untitled</title>
                                                <g fill="none" fill-rule="evenodd">
                                                    <path d="M2 2.8a.2.2 0 0 1-.2.2H.2a.2.2 0 0 1-.2-.2V.2C0 .09.09 0 .2 0h1.6c.11 0 .2.09.2.2v2.6z" fill="#FEFEFE" mask="url(#mask-2)" transform="translate(3)"></path>
                                                    <path d="M2 2.8a.2.2 0 0 1-.2.2H.2a.2.2 0 0 1-.2-.2V.2C0 .09.09 0 .2 0h1.6c.11 0 .2.09.2.2v2.6z" fill="#FEFEFE" mask="url(#mask-4)" transform="translate(13)"></path>
                                                    <path d="M2 18h14V7H2v11zM16 2v2h-4V2H6v2H2V2a2 2 0 0 0-2 2v14a2 2 0 0 0 2 2h14a2 2 0 0 0 2-2V4a2 2 0 0 0-2-2z" fill="#FEFEFE" mask="url(#mask-6)"></path>
                                                </g>
                                            </svg>
                                        </use>
                                    </svg>
                                </a>
                                <a href="#" id="button-menu" class="mobile_nav@medium-__top__header__close hide@large+">
                                    <span id="text-menu" class="f-btn">Menu</span>
                                </a>
                            </div>
                        </div>
                    </div>
                    <div class="desktop_header@large+__main__body mobile_nav@medium-__top__inner">
                        <div class="desktop_header@large+__main__body__inner mobile_nav@medium-__top__inner">
                            <div class="desktop_header@large+__main__body__item mobile_nav@medium-__top__inner">
                                <nav class="desktop_nav@large+ mobile_nav@medium-__top__inner__nav" data-behavior="DesktopNav">
                                    <div>
                                        <ul class="desktop_nav@large+__inner" data-behavior="Accordion">
                                            <li data-behavior="Dropdown">
                                                <a href="#" class="f-nav mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                </a>
                                            </li>
                                            <li>
                                                <a href="/races" ng-class="{ 'is-current': layoutScope.isRacesPage }" class="f-nav mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item close-menu-after" data-behavior="CurrentNav">
                                                    All Races
                                                </a>
                                            </li>
                                            <li>
                                                <a href="/clubstandings" ng-class="{ 'is-current': layoutScope.isClubStandingsPage }" class="f-nav mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item close-menu-after" data-behavior="CurrentNav">
                                                    Club Standings
                                                </a>
                                            </li>
                                            <li>
                                                <a href="https://www.nyrr.org/races-and-events" class="btn btn_tfk btn--nav">
                                                    <span class="f-nav">
                                                        Calendar
                                                    </span>
                                                </a>
                                            </li>
                                        </ul>
                                    </div>
                                </nav>
                            </div>
                            <div class="mobile_nav@medium-__top__inner__search desktop_header@large+__main__body__item">
                                <a href="#" ng-click="showMobileSearch()" onclick="mainMenuCloseMobile()" style="width: 100%">
                                    <svg role="img" aria-label="Search" class="icon icon--search">
                                        <title>Search</title>
                                        <use xlink:href="/images/icons.svg#icon--search"></use>
                                    </svg>
                                </a>
                            </div>
                            <div class="desktop_header@large+__main__body__item mobile_nav@medium-__top__inner visible-small-size">
                                <div class="w-100">
                                    <div class="w-50 float-left">
                                        <nav class="desktop_nav@large+ mobile_nav@medium-__top__inner__nav pb-5" data-behavior="DesktopNav">
                                            <div class="pt-4">
                                                <ul class="desktop_nav@large+__inner" data-behavior="Accordion">
                                                    <li>
                                                        <a href="https://www.nyrr.org" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            NYRR Home
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://www.nyrr.org/about" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            About NYRR
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://www.nyrr.org/charities-clubs-and-community/community-programs" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Youth and Community Programs
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://www.nyrr.org/about-us/partners" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Partners
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://www.nyrr.org/about-us/management" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Our Team
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://www.nyrr.org/about-us/careers" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Careers
                                                        </a>
                                                    </li>

                                                    <li>
                                                        <a href="http://www.charitynavigator.org/index.cfm?bay=search.summary&amp;orgid=13314" target="_blank" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Charity Rating
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://www.nyrr.org/tcsnycmarathon" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            TCS NYC Marathon
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://www.nyrr.org/runcenter" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            <i>RUN</i>CENTER
                                                        </a>
                                                    </li>
                                                </ul>
                                            </div>
                                        </nav>
                                    </div>
                                    <div class="w-50 float-left">
                                        <nav class="desktop_nav@large+ mobile_nav@medium-__top__inner__nav pb-5" data-behavior="DesktopNav">
                                            <div class="pt-4">
                                                <ul class="desktop_nav@large+__inner" data-behavior="Accordion">
                                                    <li>
                                                        <a href="https://www.nyrr.org/getinvolved/donate" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Donate
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="http://www.surveygizmo.com/s3/3306032/RMS-Feedback" target="_blank" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Feedback
                                                        </a>
                                                    </li>
                                                    <li>
                                                        <a href="https://help.nyrr.org" class="f-small pb-0 pt-2 mobile_nav@medium-__top__inner__nav__item desktop_nav@large+__item" data-behavior="CurrentNav">
                                                            Help
                                                        </a>
                                                    </li>
                                                </ul>
                                            </div>
                                        </nav>
                                    </div>
                                </div>
                            </div>
                        </div>
                        <button class="desktop_header@large+__main__body__close hide@medium-">
                            <svg role="img" aria-label="Close" class="icon icon--close">
                                <title>Close</title>
                                <use xlink:href="/images/icons.svg#icon--close"></use>
                            </svg>
                        </button>
                    </div>
                </header>
            </div>
        </div>
    </div>
</div>
        </div>
        <div>
            <div class="barba-container is-entering is-entered">
                <main>
                    <div ng-class="{ 'b-content': !layoutScope.isLandingPage, 'phone-view': layoutScope.isMobileView, 'not-phone-view': !layoutScope.isMobileView }" class="not-phone-view b-content">
                        <div data-ng-view="" data-ng-controller="indexController" class="ng-scope"></div>
                        <!-- uiView:  --><div ui-view="" class="ng-scope"><!-- uiView: header --><div ui-view="header" class="ng-scope"><!-- ngInclude: undefined --><ng-include src="'/js/common/views/globalSearch.html'" class="ng-scope"><!-- ngIf: layoutScope.isGlobalSearchFocused -->

<div class="ng-scope">
    <script id="/runners-races-template.html" type="text/ng-template">
        <div id="parentDisable" ng-click="$parent.hideMobileSearch()">
            <a href="#" ng-click="$parent.hideMobileSearch()" ng-if="$parent.layoutScope.isMobileView" class="close-btn">close</a>
        </div>
        <div class="angucomplete-holder b-search" ng-class="{ 'angucomplete-dropdown-visible': showDropdown }">
            <div class="b-search-form">
                <input id="{{ id }}_value"
                       name="{{ inputName }}"
                       tabindex="{{ fieldTabindex }}"
                       ng-model="searchStr"
                       ng-disabled="disableInput"
                       type="text"
                       placeholder="{{ placeholder }}"
                       ng-focus="onFocusHandler(); resetHideResults(); "
                       class="{{ inputClass }}"
                       ng-blur="hideResults($event)"
                       autocapitalize="off"
                       autocorrect="off"
                       autocomplete="off"
                       ng-change="inputChangeHandler(searchStr)"
                       focus-me="showDropdown"
                       maxlength="50" />
                <div class="control_buttons">
                    <a class="b-search__button" ng-click="$parent.freeTextSearch(searchStr)" ng-show="$parent.searchString != searchStr || !searchStr" href="#"></a>
                    <a class="b-clear__button" ng-click="$parent.layoutScope.clearFreeTextSearch()" ng-show="$parent.searchString == searchStr && $parent.searchString" href="#"></a>
                </div>

                <div class="b-search_autocomplete">
                    <div class="b-tab_autocomplete angucomplete_" ng-show="!searching && results && results.length > 0 && searchStr">
                        <a ng-click='$parent.switchSearchMode(false)' ng-show="$parent.searchRunnersCount > 0"><label class="angucomplete_" ng-class="{ active: $parent.isRunnersMode }">TOP Runners</label></a>
                        <a ng-click='$parent.switchSearchMode(true)' ng-show="$parent.searchEventsCount > 0"><label class="angucomplete_" ng-class="{ active: $parent.isEventsMode }">TOP Races</label></a>
                    </div>

                    <div id="{{id}}_dropdown" class="angucomplete-dropdown" ng-show="showDropdown">
                        <div class="angucomplete-searching b-searching" ng-show="searching" ng-bind="textSearching"></div>
                        <div class="angucomplete-searching b-searching" ng-show="!searching && (!results || results.length == 0) && searchStr" ng-bind="textNoResults"></div>

                        <div class="row angucomplete-row" ng-repeat="result in results" ng-show="$parent.$parent.isRunnersMode && result.originalObject.isRunner" ng-mobile-click="selectResult(result)" ng-click="selectResult(result)" ng-class="{'selected': $index == currentIndex}" style="margin-left: 0; margin-right: 0; cursor: pointer;">
                            <div class="col-xs-9 col-sm-9 col-md-9">
                                <div class="name angucomplete-title" ng-if="matchClass" ng-bind-html="result.title"></div>
                                <div class="name angucomplete-title" ng-if="!matchClass">{{ result.title }}</div>

                                <div class="description">{{ result.originalObject.description }}</div>
                            </div>
                            <a ng-href="runner/{{ result.originalObject.runnerId }}/races">
                                <div class="col-xs-3 col-sm-3 col-md-3">
                                    <span class="goto"></span>
                                    <span>
                                        {{ result.originalObject.racesCount }} Race{{ result.originalObject.racesCount > 1 ? "s" : "" }}
                                        <br />
                                        {{ result.originalObject.age ? "Age " + result.originalObject.age : "" }}
                                    </span>
                                </div>
                            </a>
                        </div>

                        <div class="row angucomplete-row" ng-repeat="result in results" ng-show="$parent.$parent.isEventsMode && result.originalObject.isEvent" ng-mobile-click="selectResult(result)" ng-click="selectResult(result)" ng-class="{'selected': $index == currentIndex}" style="margin-left: 0; margin-right: 0; cursor: pointer;">
                            <div class="col-xs-9 col-sm-9 col-md-9">
                                <div class="name angucomplete-title" ng-if="matchClass" ng-bind-html="result.title"></div>
                                <div class="name angucomplete-title" ng-if="!matchClass">{{ result.title }}</div>

                                <div class="description">{{ result.originalObject.description }}</div>
                            </div>
                            <a ng-href="event/{{ result.originalObject.eventCode }}/finishers">
                                <div class="col-xs-3 col-sm-3 col-md-3">
                                    <span class="goto"></span>
                                    <span>{{ result.originalObject.startDateTime | eventDate }}</span>
                                </div>
                            </a>
                        </div>
                    </div>

                    <div ng-show="showDropdown && results.length > 0" class="goto-search-results cursor-pointer" ng-click="$parent.freeTextSearch(searchStr)">
                        <a href="#">More Results &gt;</a>
                    </div>
                </div>
            </div>
        </div>
    </script>

    <div angucomplete-alt="" id="search-races-runners" class="autocomplete-search ng-isolate-scope search-hidden" ng-class="{ 'affix': layoutScope.isGlobalSearchFocused, 'search-hidden' : !layoutScope.isGlobalSearchVisible, 'main-page-position' : layoutScope.isLandingPage || layoutScope.isRacesPage, 'free-search-position' : layoutScope.isFreeTextSearch &amp;&amp; !layoutScope.isMobileView }" placeholder="Search for a Race, Runner or Year" pause="300" selected-object="objectSelectedCallback" remote-api-handler="searchResults" remote-url-data-field="response.items" title-field="firstName,lastName,eventName" minlength="0" input-class="b-search-input" match-class="highlight" remote-url-error-callback="httpErrorCallback" input-enter-handler="freeTextSearch" template-url="/runners-races-template.html" text-no-results="No results found" show-dropdown-handler="layoutScope.onShowDropdown" focus-in="layoutScope.globalSearchFocusIn" focus-out="layoutScope.globalSearchFocusOut">
        <div id="parentDisable" ng-click="$parent.hideMobileSearch()">
            <!-- ngIf: $parent.layoutScope.isMobileView -->
        </div>
        <div class="angucomplete-holder b-search" ng-class="{ 'angucomplete-dropdown-visible': showDropdown }">
            <div class="b-search-form">
                <input id="search-races-runners_value" name="" tabindex="" ng-model="searchStr" ng-disabled="disableInput" type="text" placeholder="Search for a Race, Runner or Year" ng-focus="onFocusHandler(); resetHideResults(); " class="b-search-input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)" focus-me="showDropdown" maxlength="50">
                <div class="control_buttons">
                    <a class="b-search__button" ng-click="$parent.freeTextSearch(searchStr)" ng-show="$parent.searchString != searchStr || !searchStr" href="#"></a>
                    <a class="b-clear__button ng-hide" ng-click="$parent.layoutScope.clearFreeTextSearch()" ng-show="$parent.searchString == searchStr &amp;&amp; $parent.searchString" href="#"></a>
                </div>

                <div class="b-search_autocomplete">
                    <div class="b-tab_autocomplete angucomplete_ ng-hide" ng-show="!searching &amp;&amp; results &amp;&amp; results.length > 0 &amp;&amp; searchStr">
                        <a ng-click="$parent.switchSearchMode(false)" ng-show="$parent.searchRunnersCount > 0" class="ng-hide"><label class="angucomplete_ active" ng-class="{ active: $parent.isRunnersMode }">TOP Runners</label></a>
                        <a ng-click="$parent.switchSearchMode(true)" ng-show="$parent.searchEventsCount > 0" class="ng-hide"><label class="angucomplete_" ng-class="{ active: $parent.isEventsMode }">TOP Races</label></a>
                    </div>

                    <div id="search-races-runners_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown">
                        <div class="angucomplete-searching b-searching ng-binding ng-hide" ng-show="searching" ng-bind="textSearching">Searching...</div>
                        <div class="angucomplete-searching b-searching ng-binding ng-hide" ng-show="!searching &amp;&amp; (!results || results.length == 0) &amp;&amp; searchStr" ng-bind="textNoResults">No results found</div>

                        <!-- ngRepeat: result in results -->

                        <!-- ngRepeat: result in results -->
                    </div>

                    <div ng-show="showDropdown &amp;&amp; results.length > 0" class="goto-search-results cursor-pointer ng-hide" ng-click="$parent.freeTextSearch(searchStr)">
                        <a href="#">More Results &gt;</a>
                    </div>
                </div>
            </div>
        </div>
    </div>
    <!-- ngIf: !layoutScope.isMobileView --><div class="b-head_top_affix_after ng-scope" ng-if="!layoutScope.isMobileView" ng-class="{ 'no-text-search-results' : runners.length == 0 &amp;&amp; events.length == 0 &amp;&amp; layoutScope.isFreeTextSearch }"></div><!-- end ngIf: !layoutScope.isMobileView -->
</div>

<div class="b-race_list ng-scope ng-hide" ng-show="layoutScope.isFreeTextSearch" style="padding-top: 0;">
    <div class="b-fix_wrapper">
        <div class="event-grid">
            <div>
                <!-- this div tag used for correct scrolling when Next button clicking -->
                <div ng-show="runnersCount > 0 || eventsCount > 0" class="ng-hide">
                    <div class="b-filtr_head b-sub_menu" id="filtr2">
                        <div class="row">
                            <div class="col-xs-12 col-sm-12 col-md-12 first-col global-search-container">
                                <ul class="submenu nav nav-tabs">
                                    <li ng-class="{ active: isRunnersMode }" ng-show="runnersCount > 0" class="ng-hide active"><a ng-click="searchRunners()" class="ng-binding">Runners: 0</a></li>
                                    <li ng-class="{ active: isEventsMode }" ng-show="eventsCount > 0" class="ng-hide"><a ng-click="searchEvents()" class="ng-binding">Races: 0</a></li>
                                </ul>
                            </div>
                        </div>
                    </div>
                    <div class="b-head_top_affix_after"></div>
                </div>

                <div class="b-race_table ng-hide" ng-show="isEventsModeForFreeTextSearch &amp;&amp; eventsCount > 0" ng-class="{'search-opened' : layoutScope.isFreeTextSearch &amp;&amp; (layoutScope.isEventPage || layoutScope.isRunnerPage)}">
                    <!-- ngRepeat: event in events -->
                </div>

                <div class="b-race_table runners ng-hide" ng-show="isRunnersModeForFreeTextSearch &amp;&amp; runnersCount > 0" ng-class="{'search-opened' : layoutScope.isFreeTextSearch &amp;&amp; (layoutScope.isEventPage || layoutScope.isRunnerPage)}">
                    <!-- ngRepeat: runner in runners -->
                </div>

            </div>

            <div class="b-race_table ng-hide" ng-show="isEventsModeForFreeTextSearch &amp;&amp; events.length == 0">
                <!-- ngIf: layoutScope.isMobileView -->
                <div class="row search-row bordered-bottom">
                    <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 first-col">
                        <div class="vert-align">
                            <h2 ng-hide="isEventSearchInProgress">No Results found</h2>
                            <h2 ng-show="isEventSearchInProgress" class="ng-hide">Searching...</h2>
                        </div>
                    </div>
                </div>
            </div>

            <div class="b-race_table ng-hide" ng-show="isRunnersModeForFreeTextSearch &amp;&amp; runners.length == 0 &amp;&amp; layoutScope.isFreeTextSearch">
                <!-- ngIf: layoutScope.isMobileView -->
                <div class="row search-row bordered-bottom">
                    <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 first-col">
                        <div class="vert-align">
                            <h2 ng-hide="isRunnerSearchInProgress">No Results found</h2>
                            <h2 ng-show="isRunnerSearchInProgress" class="ng-hide">Searching...</h2>
                        </div>
                    </div>
                </div>
            </div>

            <button ng-click="nextPage()" ng-hide="layoutScope.infiniteScrollCompleted || (events.length == 0 &amp;&amp; runners.length == 0)" class="button-load-more ng-hide">Show More</button>

        </div>
    </div>
</div></ng-include>

<!-- ngIf: layoutScope.isHeaderVisible --><div class="event-page-header ng-scope" ng-style="{ 'background-image': 'url(' + headerImageUrl + ')' }" ng-if="layoutScope.isHeaderVisible" style="background-image: url(&quot;/images/header-event.jpg&quot;);">
    <div class="b-head_top_affix_after">
        <div class="b-head">
            <div ng-class="headerBackgroundIsDefault ? 'b-head_blue' : ''" class="b-head_blue">
                <div class="b-fix_wrapper display-flex">
                    <!-- ngIf: eventDetails.logoImageId -->
                    <!-- ngIf: !eventDetails.isVirtual --><div class="event-desc ng-scope no-left-padding" ng-if="!eventDetails.isVirtual" ng-class="{ 'small': eventDetails.logoImageId, 'no-left-padding': !eventDetails.logoImageId }">
                        <h1 small-line-height="" textlen="40" class="block-with-text ng-binding">TCS New York City Marathon 2014</h1>
                        <!-- ngIf: eventDetails.logoImageId && layoutScope.isMobileView -->
                        <!-- ngIf: !eventDetails.logoImageId || !layoutScope.isMobileView --><p ng-if="!eventDetails.logoImageId || !layoutScope.isMobileView" class="ng-binding ng-scope">Marathon | November 2, 2014, 8:30AM</p><!-- end ngIf: !eventDetails.logoImageId || !layoutScope.isMobileView -->
                    </div><!-- end ngIf: !eventDetails.isVirtual -->
                    <!-- ngIf: eventDetails.isVirtual -->
                </div>
            </div>
        </div>
    </div>
</div><!-- end ngIf: layoutScope.isHeaderVisible -->

<!-- ngIf: layoutScope.isHeaderVisible --><div ng-if="layoutScope.isHeaderVisible" class="ng-scope">
    <div class="b-sub_menu event-header" id="submenu">
        <div class="container b-fix_wrapper">
            <div class="row" ng-hide="layoutScope.isMobileView">
                <div class="col-xs-8 col-sm-9 col-md-9">
                    <ul class="submenu nav nav-tabs">
                        <li ng-class="{active: activeTab == 'overview'}"><a ng-href="/event/M2014/overview" href="/event/M2014/overview">Overview</a></li>
                        <li ng-class="{active: activeTab == 'finishers'}" class="always-reloadable active"><a ng-href="/event/M2014/finishers" href="/event/M2014/finishers">Finishers</a></li>
                        <li ng-show="eventDetails.runnerAwardsCount > 0 || eventDetails.teamAwardsCount > 0" ng-class="{active: activeTab == 'awards'}" class="always-reloadable"><a ng-href="/event/M2014/runnerAwards" href="/event/M2014/runnerAwards">Awards</a></li>
                        <li ng-show="eventDetails.customStatisticsCount > 0" ng-class="{active: activeTab == 'customStatistics'}" class=""><a ng-href="/event/M2014/customStatistics" class="ng-binding" href="/event/M2014/customStatistics">Statistics</a></li>
                        <li ng-show="eventDetails.teamsCount > 0" ng-class="{active: activeTab == 'teams'}" class="always-reloadable"><a ng-href="/event/M2014/teams" href="/event/M2014/teams">Teams</a></li>
                        <li ng-class="{active: activeTab == 'compare'}"><a ng-href="/event/M2014/compare" href="/event/M2014/compare">Compare</a></li>
                    </ul>
                </div>
                <div class="col-xs-4 col-sm-3 col-md-3 corrections">
                    <div class="b-link">
                        <a ng-click="openRequestCorrection(null, eventDetails.eventCode)" href="#">Request Corrections</a>
                    </div>
                </div>
            </div>
            <div class="row ng-hide" ng-show="layoutScope.isMobileView">
                <div class="col-xs-12 col-sm-12 col-md-12 menu-mobile">
                    <ul class="submenu nav nav-tabs">
                        <li ng-class="{active: activeTab == 'overview'}"><a ng-href="/event/M2014/overview" href="/event/M2014/overview">Overview</a></li>
                        <li ng-class="{active: activeTab == 'finishers'}" class="always-reloadable active"><a ng-href="/event/M2014/finishers" href="/event/M2014/finishers">Finishers</a></li>
                        <li ng-show="eventDetails.runnerAwardsCount > 0 || eventDetails.teamAwardsCount > 0" ng-class="{active: activeTab == 'awards'}" class="always-reloadable"><a ng-href="/event/M2014/runnerAwards" href="/event/M2014/runnerAwards">Awards</a></li>
                        <li ng-show="eventDetails.customStatisticsCount > 0" ng-class="{active: activeTab == 'customStatistics'}" class=""><a ng-href="/event/M2014/customStatistics" class="ng-binding" href="/event/M2014/customStatistics">Statistics</a></li>
                        <li ng-show="eventDetails.teamsCount > 0" ng-class="{active: activeTab == 'teams'}" class="always-reloadable"><a ng-href="/event/M2014/teams" href="/event/M2014/teams">Teams</a></li>
                        <li ng-class="{active: activeTab == 'compare'}"><a ng-href="/event/M2014/compare" href="/event/M2014/compare">Compare</a></li>
                    </ul>
                </div>
            </div>
        </div>
    </div>
    <div class="b-head_sub_menu_affix_after before_finishers" ng-class="{ before_finishers : activeTab == 'finishers' &amp;&amp; !layoutScope.isResultDetailsExpanded(), before_team_awards : activeTab == 'awards' &amp;&amp; eventDetails.teamAwardsCount > 0 &amp;&amp; !layoutScope.isResultDetailsExpanded(), before_teams : activeTab == 'teams' &amp;&amp; !layoutScope.isResultDetailsExpanded() }">
    </div>
</div><!-- end ngIf: layoutScope.isHeaderVisible -->

<!-- ngIf: Ads.ad --></div>
<!-- uiView: container --><div ui-view="container" ng-hide="layoutScope.isFreeTextSearch" class="ng-scope"><div ng-controller="runnerGraphController" class="b-content ng-scope">
    <div class="b-fix_wrapper">

        <div class="container-fluid">
            <div class="row">
                <div class="col-xs-9 col-sm-9 col-md-9 rms-no-padding">
                    <div class="page-tab-menu">
                        <ul class="submenu nav nav-tabs">
                            <!-- ngRepeat: handicap in filterHandicaps track by $index --><li ng-class="{ 'active' : handicap == selectedHandicap }" ng-show="handicap.count > 0" ng-repeat="handicap in filterHandicaps track by $index" class="ng-scope active">
                                <a ng-hide="finishersLoading" ng-click="selectHandicap(handicap)" href="#" class="ng-binding">Runners: <span ng-show="handicap == selectedHandicap &amp;&amp; filteredFinishersCount != handicap.count" class="not-bold text-lowercase ng-binding ng-hide">50395 of </span><span class="ng-binding">50395</span></a>
                            </li><!-- end ngRepeat: handicap in filterHandicaps track by $index --><li ng-class="{ 'active' : handicap == selectedHandicap }" ng-show="handicap.count > 0" ng-repeat="handicap in filterHandicaps track by $index" class="ng-scope">
                                <a ng-hide="finishersLoading" ng-click="selectHandicap(handicap)" href="#" class="ng-binding">Wheelchair: <span ng-show="handicap == selectedHandicap &amp;&amp; filteredFinishersCount != handicap.count" class="not-bold text-lowercase ng-binding ng-hide">50395 of </span><span class="ng-binding">66</span></a>
                            </li><!-- end ngRepeat: handicap in filterHandicaps track by $index --><li ng-class="{ 'active' : handicap == selectedHandicap }" ng-show="handicap.count > 0" ng-repeat="handicap in filterHandicaps track by $index" class="ng-scope">
                                <a ng-hide="finishersLoading" ng-click="selectHandicap(handicap)" href="#" class="ng-binding">Handcycles: <span ng-show="handicap == selectedHandicap &amp;&amp; filteredFinishersCount != handicap.count" class="not-bold text-lowercase ng-binding ng-hide">50395 of </span><span class="ng-binding">67</span></a>
                            </li><!-- end ngRepeat: handicap in filterHandicaps track by $index -->
                        </ul>
                    </div>
                </div>
                <!-- ngIf: layoutScope.isDesktopView -->
            </div>
        </div>

        <div class="container-fluid">
            <div class="row">
                <div class="col-xs-12 col-sm-12 col-md-12 rms-no-padding">
                    <div ng-style="{ 'margin-bottom' : '5px'}" ng-hide="layoutScope.isGlobalSearchVisible" style="margin-bottom: 5px;">
                        <script id="/finishers-template.html" type="text/ng-template">
                            <div id="parentDisable"></div>
                            <div class="angucomplete-holder b-search" ng-class="{'angucomplete-dropdown-visible': showDropdown}">
                                <div class="b-search-form">
                                    <input id="{{ id }}_value"
                                           name="{{ inputName }}"
                                           tabindex="{{ fieldTabindex }}"
                                           ng-model="searchStr"
                                           ng-disabled="disableInput"
                                           type="text"
                                           placeholder="{{ placeholder }}"
                                           ng-focus="onFocusHandler(); resetHideResults();"
                                           class="{{ inputClass }}"
                                           ng-blur="hideResults($event)"
                                           autocapitalize="off"
                                           autocorrect="off"
                                           autocomplete="off"
                                           ng-change="inputChangeHandler(searchStr)"
                                           focus-me="showDropdown"
                                           maxlength="50" />
                                    <div class="control_buttons">
                                        <a class="b-search__button" ng-click="$parent.freeTextSearch(searchStr)" ng-show="$parent.searchString != searchStr" href="#"></a>
                                        <a class="b-clear__button" ng-click="$parent.clearFreeTextSearch()" ng-show="$parent.searchString == searchStr && $parent.searchString" href="#"></a>
                                    </div>

                                    <div class="b-search_autocomplete">
                                        <div id="{{id}}_dropdown" class="angucomplete-dropdown" ng-show="showDropdown">
                                            <div class="angucomplete-searching b-searching" ng-show="searching" ng-bind="textSearching"></div>
                                            <div class="angucomplete-searching b-searching" ng-show="!searching && (!results || results.length == 0) && searchStr" ng-bind="textNoResults"></div>
                                            <div class="angucomplete-searching b-searching" ng-show="!searching && (!results || results.length == 0) && !searchStr">Type in First Name, Last Name or Bib</div>
                                            <div class="row angucomplete-row" ng-repeat="result in results" ng-click="selectResult(result)" ng-mouseenter="hoverRow($index)" ng-class="{'selected': $index == currentIndex}" style="margin-left: 0; margin-right: 0; cursor: pointer;">
                                                <div class="col-xs-9 col-sm-9 col-md-9">
                                                    <div class="name angucomplete-title" ng-if="matchClass" ng-bind-html="result.title"></div>
                                                    <div class="name angucomplete-title" ng-if="!matchClass">{{ result.title }}</div>
                                                    <div>
                                                        Bib: <span ng-bind-html="result.originalObject.bib | highlight : searchStr"></span> | Place: {{ result.originalObject.overallPlace }} | {{ result.originalObject.address }}
                                                    </div>
                                                </div>
                                                <a>
                                                    <div class="col-xs-3 col-sm-3 col-md-3">
                                                        <span class="goto">View Runner Results</span>
                                                        <span>{{ result.originalObject.overallTime }}</span>
                                                    </div>
                                                </a>
                                            </div>
                                        </div>
                                        <div ng-show="showDropdown && results.length > 0" class="goto-search-results cursor-pointer" ng-click="$parent.freeTextSearch(searchStr)">
                                            <a href="#">More Results &gt;</a>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </script>

                        <div angucomplete-alt="" id="search-finishers" class="autocomplete-search ng-isolate-scope" placeholder="Search For a Runner from this Race" pause="300" selected-object="objectSelectedCallback" remote-api-handler="searchResults" remote-url-data-field="response.items" title-field="firstName,lastName" minlength="0" input-class="b-search-input" match-class="highlight" remote-url-error-callback="httpErrorCallback" input-enter-handler="freeTextSearch" template-url="/finishers-template.html" text-no-results="No results found" focus-in="finisherSearchFocusIn" focus-out="finisherSearchFocusOut">
                            <div id="parentDisable"></div>
                            <div class="angucomplete-holder b-search" ng-class="{'angucomplete-dropdown-visible': showDropdown}">
                                <div class="b-search-form">
                                    <input id="search-finishers_value" name="" tabindex="" ng-model="searchStr" ng-disabled="disableInput" type="text" placeholder="Search For a Runner from this Race" ng-focus="onFocusHandler(); resetHideResults();" class="b-search-input ng-valid-maxlength" ng-blur="hideResults($event)" autocapitalize="off" autocorrect="off" autocomplete="off" ng-change="inputChangeHandler(searchStr)" focus-me="showDropdown" maxlength="50">
                                    <div class="control_buttons">
                                        <a class="b-search__button ng-hide" ng-click="$parent.freeTextSearch(searchStr)" ng-show="$parent.searchString != searchStr" href="#"></a>
                                        <a class="b-clear__button ng-hide" ng-click="$parent.clearFreeTextSearch()" ng-show="$parent.searchString == searchStr &amp;&amp; $parent.searchString" href="#"></a>
                                    </div>

                                    <div class="b-search_autocomplete">
                                        <div id="search-finishers_dropdown" class="angucomplete-dropdown ng-hide" ng-show="showDropdown">
                                            <div class="angucomplete-searching b-searching ng-binding ng-hide" ng-show="searching" ng-bind="textSearching">Searching...</div>
                                            <div class="angucomplete-searching b-searching ng-binding ng-hide" ng-show="!searching &amp;&amp; (!results || results.length == 0) &amp;&amp; searchStr" ng-bind="textNoResults">No results found</div>
                                            <div class="angucomplete-searching b-searching" ng-show="!searching &amp;&amp; (!results || results.length == 0) &amp;&amp; !searchStr">Type in First Name, Last Name or Bib</div>
                                            <!-- ngRepeat: result in results -->
                                        </div>
                                        <div ng-show="showDropdown &amp;&amp; results.length > 0" class="goto-search-results cursor-pointer ng-hide" ng-click="$parent.freeTextSearch(searchStr)">
                                            <a href="#">More Results &gt;</a>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </div>

        <div id="sort" class="container-fluid b-sort" ng-class="{ 'after-autocomplete': isFreeSearchMode }">
            <div class="row" ng-show="!hasAnyAdvancedFilter()">
                <div class="col-xs-9 col-sm-9 col-md-9">
                    <!-- ngIf: !layoutScope.isMobileView && !layoutScope.isTabletView -->
                    <div class="dropdown dropdown-main short-filter">
                        <a role="button" data-toggle="dropdown" data-target="#" href="#" class="filter-button ng-binding">
                            All Genders <span class="caret"></span>
                        </a>
                        <div class="dropdown-menu">
                            <ul role="menu">
                                <li>
                                    <a ng-click="selectGender(null)" ng-class="{ 'checked active' : selectedGender == null }" href="#" class="checked active">All Genders</a>
                                </li>
                                <li>
                                    <a ng-click="selectGender('M')" ng-class="{ 'checked active' : selectedGender == 'M' }" href="#">Men</a>
                                </li>
                                <li>
                                    <a ng-click="selectGender('W')" ng-class="{ 'checked active' : selectedGender == 'W' }" href="#">Women</a>
                                </li>
                                <li>
                                    <a ng-click="selectGender('X')" ng-class="{ 'checked active' : selectedGender == 'X' }" href="#">Non-Binary</a>
                                </li>
                            </ul>
                        </div>
                    </div>
                    <div class="dropdown dropdown-main short-filter ages-filter">
                        <a role="button" data-toggle="dropdown" data-target="#" href="#" class="filter-button ng-binding">
                            All ages <span class="caret"></span>
                        </a>
                        <div class="dropdown-menu">
                            <ul role="menu">
                                <li>
                                    <a ng-click="selectAgeGroup(null)" ng-class="{ 'active' : !(selectedAgeFrom &amp;&amp; selectedAgeTo &amp;&amp; selectedAgeFrom !== selectedAgeTo) }" href="#" class="active">All ages</a>
                                </li>
                                <!-- ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 18-19</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 20-24</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 25-29</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 30-34</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 35-39</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 40-44</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 45-49</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 50-54</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 55-59</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 60-64</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 65-69</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 70-74</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 75-79</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 80-89</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index --><li ng-repeat="ageGroup in filterAgeGroups track by $index" class="ng-scope">
                                    <a ng-click="selectAgeGroup(ageGroup)" ng-class="{ 'active' : ageGroup.ageFrom === selectedAgeFrom &amp;&amp; ageGroup.ageTo === selectedAgeTo }" href="#" class="ng-binding">Age: 90-99</a>
                                </li><!-- end ngRepeat: ageGroup in filterAgeGroups track by $index -->
                            </ul>
                        </div>
                    </div>
                    <div class="short-filter button-advanced-filter" style="width: 150px;" ng-click="showAdvancedFilter()">
                        <span class="filter-button">
                            Advanced Filter <i class="glyphicon glyphicon-filter"></i>
                        </span>
                    </div>
                </div>
                <div class="col-xs-3 col-sm-3 col-md-3 active">
                    <!-- ngIf: !layoutScope.isMobileView && !layoutScope.isTabletView -->
                    <div class="dropdown dropdown-main short-filter" style="float: right;">
                        <a role="button" data-toggle="dropdown" data-target="#" href="#" class="filter-button ng-binding">
                            Finish Time <span class="caret"></span>
                        </a>
                        <div class="dropdown-menu">
                            <ul role="menu">
                                <!-- ngRepeat: (key, value) in filterSortColumns track by $index --><li ng-repeat="(key, value) in filterSortColumns track by $index" class="ng-scope">
                                    <a class="no-background ng-binding active sort-asc" ng-click="selectSortColumn(key)" ng-class="{ 'active' : key == selectedSortColumn, 'sort-asc' : (key === selectedSortColumn &amp;&amp; !selectedSortDescending), 'sort-desc' : (key === selectedSortColumn &amp;&amp; selectedSortDescending) }" href="#">Finish Time</a>
                                </li><!-- end ngRepeat: (key, value) in filterSortColumns track by $index --><li ng-repeat="(key, value) in filterSortColumns track by $index" class="ng-scope">
                                    <a class="no-background ng-binding" ng-click="selectSortColumn(key)" ng-class="{ 'active' : key == selectedSortColumn, 'sort-asc' : (key === selectedSortColumn &amp;&amp; !selectedSortDescending), 'sort-desc' : (key === selectedSortColumn &amp;&amp; selectedSortDescending) }" href="#">Gun Time</a>
                                </li><!-- end ngRepeat: (key, value) in filterSortColumns track by $index --><li ng-repeat="(key, value) in filterSortColumns track by $index" class="ng-scope">
                                    <a class="no-background ng-binding" ng-click="selectSortColumn(key)" ng-class="{ 'active' : key == selectedSortColumn, 'sort-asc' : (key === selectedSortColumn &amp;&amp; !selectedSortDescending), 'sort-desc' : (key === selectedSortColumn &amp;&amp; selectedSortDescending) }" href="#">Age-Graded Time</a>
                                </li><!-- end ngRepeat: (key, value) in filterSortColumns track by $index --><li ng-repeat="(key, value) in filterSortColumns track by $index" class="ng-scope">
                                    <a class="no-background ng-binding" ng-click="selectSortColumn(key)" ng-class="{ 'active' : key == selectedSortColumn, 'sort-asc' : (key === selectedSortColumn &amp;&amp; !selectedSortDescending), 'sort-desc' : (key === selectedSortColumn &amp;&amp; selectedSortDescending) }" href="#">Age-Graded Place</a>
                                </li><!-- end ngRepeat: (key, value) in filterSortColumns track by $index --><li ng-repeat="(key, value) in filterSortColumns track by $index" class="ng-scope">
                                    <a class="no-background ng-binding" ng-click="selectSortColumn(key)" ng-class="{ 'active' : key == selectedSortColumn, 'sort-asc' : (key === selectedSortColumn &amp;&amp; !selectedSortDescending), 'sort-desc' : (key === selectedSortColumn &amp;&amp; selectedSortDescending) }" href="#">Age Graded Percentage</a>
                                </li><!-- end ngRepeat: (key, value) in filterSortColumns track by $index -->
                            </ul>
                        </div>
                    </div>
                </div>
            </div>

            <div class="row ng-hide" ng-show="hasAnyAdvancedFilter()">
                <div class="col-xs-12">
                    <span style="font-size: 1.2em">Finishers filtered by: </span>
                    <!-- ngIf: selectedCountryCode -->
                    <!-- ngIf: selectedStateProvince -->
                    <!-- ngIf: selectedCity -->
                    <!-- ngIf: selectedTeamName -->
                    <!-- ngIf: selectedTeamCode -->
                    <!-- ngIf: selectedGender -->
                    <!-- ngIf: selectedAgeFrom && selectedAgeTo && selectedAgeFrom != selectedAgeTo -->
                    <!-- ngIf: selectedAgeFrom && selectedAgeTo && selectedAgeFrom == selectedAgeTo -->
                    <!-- Overall Place -->
                    <!-- ngIf: selectedOverallPlaceFrom && selectedOverallPlaceTo && selectedOverallPlaceFrom === selectedOverallPlaceTo -->
                    <!-- ngIf: selectedOverallPlaceFrom && !selectedOverallPlaceTo -->
                    <!-- ngIf: !selectedOverallPlaceFrom && selectedOverallPlaceTo -->
                    <!-- Pace -->
                    <!-- ngIf: selectedPaceFrom && selectedPaceTo && selectedPaceFrom === selectedPaceTo -->
                    <!-- ngIf: selectedPaceFrom && !selectedPaceTo -->
                    <!-- ngIf: !selectedPaceFrom && selectedPaceTo -->
                    <!-- Finish Time -->
                    <!-- ngIf: selectedOverallTimeFrom && selectedOverallTimeTo && selectedOverallTimeFrom === selectedOverallTimeTo -->
                    <!-- ngIf: selectedOverallTimeFrom && !selectedOverallTimeTo -->
                    <!-- ngIf: !selectedOverallTimeFrom && selectedOverallTimeTo -->
                    <!-- Gun Time -->
                    <!-- ngIf: selectedGunTimeFrom && selectedGunTimeTo && selectedGunTimeFrom === selectedGunTimeTo -->
                    <!-- ngIf: selectedGunTimeFrom && !selectedGunTimeTo -->
                    <!-- ngIf: !selectedGunTimeFrom && selectedGunTimeTo -->
                    <!-- Age-Graded Time -->
                    <!-- ngIf: selectedAgeGradedTimeFrom && selectedAgeGradedTimeTo && selectedAgeGradedTimeFrom === selectedAgeGradedTimeTo -->
                    <!-- ngIf: selectedAgeGradedTimeFrom && !selectedAgeGradedTimeTo -->
                    <!-- ngIf: !selectedAgeGradedTimeFrom && selectedAgeGradedTimeTo -->
                    <!-- Age-Graded Place -->
                    <!-- ngIf: selectedAgeGradedPlaceFrom && selectedAgeGradedPlaceTo && selectedAgeGradedPlaceFrom === selectedAgeGradedPlaceTo -->
                    <!-- ngIf: selectedAgeGradedPlaceFrom && !selectedAgeGradedPlaceTo -->
                    <!-- ngIf: !selectedAgeGradedPlaceFrom && selectedAgeGradedPlaceTo -->
                    <!-- Age-Graded Percentage -->
                    <!-- ngIf: selectedAgeGradedPerformanceFrom && selectedAgeGradedPerformanceTo && selectedAgeGradedPerformanceFrom === selectedAgeGradedPerformanceTo -->
                    <!-- ngIf: selectedAgeGradedPerformanceFrom && !selectedAgeGradedPerformanceTo -->
                    <!-- ngIf: !selectedAgeGradedPerformanceFrom && selectedAgeGradedPerformanceTo -->
                </div>
                <div class="col-sm-12 text-right" style="padding-bottom: 10px">
                    <a class="btn btn-link button-clear" href="#" ng-click="clearAllFilters()">Clear All</a>
                    <a class="btn btn-default button-apply" href="#" ng-click="showAdvancedFilter()">Edit</a>
                </div>
            </div>
        </div>

        <div ng-show="eventFinishers.length > 0" class="">
            <!-- ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Wilson Kipsang
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:10:59</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:00</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">1</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lelisa Desisa Benti
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ETH</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">4</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:11:06</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:01</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">2</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Gebre Gebremariam
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ETH</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">7</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:12:13</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:03</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">3</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Meb Keflezighi
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">San Diego</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">5</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:13:18</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">4</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stephen Kiprotich
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M25</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">UGA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">11</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:13:25</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">5</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Geoffrey Mutai
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:13:44</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:07</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">6</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Masato Imai
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">6</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:14:36</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:08</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">7</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Peter Cheruiyot Kirui
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">8</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:14:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:09</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">8</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ryan Vail
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Portland</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">OR</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">12</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:15:08</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">9</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nick Arciniaga
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Flagstaff</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">AZ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">15</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:15:39</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:11</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">10</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Yuki Kawauchi
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">14</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:16:41</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:13</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">11</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lusapho April
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">RSA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">3</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:16:50</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:14</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">12</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Birhanu Dare Kemal
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ETH</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">212</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:18:24</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:17</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">13</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Micah Kogo
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">10</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:18:36</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:18</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">14</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Danilo Goffi
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">40</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:19:44</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:20</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">15</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stephan Shay
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Huntington Beach</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">20</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:19:47</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:20</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">16</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Michael Kipyego
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">9</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:20:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">17</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Negash Abebe Duki
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ETH</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">200</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:20:15</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">18</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Harbert Okuti
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">UGA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">34</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:22:34</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">19</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Aron Rono
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Beaverton</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">OR</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">36</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:23:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">20</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Craig Hopkins
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">27</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:23:49</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">21</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Zach Hine
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Boulder</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CO</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">26</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:24:10</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">22</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lars Budolfsen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">DEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">23</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:24:40</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:32</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">23</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Teklu Tefera Deneke
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ETH</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">29</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:25:07</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:33</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">24</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mary Keitany
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">104</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:25:07</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:33</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">25</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lee Troop
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">41</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:25:09</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:33</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">26</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jemima Sumgong
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">106</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:25:10</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:33</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">27</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alex Varner
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">San Rafael</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">246</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:25:45</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:34</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">28</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Gian Luca Borghesi
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">206</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:25:49</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:34</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">29</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                James Kelly
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">33</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:25:56</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:34</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">30</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sara Moreira
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">116</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:26:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:35</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">31</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jelena Prokopcuka
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">LAT</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">103</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:26:15</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:35</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">32</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jerry Faulkner
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Sunnyside</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">215</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:26:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:36</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">33</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nick End
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Pittsburgh</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">PA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">30</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:26:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:37</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">34</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Oz Pearlman
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">234</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:26:59</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:37</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">35</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Craig Curley
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Tucson</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">AZ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">25</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:27:33</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:38</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">36</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Denis Curzi
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">28</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:27:35</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:38</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">37</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Frank Bollen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">BEL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">22</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:28:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:39</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">38</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nils Schallner
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GER</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">239</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:28:06</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:39</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">39</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Desiree Linden
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Washington</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MI</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">109</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:28:11</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:40</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">40</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Firehiwot Dado
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ETH</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">108</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:28:36</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:41</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">41</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Luke Puskedra
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Beaverton</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">OR</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">17</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:28:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:41</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">42</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nelson Cruz
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1028</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:29:19</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:42</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">43</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Valeria Straneo
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">107</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:29:24</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:42</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">44</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jaakko Nieminen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FIN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">296</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:29:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:43</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">45</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Siemers
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Littleton</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CO</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">32</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:30:04</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:44</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">46</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Max Haines-Stiles
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">San Francisco</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">217</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:30:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:45</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">47</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Abel Villanueva Taipe
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">PER</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">38</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:30:33</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:45</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">48</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sebastien Bazeille
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1179</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:30:34</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:45</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">49</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Martin Kjall-Ohlsson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">221</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:30:56</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:46</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">50</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Roman Weger
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUT</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">47</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:31:11</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:46</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">51</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Buzunesh Deba
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ETH</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">102</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:31:40</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:48</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">52</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ben Leese
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">225</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:31:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:48</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">53</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Claes Bengtsson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">204</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:31:57</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:48</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">54</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ole Kristian Heggheim
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NOR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">218</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:32:13</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:49</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">55</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Urige Buta
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NOR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">18</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:32:13</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:49</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">56</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                José Gaspar
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1048</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:32:42</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:50</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">57</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Oscar Martin Perez
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ESP</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1161</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:01</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:51</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">58</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Annie Bersagel
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Oslo</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">115</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:02</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:51</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">59</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Billy Demong
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Park City</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">UT</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1828</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:05</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:51</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">60</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Deena Kastor
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Mammoth Lakes</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">110</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:18</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:51</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">61</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Tim Clarke
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1151</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:23</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:51</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">62</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Antonello Landi
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1059</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:52</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">63</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jeff Ares
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">243</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:52</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">64</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Greg Cass
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">208</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:33:41</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:52</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">65</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Hermann Achmueller
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">201</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:34:05</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:53</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">66</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Philippe Rolly
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Fairfax</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">VA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">45</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:34:32</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:54</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">67</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Joseph Darda
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Willimantic</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CT</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">211</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:34:53</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:55</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">68</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Phillip Falk
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">213</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:34:53</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:55</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">69</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jeffrey Stein
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Washington</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">DC</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1346</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:35:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:55</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">70</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Patrick Hearn
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Mount Pleasant</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">SC</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1349</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:35:28</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:56</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">71</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Teddy Bezancon
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1199</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:35:28</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:56</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">72</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                William Vanos
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Orlando</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">FL</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">245</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:35:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:56</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">73</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ana Dulce Felix
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">112</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:35:33</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:56</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">74</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sam Krieg
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Pocatello</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">ID</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1829</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:57</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">75</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jeff Bailey
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Villa Park</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">IL</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">202</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:57</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">76</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Brett Coleman
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1120</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:23</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:58</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">77</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sebastien Charnay
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">210</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:23</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:58</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">78</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Edna Kiplagat
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">KEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">105</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:24</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:58</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">79</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lars Martin Steen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NOR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1401</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:27</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:59</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">80</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mac Schneider
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Woodway</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">WA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1456</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:38</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:59</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">81</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alister Gardner
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1248</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:47</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:59</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">82</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Bryan Kovalsky
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Ridgefield</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CT</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">222</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:59</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">83</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kyle Sousa
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Taunton</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1520</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">05:59</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">84</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Bryan Sharkey
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Miami</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">FL</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">241</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:36:55</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:00</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">85</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Hector Rivera
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Clifton</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NJ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">237</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:37:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:00</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">86</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kara Goucher
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Boulder</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CO</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">111</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:37:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:00</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">87</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Benjamin Ludovici
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Syracuse</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1091</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:37:20</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:01</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">88</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Emiliano Garcia
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">MEX</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">829</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:37:43</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:01</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">89</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Christian Dirscherl
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GER</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">214</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:37:49</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:02</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">90</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Antoine Rondot
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">238</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:37:56</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:02</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">91</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jose Ruiz Tagle
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CHI</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1115</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:02</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">92</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Bjarke Kobberoe
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">DEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1167</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:02</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">93</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alejandro Troncoso
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Tucson</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">AZ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">242</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:02</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">94</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Piergiorgio Conti
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M44</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">96</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:05</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:02</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">95</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Carlos Cardoso
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1827</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:03</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">96</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Aaron Beaber
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Minneapolis</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MN</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1450</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:03</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">97</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Marcel Tschopp
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">LIE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">244</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:32</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:03</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">98</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Tom Fairbrother
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1138</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:46</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:04</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">99</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Paul Jacobs
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Washington</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">DC</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1284</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:50</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:04</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">100</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Finn Kollstad
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NOR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1196</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:04</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">101</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Amado Tlatempa
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Bronx</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">789</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:04</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">102</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mathew Weissinger
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Northampton</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1100</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:04</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">103</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Daniel Robinson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1206</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:04</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">104</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Hugh Parker
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">233</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:38:57</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:04</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">105</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Abd Amare
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1134</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:08</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:05</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">106</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lauren Kleppin
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W25</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Mammoth Lakes</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">114</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:13</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:05</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">107</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Adam Mulia
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brooklyn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">718</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:14</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:05</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">108</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Peter Hanson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Seattle</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">WA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1262</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:21</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:05</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">109</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nicholas Browne
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NZL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1155</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:05</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">110</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Carlos Gonzalez servian
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M23</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">PAR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1147</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:05</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">111</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Tim Seeley
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Conshohocken</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">PA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">240</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:27</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:05</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">112</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Johan Yvalun
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1326</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:32</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">113</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jordan Tropf
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M22</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Annapolis</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MD</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1210</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:38</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">114</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Matt Dahl
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New Brunswick</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NJ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1387</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:39</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">115</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Liam Harrison
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Chappaqua</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">652</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:43</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">116</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alia Gray
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W25</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Boulder</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CO</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">126</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:43</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">117</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jyrki Ruohomaki
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FIN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">751</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:48</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">118</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Rob Nachtwey
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Berkeley</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1395</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:49</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">119</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Raulli
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Syracuse</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">235</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">120</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ruotte Anthony
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1220</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:55</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:06</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">121</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Julio Sauce
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ECU</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">758</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:57</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:07</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">122</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Anders Christensen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">DEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1430</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:39:57</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:07</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">123</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Marci Gage
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Bend</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">OR</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">120</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:07</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">124</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nikolaj Mikkelsen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">DEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1521</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:06</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:07</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">125</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                David Dixon
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M22</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Cleveland</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">OH</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1070</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:15</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:07</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">126</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Miguel Dones
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Luquillo</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">PR</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1043</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:08</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">127</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                David Gibson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1397</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:08</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">128</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sean Egan
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Wyncote</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">PA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">607</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:08</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">129</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Carlo Agostinetto
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">822</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:44</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:08</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">130</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Hilary Dionne
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Charlestown</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">121</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:09</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">131</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stephane Deleurme
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1294</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:40:56</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:09</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">132</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Patrick Cote
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1423</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:04</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:09</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">133</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Matthew Reisenauer
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Seattle</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">WA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1381</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:07</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:09</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">134</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nick Roberts
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1451</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:08</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:09</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">135</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Astrel Clovis
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M44</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Los Angeles</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1867</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:20</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">136</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                David Nightingale
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">232</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:25</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">137</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Richard Skilling
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M48</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2322</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">138</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                David Roeske
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brooklyn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">748</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">139</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jamie Stroffolino
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Wappingers Falls</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1518</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">140</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Matthew Gibson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1429</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:32</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">141</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Danilo Osimani
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1338</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:41</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:10</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">142</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Antonio Giardiello
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1185</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:11</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">143</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Michael Stadolnik
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Plainfield</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CT</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1409</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:41:59</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:11</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">144</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ben Evans
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1247</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:11</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">145</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Peter Mackrell
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Leighton Buzzard</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1463</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:04</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:11</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">146</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Matt Leduc
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1071</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:09</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">147</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jan Daems
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M44</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">BEL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1187</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:12</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">148</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Diego Vanegas
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1843</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:13</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">149</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lawrence Avery
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1531</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:18</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">150</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sam Harper
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1486</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">151</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Eddy Bossier
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M50</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">BEL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">207</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">152</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Trygve Andresen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NOR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1418</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:32</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">153</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Francois Lhuissier
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">227</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:42:33</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:12</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">154</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Fernando Villarmin
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ESP</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1149</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:14</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">155</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Timothy Kramer
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1587</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:14</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">156</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lionel Ribeiro
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">236</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:27</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">157</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Dylan Marton
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M23</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Somerville</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NJ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1565</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">158</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Koji Kawamoto
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1236</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">159</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Yuji Yamanaka
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1150</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">160</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Domenico Barbierato
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1718</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:35</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">161</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Fan Zhou
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Lexington</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">KY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1359</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:40</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">162</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Brendan Trimboli
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Durango</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CO</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1164</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:42</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">163</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alfredo Norvello
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M47</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">826</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:43</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">164</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alessio Asaro
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M25</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Forest Hills</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1260</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:43</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:15</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">165</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Laurent Humbert
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1188</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:43:55</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:16</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">166</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Graham
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1400</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:16</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">167</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Magnus Mattsson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1422</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:15</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:16</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">168</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Patrik Nystrom
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M44</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1413</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:21</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:17</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">169</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stephane Hannot
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1086</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:21</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:17</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">170</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ryan Swartz
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Houston</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">TX</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1426</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:35</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:17</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">171</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Tomasz Polanski
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1433</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:39</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:17</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">172</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Masahiro Takaoka
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1559</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:46</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:18</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">173</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Eric Noel
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1265</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:44:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:18</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">174</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sean Welleck
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M23</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Austin</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">TX</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1218</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:06</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:18</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">175</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jacob Frandsen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">DEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1672</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:10</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:18</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">176</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Domenico la Banca
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1567</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:12</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">177</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Dawes
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">593</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:19</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">178</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Robert Michell
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Glenn Dale</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MD</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1608</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">179</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Devin Kelly
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M23</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2999</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:23</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">180</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kenneth Rideout
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Katonah</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">747</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">181</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Rocio Cantara Rojas
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">PER</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">131</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">182</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Andrew Archer
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M26</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Park City</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">UT</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1301</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:34</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">183</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nicholas Thompson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brooklyn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">785</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:36</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:19</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">184</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kate Pallardy
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">128</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:46</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:20</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">185</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                James McGovern
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Atlantic Highlands</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NJ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1139</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:50</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:20</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">186</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ottaviano Andriani
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1325</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:53</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:20</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">187</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stefano Baldini
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1355</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:45:53</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:20</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">188</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Derek Zelazny
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Dallas</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">TX</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1183</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:01</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:20</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">189</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Gerard Combalia Claverias
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ESP</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1668</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:05</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">190</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Brad Hart
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1172</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:13</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">191</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ian Neill
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Boston</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1484</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:14</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">192</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                David Dreverman
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1157</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:17</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">193</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jonathon Laurie
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1033</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:21</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">194</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Pablo Gonzalez
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CHI</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1599</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:21</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">195</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mitch VanBruggen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Sunnyvale</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">797</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:22</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">196</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Curtis Suver
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Colorado Springs</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CO</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1826</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:39</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:22</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">197</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                John Ealy
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Baltimore</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MD</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2901</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:42</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:22</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">198</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Boyd Carrington
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Amityville</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1207</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:45</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:22</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">199</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Brett Bernakevitch
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1601</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:46</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:22</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">200</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Erik Bergersen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M45</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NOR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1250</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:46:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:22</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">201</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Keith Nicoll
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M50</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">12601</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:01</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">202</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Marcel Buehler
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M48</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SUI</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2259</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:04</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">203</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Norikazu Endo
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1264</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:04</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">204</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Scott Burger
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M23</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Worcester</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1201</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:05</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">205</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kurt Michels
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Tucson</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">AZ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">230</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:07</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">206</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Fabian Daza Pacheco
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">COL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">594</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:07</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">207</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Joel Scholz
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Wheat Ridge</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CO</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1502</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:11</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">208</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Louis-Philippe Garnier
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M50</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">50</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:17</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">209</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kamel Latrach
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1549</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:19</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:23</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">210</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Rich Power
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M50</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Rochester</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MI</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1311</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:23</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">211</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Marcos Duarte
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ARG</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">601</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:24</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">212</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Katie Conlon
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Seattle</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">WA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2887</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:28</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">213</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Farley
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Arlington</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">VA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">8491</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:40</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">214</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jotham Burnett
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M34</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brooklyn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1556</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:42</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">215</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Luke Shane
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Bolton Lnding</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1234</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:43</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">216</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stephen Fair
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brookline</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1307</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:46</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">217</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Angel Saul Garcia-Parrado Illescas
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ESP</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1488</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:46</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">218</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Luca Fabbri
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2839</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:48</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">219</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Derek Hanson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Glendale</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">650</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:48</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:24</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">220</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stephen Tranter
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">791</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">221</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Isaiah Leonard
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M21</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1554</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:47:55</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">222</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Stephane Humblot
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M46</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1331</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:01</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">223</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Krzysztof Zegarek
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M25</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2363</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:03</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">224</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Matej Valtr
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CZE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1269</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:05</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">225</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lars Emanuelsson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1730</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:10</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">226</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Atsushi Ito
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">666</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:11</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">227</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Timothy Stiel
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M47</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2091</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:12</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">228</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Eladio Telecher
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M55</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1252</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:14</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:25</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">229</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Carlos Abellan
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ESP</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2071</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:21</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">230</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jeremy Cook
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Hudson</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">WI</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1310</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">231</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Aleksandr Cherenev
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M39</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">RUS</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">9790</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:24</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">232</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ivan Jezko
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SVK</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1511</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:25</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">233</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                George Wright
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1533</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">234</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Parris-Lamb
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brooklyn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1363</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:28</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">235</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Charles Prange
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1544</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">236</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lawrence Quinn
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Pittsburgh</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">PA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1305</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">237</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Anders Marcusson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1302</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:30</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">238</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Cristiano Spiller
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1062</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">239</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Dominique Chauvelier
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M58</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1656</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">240</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Lionel Vignon
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M46</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1879</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:32</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">241</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Felipe Vergara
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M50</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">MEX</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">800</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:33</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:26</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">242</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kvikstad Rune
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NOR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1292</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:45</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">243</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Seamus Fearon
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">IRL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1678</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:48</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">244</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Palos
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M46</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Ashburn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">VA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2331</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:48</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">245</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Dave Walters
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M59</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Lisle</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">IL</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1462</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:50</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">246</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Brian Lashinski
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Minneapolis</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MN</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1460</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">247</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Daniel Webber
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1408</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">248</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Martin Hanisch
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">AUT</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1427</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">249</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ted Callinan
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Haddonfield</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NJ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">43</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">250</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mario Dimas
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">MEX</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1268</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">251</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mattias Hagen
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M42</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Lidingö</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1817</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:48:59</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">252</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Rickard Pell
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1465</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:00</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">253</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Markus Gustafsson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M35</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2048</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:04</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:27</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">254</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Michael Rodriguez
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Des Moines</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">IA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1005</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:08</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">255</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Tim Rossi
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M22</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">749</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:09</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">256</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Philip Lang
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">684</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:11</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">257</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jeff Matsumoto
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Scottsdale</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">AZ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1365</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:12</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">258</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Joel McCreary
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Phoenix</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">AZ</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1596</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:14</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">259</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Michelle Lilienthal
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Portland</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">ME</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">119</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:16</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">260</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alexander Batanov
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M46</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1848</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:21</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">261</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Juan Carlos Solorzano
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M36</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CRC</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2285</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">262</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Alexander Walsh
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brooklyn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">803</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:25</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">263</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Avery Best
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1588</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">264</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Shawn Pollard
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">East Setauket</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1547</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:27</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">265</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mario Carreira
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M46</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1209</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">266</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nils Wetterberg
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M24</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1515</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">267</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Eros Gnoli
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1862</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">268</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kieran Condon
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M37</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">IRL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1473</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:32</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:28</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">269</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Kevin Galante
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Massapequa</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1653</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:34</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">270</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Andrew Leveson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">226</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:35</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">271</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Enrico Benedetti
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1870</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:40</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">272</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Cyril Willemin
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Chicago</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">IL</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1345</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:44</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">273</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Brad Weiss
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">807</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:45</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">274</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Claudio Giorgetti
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M54</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1333</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:48</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">275</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Mario Segura
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Bronx</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1607</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:49</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">276</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Sean Delanghe
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M29</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1398</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:51</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">277</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Adam Kuklinski
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M50</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POL</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">683</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:53</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">278</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Michael Rothbart
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1136</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:55</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">279</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Ruud Hadders
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M28</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">NED</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1246</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:57</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">280</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jean-Baptiste Theard
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1492</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:58</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">281</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Yutaka Fukuda
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M44</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">3477</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:49:58</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:29</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">282</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Elenilton Rangel
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">BRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1280</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:02</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">283</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Thomas Boland
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Medford</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">MA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2093</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:05</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">284</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Antonio Belotti
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2205</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:11</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">285</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Luis Carlos Perez
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ESP</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1541</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:12</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">286</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Drew VandenBrul
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M43</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Glen Mills</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">PA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1705</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:16</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">287</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Justin McCarthy
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M32</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Arlington</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">VA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1221</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:18</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">288</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jake Stookey
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Clifton Park</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1469</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:18</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">289</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Steven Bothe
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Newnan</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">GA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1279</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:22</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">290</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Akira Nishimura
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M38</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">JPN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2201</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:25</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">291</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Pierrick Le Roux
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">FRA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1561</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:30</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">292</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Martin Gignac
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M41</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">CAN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1714</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:26</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">293</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Chris Carroll
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M31</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">San Carlos</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">CA</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1241</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:29</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">294</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Henning Bechmann
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M48</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">DEN</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1479</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:31</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">295</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Nicholas Hippensteel
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">Brooklyn</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1740</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:34</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">296</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Jesus Zamora
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M23</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">New York</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1606</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:36</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">297</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Peter Rowe
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M27</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1439</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:39</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">298</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Michael Ohler
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M45</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GER</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">2264</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:41</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">299</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Edmund Fazakerley
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M45</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">GBR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1679</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:41</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">300</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Carlos Ferreira
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M33</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">POR</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1232</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:41</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">301</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Linus Eriksson
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M40</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">SWE</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1519</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:44</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:31</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">302</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Adolfo Munguia
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M30</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">MEX</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">719</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:52</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:32</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">303</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Roberto Epifani
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M21</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">3878</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:32</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">304</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Benjamin Shields
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">M22</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa --><span ng-if="eventFinisher.city &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">West Point</span><!-- end ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa --><span ng-if="eventFinisher.stateProvince &amp;&amp; eventFinisher.showUsa" class="ng-binding ng-scope">NY</span><!-- end ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">USA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">1501</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:54</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:32</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">305</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers --><div ng-repeat="eventFinisher in eventFinishers" class="cmd-finisher ng-scope">
                <div class="container-fluid b-runners_detailes-list">
                    <div class="row rms-grid-item" ng-click="openRunnerResults(eventCode, eventFinisher.bib)" ng-class="{ 'narrow' : layoutScope.isGridRowNarrow &amp;&amp; layoutScope.isDesktopView }">
                        <div class="col-xs-4 col-sm-4 col-md-6 h-100" style="padding-right: 0;">
                            <div class="name rms-grid-line ng-binding">
                                Claudia Gelsomino
                            </div>
                            <div class="details rms-grid-line">
                                <!-- ngIf: eventFinisher.gender || eventFinisher.age --><span ng-if="eventFinisher.gender || eventFinisher.age" class="ng-binding ng-scope">W45</span><!-- end ngIf: eventFinisher.gender || eventFinisher.age -->
                                <!-- ngIf: eventFinisher.city && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.stateProvince && eventFinisher.showUsa -->
                                <!-- ngIf: eventFinisher.countryCode && !eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.iaaf --><span ng-if="eventFinisher.iaaf" class="ng-binding ng-scope">ITA</span><!-- end ngIf: eventFinisher.iaaf -->
                                <!-- ngIf: eventFinisher.bib --><span class="left-bordered ng-scope" ng-if="eventFinisher.bib">Bib <span class="num ng-binding">142</span></span><!-- end ngIf: eventFinisher.bib -->
                            </div>
                        </div>
                        <div class="col-xs-8 col-sm-8 col-md-6">
                            <span class="result right-floated-item info-link"><a href="#">Info</a></span>
                            <span class="result right-floated-item long-text">Time<span class="num ng-binding">2:50:56</span></span>
                            <span class="result right-floated-item short-text">Pace<span class="num ng-binding">06:32</span></span>
                            <span class="result right-floated-item mid-text">Place<span class="num ng-binding">306</span></span>
                        </div>
                    </div>
                </div>
                <div ng-show="eventFinisher.ad &amp;&amp; eventFinisher.ad != null" class="grid-rmsad ng-hide">
                    <!-- ngIf: eventFinisher.ad && eventFinisher.ad != null -->
                </div>
            </div><!-- end ngRepeat: eventFinisher in eventFinishers -->

            <button ng-click="nextPage()" ng-hide="layoutScope.infiniteScrollCompleted || finishersLoading || !canShowMore()" class="button-compare">Show More</button>
            <div class="text-load-more ng-hide" ng-hide="canShowMore() || finishersLoading">
                <span>Please use the advanced filter to find more</span>
            </div>

        </div>

        <div class="b-title ng-hide" ng-show="eventFinishers.length == 0 &amp;&amp; !finishersLoading">
            <h3>No Finishers Found</h3>
        </div>

        <div class="b-title ng-hide" ng-show="finishersLoading">
            <h3>Finishers loading...</h3>
        </div>

        <div ng-show="eventFinishers.length <= 2" ng-style="{ 'height' : (eventFinishers.length == 2 ? 50 : (eventFinishers.length == 1 ? 130 : 150)) + 'px'}" style="height: 150px;" class="ng-hide">
        </div>

    </div>
</div></div></div>
                    </div>
                </main>
            </div>
            <footer class="footer">
    <div class="container-fluid footer_mid">

        <div class="footer_desktop_tablet">
            <div class="top-container-footer">
                <img data-original="~/images/nyrr.svg" alt="NYRR" class="footer_logo loaded" src="/images/nyrr.svg">
                <p class="footer_bio">
                    New York Road Runners, whose mission is to help and inspire people through running,
                    serves runners of all ages and abilities through races, community runs, walks, training, virtual products, and other running-related programming.
                    Our free youth programs and events serve kids in New York City’s five boroughs and across the country.
                </p>
                <div class="footer__address_group">
                    <div class="footer__address_name">NYRR <i>RUN</i>CENTER</div>
                    <div class="footer__address">320 West 57th Street <br>New York, NY 10019</div>
                </div>
            </div>

            <div class="footer_aux">
                <div class="row no-gutters">
                    <div class="col-xs-12 col-xl-3 order-xl-3 align-self-center">
                        <div class="media_icon_group">
                            <a target="_blank" href="https://www.facebook.com/NewYorkRoadRunners" class="media_icon media_icon--small ">
                                <svg role="img" aria-label="Facebook" class="icon icon-footer icon--facebook">
                                    <title>Facebook</title>
                                    <use xlink:href="/images/icons.svg#icon--facebook">
                                        <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 28 25" id="icon--facebook" width="100%" height="100%"><title>facebook</title><path fill="currentColor" d="M12 7h3v15h-3z"></path><path fill="currentColor" d="M9 14h9l1-3H9v3zM15 4h4v3h-4z"></path><path fill="currentColor" d="M15 5h1v2h-1zM14 5h1v2h-1z"></path><path fill="currentColor" opacity=".8" d="M13 5h1v1h-1z"></path><path fill="currentColor" d="M13 6h1v1h-1z"></path><path fill="currentColor" opacity=".8" d="M12 6h1v1h-1zM14 4h1v1h-1z"></path><path fill="currentColor" opacity=".7" d="M15 7h1v1h-1z"></path><path fill="currentColor" opacity=".8" d="M15 4h1v1h-1z"></path></svg>
                                    </use>
                                </svg>
                            </a>
                            <a target="_blank" href="https://twitter.com/nyrr" class="media_icon media_icon--small ">
                                <svg role="img" aria-label="Twitter" class="icon icon-footer icon--twitter">
                                    <title>Twitter</title>
                                    <use xlink:href="/images/icons.svg#icon--twitter">
                                        <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 28 25" id="icon--twitter" width="100%" height="100%"><title>twitter</title><path d="M22.734 7.773a7.746 7.746 0 0 1-2.207.6 3.81 3.81 0 0 0 1.69-2.1 7.873 7.873 0 0 1-2.442.925 3.855 3.855 0 0 0-6.647 2.591 3.66 3.66 0 0 0 .1.859 10.985 10.985 0 0 1-7.925-3.955 3.722 3.722 0 0 0-.521 1.903 3.772 3.772 0 0 0 1.712 3.151 3.873 3.873 0 0 1-1.742-.473v.048a3.8 3.8 0 0 0 3.082 3.712 3.899 3.899 0 0 1-1.012.132 3.803 3.803 0 0 1-.722-.064 3.84 3.84 0 0 0 3.59 2.628 7.797 7.797 0 0 1-4.774 1.622A7.357 7.357 0 0 1 4 19.297 10.98 10.98 0 0 0 9.892 21a10.775 10.775 0 0 0 10.933-10.775c0-.163 0-.327-.007-.49a7.744 7.744 0 0 0 1.916-1.962z" fill="currentColor"></path></svg>
                                    </use>
                                </svg>
                            </a>
                            <a target="_blank" href="https://www.instagram.com/nyrr" class="media_icon media_icon--small ">
                                <svg role="img" aria-label="Instagram" class="icon icon-footer icon--instagram">
                                    <title>Instagram</title>
                                    <use xlink:href="/images/icons.svg#icon--instagram">
                                        <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 19 19" id="icon--instagram" width="100%" height="100%"><title>instagram</title><path d="M9.5 1.583c2.578 0 2.884.01 3.902.057a5.343 5.343 0 0 1 1.793.332 2.992 2.992 0 0 1 1.11.722 2.992 2.992 0 0 1 .723 1.11 5.343 5.343 0 0 1 .332 1.794c.047 1.018.057 1.324.057 3.902s-.01 2.884-.057 3.902a5.343 5.343 0 0 1-.332 1.793 3.198 3.198 0 0 1-1.833 1.833 5.343 5.343 0 0 1-1.793.332c-1.018.047-1.323.057-3.902.057s-2.884-.01-3.902-.057a5.343 5.343 0 0 1-1.793-.332 2.992 2.992 0 0 1-1.11-.722 2.992 2.992 0 0 1-.723-1.11 5.343 5.343 0 0 1-.332-1.794c-.047-1.018-.057-1.324-.057-3.902s.01-2.884.057-3.902a5.343 5.343 0 0 1 .332-1.793 2.992 2.992 0 0 1 .722-1.11 2.992 2.992 0 0 1 1.11-.723 5.343 5.343 0 0 1 1.794-.332c1.018-.047 1.324-.057 3.902-.057M9.5 0C6.92 0 6.596.01 5.583.057A6.973 6.973 0 0 0 3.277.5a4.657 4.657 0 0 0-1.683 1.095A4.657 4.657 0 0 0 .5 3.277a6.973 6.973 0 0 0-.442 2.306C.011 6.596 0 6.92 0 9.5s.01 2.904.057 3.917A6.973 6.973 0 0 0 .5 15.723a4.657 4.657 0 0 0 1.095 1.682 4.657 4.657 0 0 0 1.683 1.096 6.973 6.973 0 0 0 2.306.442C6.596 18.989 6.92 19 9.5 19s2.904-.01 3.917-.057a6.973 6.973 0 0 0 2.306-.442 4.858 4.858 0 0 0 2.778-2.778 6.973 6.973 0 0 0 .442-2.306C18.989 12.404 19 12.08 19 9.5s-.01-2.904-.057-3.917a6.973 6.973 0 0 0-.442-2.306 4.657 4.657 0 0 0-1.095-1.682A4.657 4.657 0 0 0 15.723.499a6.973 6.973 0 0 0-2.306-.442C12.404.011 12.08 0 9.5 0z" fill="currentColor"></path><path d="M9.5 4.622A4.878 4.878 0 1 0 14.378 9.5 4.878 4.878 0 0 0 9.5 4.622zm0 8.045A3.167 3.167 0 1 1 12.667 9.5 3.167 3.167 0 0 1 9.5 12.667z" fill="currentColor"></path><circle cx="14.571" cy="4.429" r="1.14" fill="currentColor"></circle></svg>
                                    </use>
                                </svg>
                            </a>
                            <a target="_blank" href="https://www.strava.com/clubs/new-york-road-runners-108605" class="media_icon media_icon--small">
                                <svg role="img" aria-label="Strava" class="icon icon-footer icon--strava">
                                    <title>Strava</title>
                                    <use xlink:href="/images/icons.svg#icon--strava">
                                        <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 19 19" id="icon--strava" width="100%" height="100%"><title>strava</title><path d="M6.1 7.8l2.2 5h3.9L6.1 0 0 12.8h3.9l2.2-5" fill="currentColor"></path><path d="M10.6 22.4l-4.5-9.5h2.8l1.6 3.9 1.6-3.9H15l-4.4 9.5" opacity="0.5"></path><circle cx="14.571" cy="4.429" r="1.14" fill="currentColor"></circle></svg>
                                    </use>
                                </svg>
                            </a>
                        </div>
                    </div>
                    <div class="col-xs-4 col-xl-auto order-xl-1">
                        <div class="footer__aux_title">
                            © New York Road Runners
                        </div>
                    </div>
                    <div class="col-xs order-xl-3">
                        <nav class="footer__aux_nav">
                            <a href="#" class="footer__aux_nav_item ng-binding" ng-click="changeTextContrast()">
                                Increase Text Contrast
                            </a>
                            <a href="https://www.nyrr.org/terms-of-use" class="footer__aux_nav_item">
                                Terms of Use
                            </a>
                            <a href="https://nyrr.org/privacy-policy" class="footer__aux_nav_item">
                                Privacy Policies
                            </a>
                            <a href="mailto:help@nyrr.org" class="footer__aux_nav_item">
                                Contact
                            </a>
                        </nav>
                    </div>
                </div>
            </div>
        </div>

        <div class="footer_mobile container-fluid">
            <div class="row">
                <div class="" style="float:left;">
                    <img data-original="~/images/nyrr.svg" alt="NYRR" class="footer_logo_mobile loaded" src="/images/nyrr.svg">
                </div>

                <p class="footer_bio_mobile">
                    Visit <span style="display:inline"><a href="https://www.nyrr.org" style="color:white"> NYRR.ORG </a></span> for more info
                </p>

            </div>
        </div>

        <div class="footer_mobile_menu">
            <div>
                <img data-original="~/images/nyrr.svg" alt="NYRR" class="footer_logo_mobile loaded" src="/images/nyrr.svg" style="display:inline;">
                <p class="mobile_menu_link">
                    Visit <span style="display:inline;"><a href="https://www.nyrr.org" style="color:white"> NYRR.ORG </a></span> for more info
                </p>
            </div>
            <p class="footer_bio">
                New York Road Runners, whose mission is to help and inspire people through running,
                serves runners of all ages and abilities through races, community runs, walks, training, virtual products, and other running-related programming.
                Our free youth programs and events serve kids in New York City’s five boroughs and across the country.
            </p>
            <div class="footer__address_group">
                <div class="footer__address_name">NYRR RUNCENTER</div>
                <div class="footer__address">320 West 57th Street <br>New York, NY 10019</div>
            </div>
            <div class="media_icon_group" style="padding-top:20px;">
                <a target="_blank" href="https://www.facebook.com/NewYorkRoadRunners" class="media_icon media_icon--small ">
                    <svg role="img" aria-label="Facebook" class="icon icon-footer icon--facebook">
                        <title>Facebook</title>
                        <use xlink:href="/images/icons.svg#icon--facebook">
                            <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 28 25" id="icon--facebook" width="100%" height="100%"><title>facebook</title><path fill="currentColor" d="M12 7h3v15h-3z"></path><path fill="currentColor" d="M9 14h9l1-3H9v3zM15 4h4v3h-4z"></path><path fill="currentColor" d="M15 5h1v2h-1zM14 5h1v2h-1z"></path><path fill="currentColor" opacity=".8" d="M13 5h1v1h-1z"></path><path fill="currentColor" d="M13 6h1v1h-1z"></path><path fill="currentColor" opacity=".8" d="M12 6h1v1h-1zM14 4h1v1h-1z"></path><path fill="currentColor" opacity=".7" d="M15 7h1v1h-1z"></path><path fill="currentColor" opacity=".8" d="M15 4h1v1h-1z"></path></svg>
                        </use>
                    </svg>
                </a>
                <a target="_blank" href="https://twitter.com/nyrr" class="media_icon media_icon--small ">
                    <svg role="img" aria-label="Twitter" class="icon icon-footer icon--twitter">
                        <title>Twitter</title>
                        <use xlink:href="/images/icons.svg#icon--twitter">
                            <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 28 25" id="icon--twitter" width="100%" height="100%"><title>twitter</title><path d="M22.734 7.773a7.746 7.746 0 0 1-2.207.6 3.81 3.81 0 0 0 1.69-2.1 7.873 7.873 0 0 1-2.442.925 3.855 3.855 0 0 0-6.647 2.591 3.66 3.66 0 0 0 .1.859 10.985 10.985 0 0 1-7.925-3.955 3.722 3.722 0 0 0-.521 1.903 3.772 3.772 0 0 0 1.712 3.151 3.873 3.873 0 0 1-1.742-.473v.048a3.8 3.8 0 0 0 3.082 3.712 3.899 3.899 0 0 1-1.012.132 3.803 3.803 0 0 1-.722-.064 3.84 3.84 0 0 0 3.59 2.628 7.797 7.797 0 0 1-4.774 1.622A7.357 7.357 0 0 1 4 19.297 10.98 10.98 0 0 0 9.892 21a10.775 10.775 0 0 0 10.933-10.775c0-.163 0-.327-.007-.49a7.744 7.744 0 0 0 1.916-1.962z" fill="currentColor"></path></svg>
                        </use>
                    </svg>
                </a>
                <a target="_blank" href="https://www.instagram.com/nyrr" class="media_icon media_icon--small ">
                    <svg role="img" aria-label="Instagram" class="icon icon-footer icon--instagram">
                        <title>Instagram</title>
                        <use xlink:href="/images/icons.svg#icon--instagram">
                            <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 19 19" id="icon--instagram" width="100%" height="100%"><title>instagram</title><path d="M9.5 1.583c2.578 0 2.884.01 3.902.057a5.343 5.343 0 0 1 1.793.332 2.992 2.992 0 0 1 1.11.722 2.992 2.992 0 0 1 .723 1.11 5.343 5.343 0 0 1 .332 1.794c.047 1.018.057 1.324.057 3.902s-.01 2.884-.057 3.902a5.343 5.343 0 0 1-.332 1.793 3.198 3.198 0 0 1-1.833 1.833 5.343 5.343 0 0 1-1.793.332c-1.018.047-1.323.057-3.902.057s-2.884-.01-3.902-.057a5.343 5.343 0 0 1-1.793-.332 2.992 2.992 0 0 1-1.11-.722 2.992 2.992 0 0 1-.723-1.11 5.343 5.343 0 0 1-.332-1.794c-.047-1.018-.057-1.324-.057-3.902s.01-2.884.057-3.902a5.343 5.343 0 0 1 .332-1.793 2.992 2.992 0 0 1 .722-1.11 2.992 2.992 0 0 1 1.11-.723 5.343 5.343 0 0 1 1.794-.332c1.018-.047 1.324-.057 3.902-.057M9.5 0C6.92 0 6.596.01 5.583.057A6.973 6.973 0 0 0 3.277.5a4.657 4.657 0 0 0-1.683 1.095A4.657 4.657 0 0 0 .5 3.277a6.973 6.973 0 0 0-.442 2.306C.011 6.596 0 6.92 0 9.5s.01 2.904.057 3.917A6.973 6.973 0 0 0 .5 15.723a4.657 4.657 0 0 0 1.095 1.682 4.657 4.657 0 0 0 1.683 1.096 6.973 6.973 0 0 0 2.306.442C6.596 18.989 6.92 19 9.5 19s2.904-.01 3.917-.057a6.973 6.973 0 0 0 2.306-.442 4.858 4.858 0 0 0 2.778-2.778 6.973 6.973 0 0 0 .442-2.306C18.989 12.404 19 12.08 19 9.5s-.01-2.904-.057-3.917a6.973 6.973 0 0 0-.442-2.306 4.657 4.657 0 0 0-1.095-1.682A4.657 4.657 0 0 0 15.723.499a6.973 6.973 0 0 0-2.306-.442C12.404.011 12.08 0 9.5 0z" fill="currentColor"></path><path d="M9.5 4.622A4.878 4.878 0 1 0 14.378 9.5 4.878 4.878 0 0 0 9.5 4.622zm0 8.045A3.167 3.167 0 1 1 12.667 9.5 3.167 3.167 0 0 1 9.5 12.667z" fill="currentColor"></path><circle cx="14.571" cy="4.429" r="1.14" fill="currentColor"></circle></svg>
                        </use>
                    </svg>
                </a>
                <a target="_blank" href="https://www.strava.com/clubs/new-york-road-runners-108605" class="media_icon media_icon--small ">
                    <svg role="img" aria-label="Instagram" class="icon icon-footer icon--strava">
                        <title>Strava</title>
                        <use xlink:href="/images/icons.svg#icon--strava">
                            <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 19 19" id="icon--strava" width="100%" height="100%"><title>strava</title><path d="M9.5 1.583c2.578 0 2.884.01 3.902.057a5.343 5.343 0 0 1 1.793.332 2.992 2.992 0 0 1 1.11.722 2.992 2.992 0 0 1 .723 1.11 5.343 5.343 0 0 1 .332 1.794c.047 1.018.057 1.324.057 3.902s-.01 2.884-.057 3.902a5.343 5.343 0 0 1-.332 1.793 3.198 3.198 0 0 1-1.833 1.833 5.343 5.343 0 0 1-1.793.332c-1.018.047-1.323.057-3.902.057s-2.884-.01-3.902-.057a5.343 5.343 0 0 1-1.793-.332 2.992 2.992 0 0 1-1.11-.722 2.992 2.992 0 0 1-.723-1.11 5.343 5.343 0 0 1-.332-1.794c-.047-1.018-.057-1.324-.057-3.902s.01-2.884.057-3.902a5.343 5.343 0 0 1 .332-1.793 2.992 2.992 0 0 1 .722-1.11 2.992 2.992 0 0 1 1.11-.723 5.343 5.343 0 0 1 1.794-.332c1.018-.047 1.324-.057 3.902-.057M9.5 0C6.92 0 6.596.01 5.583.057A6.973 6.973 0 0 0 3.277.5a4.657 4.657 0 0 0-1.683 1.095A4.657 4.657 0 0 0 .5 3.277a6.973 6.973 0 0 0-.442 2.306C.011 6.596 0 6.92 0 9.5s.01 2.904.057 3.917A6.973 6.973 0 0 0 .5 15.723a4.657 4.657 0 0 0 1.095 1.682 4.657 4.657 0 0 0 1.683 1.096 6.973 6.973 0 0 0 2.306.442C6.596 18.989 6.92 19 9.5 19s2.904-.01 3.917-.057a6.973 6.973 0 0 0 2.306-.442 4.858 4.858 0 0 0 2.778-2.778 6.973 6.973 0 0 0 .442-2.306C18.989 12.404 19 12.08 19 9.5s-.01-2.904-.057-3.917a6.973 6.973 0 0 0-.442-2.306 4.657 4.657 0 0 0-1.095-1.682A4.657 4.657 0 0 0 15.723.499a6.973 6.973 0 0 0-2.306-.442C12.404.011 12.08 0 9.5 0z" fill="currentColor"></path><path d="M9.5 4.622A4.878 4.878 0 1 0 14.378 9.5 4.878 4.878 0 0 0 9.5 4.622zm0 8.045A3.167 3.167 0 1 1 12.667 9.5 3.167 3.167 0 0 1 9.5 12.667z" fill="currentColor"></path><circle cx="14.571" cy="4.429" r="1.14" fill="currentColor"></circle></svg>
                        </use>
                    </svg>
                </a>
            </div>
            <div class="footer_menu_title">
                © New York Road Runners
            </div>
        </div>
    </div>
</footer>

        </div>
    </div>
    <script type="text/javascript" src="/GetSettings/rms-settings.rjs"></script>



        <script src="/bundles/site.min.js?v=TDU31E3ECmSrdCwtIPpRSliYzUKryTX5CVx-kieUXKQ"></script>


    <script type="text/javascript">
        $(function () {
            var elemWidth, fitCount, varWidth = 0, ctr,
                $menu = $("ul#left-menu-header"), $collectedSet;
            ctr = $menu.children('.tfk-menu-item').length;
            $menu.children('.tfk-menu-item').each(function () {
                varWidth += $(this).outerWidth(true);
            });
            if ($(window).width() >= '980') {
                renderHeaderMenu();
            }

            function renderHeaderMenu() {
                $menu.css('overflow', 'hidden');
                if (varWidth === 0) { // for mobile true
                    $menu.children('.tfk-menu-item').each(function () {
                        varWidth += $(this).outerWidth(true);
                    });
                    if (varWidth === 0) { // for mobile stay zero, not render for mobile
                        return;
                    };
                }
                elemWidth = $menu.width() - 60;
                fitCount = Math.floor((elemWidth / varWidth) * ctr) - 1;

                if (fitCount >= ctr) {
                    $('#moreMenuLinkContainer').css({ "display": "none", "width": "0" });
                } else {
                    $('#moreMenuLinkContainer').css({ "display": "list-item", "width": "auto" });
                }

                $menu.children('.tfk-menu-item').css({ "display": "list-item", "width": "auto" });
                $collectedSet = $menu.children(".tfk-menu-item:gt(" + (fitCount - 1) + ")");

                $("#moreMenuLinkItems").empty().append($collectedSet.find('a').clone().removeClass().addClass('dropdown-item-nyrr'));
                $collectedSet.css({ "display": "none", "width": "0" });
                $menu.css('overflow', 'visible');
            }

            $(window).resize(function () {
                if ($(window).width() >= '980') {
                    renderHeaderMenu();
                    mainMenuCloseMobile();
                }
            });

            $("#button-menu").click(function () {
                if ($('html').hasClass('mobile-nav-is-open')) {
                    mainMenuCloseMobile();
                } else {
                    mainMenuOpenMobile();
                }
            });

            $(".close-menu-after").click(function () {
                mainMenuCloseMobile();
            });
        });

        function mainMenuCloseMobile() {
            $('html').removeClass("mobile-nav-is-open");
            $("main").removeClass("disable-scrolling");
            $("#text-menu").text("Menu");
        }

        function mainMenuOpenMobile() {
            $('html').addClass("mobile-nav-is-open");
            $("main").addClass("disable-scrolling");
            $("#text-menu").text("Close");
        }

    </script>

    <!--
        Version: 1.0.0.0
        Created: 10/16/2023 4:16:37 PM UTC
    -->
        <!-- Go to www.addthis.com/dashboard to customize your tools -->
        <script type="text/javascript" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5983936da604f90b"></script>

<div style="display: none; visibility: hidden;"><script type="text/javascript">for(var e=document.getElementsByTagName("iframe"),x=e.length;x--;)/youtube.com\/embed/.test(e[x].src)&&-1===e[x].src.indexOf("enablejsapi\x3d")&&(e[x].src+=(-1===e[x].src.indexOf("?")?"?":"\x26")+"enablejsapi\x3d1");var gtmYTListeners=[];
function onYouTubeIframeAPIReady(){for(var a=document.getElementsByTagName("iframe"),b=a.length;b--;)/youtube.com\/embed/.test(a[b].src)&&(gtmYTListeners.push(new YT.Player(a[b],{events:{onStateChange:onPlayerStateChange,onError:onPlayerError}})),YT.gtmLastAction="p")}
function onPlayerStateChange(a){a.data==YT.PlayerState.PLAYING&&setTimeout(onPlayerPercent,1E3,a.target);var b=a.target.getVideoData();b=b.video_id+":"+b.title;a.data==YT.PlayerState.PLAYING&&"p"==YT.gtmLastAction&&(dataLayer.push({event:"youtube",action:"play",label:b}),YT.gtmLastAction="");a.data==YT.PlayerState.PAUSED&&(dataLayer.push({event:"youtube",action:"pause",label:b}),YT.gtmLastAction="p")}
function onPlayerError(a){dataLayer.push({event:"youtube",action:"GTM",label:"youtube:"+a.target.src+"-"+a.data})}function onPlayerPercent(a){if(a.getPlayerState()==YT.PlayerState.PLAYING){var b=1.5>=a.getDuration()-a.getCurrentTime()?1:(Math.floor(a.getCurrentTime()/a.getDuration()*4)/4).toFixed(2);if(!a.lastP||b>a.lastP){var c=a.getVideoData();c=c.video_id+":"+c.title;a.lastP=b;dataLayer.push({event:"youtube",action:100*b+"%",label:c})}1!=a.lastP&&setTimeout(onPlayerPercent,1E3,a)}}
var j=document.createElement("script"),f=document.getElementsByTagName("script")[0];j.src="//www.youtube.com/iframe_api";j.async=!0;f.parentNode.insertBefore(j,f);</script></div></body></html>"""

# %%
soup = BeautifulSoup(raw_html2014, 'html.parser')

# %%
pretty_soup = soup.prettify()

# %%
name_nodes = soup.select('.name')

# %%
len(name_nodes)
# Out:
# 306

# %%
name_node = name_nodes[0]
name_node
# Out:
# <div class="name rms-grid-line ng-binding">
#                                 Wilson Kipsang
#                             </div>

# %%
name_node.get_text(strip=True)
# Out:
# 'Wilson Kipsang'

# %%
def get_name(name_node):
  return name_node.get_text(strip=True)

# %%
list_all_namedivs = []
for name_node in name_nodes:
  list_all_namedivs.append(get_name(name_node))

# %%
index_to_remove = list_all_namedivs.index('TCS New York City Marathon 2021')

# %%
list_all_namedivs = list_all_namedivs[index_to_remove + 1:]

# %%
country_nodes = soup.select('[ng-if="eventFinisher.iaaf"]')

# %%
def get_country(country_node):
  return country_node.get_text()

# %%
gender_age_nodes = soup.select('[ng-if="eventFinisher.gender || eventFinisher.age"]')

# %%
def get_gender(gender_age_node):
  return gender_age_node.get_text()[0]

def get_age(gender_age_node):
  return gender_age_node.get_text()[1:]

# %%
place_nodes = soup.select('span.result.right-floated-item.mid-text span.num.ng-binding')

# %%
def get_place(place_node):
  return place_node.get_text()

# %%
time_nodes = soup.select('span.result.right-floated-item.long-text span.num.ng-binding')

# %%
def get_time(time_node):
  return time_node.get_text()

# %%
bib_nodes = soup.select('span.left-bordered.ng-scope[ng-if="eventFinisher.bib"] span.num.ng-binding')

# %%
def get_bib(bib_node):
  return bib_node.get_text()

# %%
list_all_countries = []
for country_node in country_nodes:
  list_all_countries.append(get_country(country_node))

list_all_gender = []
list_all_ages = []
for gender_age_node in gender_age_nodes:
  list_all_gender.append(get_gender(gender_age_node))
  list_all_ages.append(get_age(gender_age_node))

list_overall_places = []
for place_node in place_nodes:
  list_overall_places.append(get_place(place_node))

list_times = []
for time_node in time_nodes:
  list_times.append(get_time(time_node))

list_bibs = []
for bib_node in bib_nodes:
  list_bibs.append(get_bib(bib_node))

# %%
assert len(list_all_namedivs) == len(list_all_gender) == len(list_all_ages) == len(list_all_countries) == len(list_bibs) == len(list_overall_places) == len(list_times)

# %%
data = {
    'Name': list_all_namedivs,
    'Gender': list_all_gender,
    'Age': list_all_ages,
    'Country': list_all_countries,
    'BIB': list_bibs,
    'Overall Place': list_overall_places,
    'Time': list_times
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                     Name Gender Age Country   BIB Overall Place     Time
# 0         Wilson Kipsang      M  32     KEN     2             1  2:10:59
# 1    Lelisa Desisa Benti      M  24     ETH     4             2  2:11:06
# 2      Gebre Gebremariam      M  30     ETH     7             3  2:12:13
# 3         Meb Keflezighi      M  39     USA     5             4  2:13:18
# 4      Stephen Kiprotich      M  25     UGA    11             5  2:13:25
# ..                   ...    ...  ..     ...   ...           ...      ...
# 301       Linus Eriksson      M  40     SWE  1519           302  2:50:44
# 302       Adolfo Munguia      M  30     MEX   719           303  2:50:52
# 303      Roberto Epifani      M  21     ITA  3878           304  2:50:54
# 304     Benjamin Shields      M  22     USA  1501           305  2:50:54
# 305    Claudia Gelsomino      W  45     ITA   142           306  2:50:56
#
# [306 rows x 7 columns]

# %%
df.to_csv('NY_Marathon2014.csv', index=False)
