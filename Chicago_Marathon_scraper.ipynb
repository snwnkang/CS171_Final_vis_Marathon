# %% [markdown]
# <a href="https://colab.research.google.com/github/snwnkang/CS171_Final_vis_Marathon/blob/main/Chicago_Marathon_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from IPython.display import HTML
import html

# %%
year = "2019"
url = "https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/chicago_data/gendercsv/2019gender.csv"

# %%
raw_html = """<html><head><style>body {transition: opacity ease-in 0.2s; }
body[unresolved] {opacity: 0; display: block; overflow: hidden; position: relative; }
</style>
<title>Bank of America Chicago Marathon</title>
<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
<meta name="apple-mobile-web-app-status-bar-style" content="black">
<link rel="apple-touch-icon" href="//results-static.mikatiming.com/events/chicago/../../stages/blue/images/apple-touch-icon.png">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/css/bootstrap.css">
<link rel="stylesheet" href="//results-static.mikatiming.com/stages/blue/lib/static/styles.build/responsive_2016/style.css">
<link href="/2022/?content=css_event&amp;theme=responsive&amp;event=events_chicago&amp;style=responsive_2016" rel="stylesheet" type="text/css">
<link rel="shortcut icon" href="//results-static.mikatiming.com/stages/blue/images/favicon.ico">
<script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-X7BG41Z7K0&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" src="//assets.mikatiming.com/lib/jquery/1.11.3/jquery.min.js"></script>
<script src="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/js/bootstrap.min.js"></script>
<script type="text/javascript" src="/2022/?content=ajax2&amp;client=js"></script>
<script type="text/javascript"> var require = {"baseUrl":"\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static","deps":["\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static\/webcomponentsjs-0.7.0\/webcomponents-lite.js"],"paths":{"d3":"d3-3.4.13\/d3","c3":"c3-0.4.8\/c3","moment":"moment.js-2.9.0\/moment-with-locales.min","GDouglasPeuker":"GDouglasPeuker","Mika":"Mika.build","async":"require.js-plugins-1.0.3\/async","combokeys":"combokeys-2.3.0\/dist\/combokeys","videojs":"..\/..\/node_modules\/video.js\/dist\/video.min","hls2":"videojs5-hlsjs-source-handler\/dist\/videojs5-hlsjs-source-handler","nouislider":"noUiSlider-9.2.0\/nouislider.min","screenfull":"screenfull.js-4.0.0\/screenfull","lodashIsEqual":"lodash\/isEqual","Mika\/Cookie":"Mika.build\/Cookie.js?ff716e5556","Mika\/Dialog":"Mika.build\/Dialog.js?c4ce14ed92","Mika\/Environment":"Mika.build\/Environment.js?c29942fcfd","Mika\/FavoriteColorMapper":"Mika.build\/FavoriteColorMapper.js?c9630670ac","Mika\/ImageErrorHandler":"Mika.build\/ImageErrorHandler.js?ee9286242b","Mika\/ImageViewer":"Mika.build\/ImageViewer.js?c06c87b4c1","Mika\/Logger":"Mika.build\/Logger.js?e1107568f4","Mika\/Map\/FavoriteBar":"Mika.build\/Map\/FavoriteBar.js?3ea7f5c014","Mika\/Map\/LatLng":"Mika.build\/Map\/LatLng.js?52354fc88e","Mika\/Map\/LatLngBounds":"Mika.build\/Map\/LatLngBounds.js?1dfacf85e0","Mika\/Map\/Map":"Mika.build\/Map\/Map.js?4f877dc9d8","Mika\/Map\/Marker\/
Plugins\/strings.js?be3574f716","Mika\/Results\/Requester":"Mika.build\/Results\/Requester.js?e08e2c3a1b","Mika\/SearchProvider":"Mika.build\/SearchProvider.js?119e90ba1f","Mika\/Sharer\/Networks\/base":"Mika.build\/Sharer\/Networks\/base.js?5e512e5688","Mika\/Sharer\/Networks\/facebook":"Mika.build\/Sharer\/Networks\/facebook.js?0d6fa0375a","Mika\/Sharer\/Networks\/googleplus":"Mika.build\/Sharer\/Networks\/googleplus.js?3beb6aba2b","Mika\/Sharer\/Networks\/twitter":"Mika.build\/Sharer\/Networks\/twitter.js?aa24183cf7","Mika\/Sharer\/Networks\/whatsapp":"Mika.build\/Sharer\/Networks\/whatsapp.js?4033c2aa8c","Mika\/Sharer\/Networks\/xing":"Mika.build\/Sharer\/Networks\/xing.js?39187fc831","Mika\/Sharer\/Sharer":"Mika.build\/Sharer\/Sharer.js?c7dcac3a10","Mika\/Ticker":"Mika.build\/Ticker.js?141ff57f2e","Mika\/Timer":"Mika.build\/Timer.js?260b39f15c","Mika\/Tools":"Mika.build\/Tools.js?370394a8e7","Mika\/Tracker":"Mika.build\/Tracker.js?e68c5b2784","Mika\/Uploader":"Mika.build\/Uploader.js?68ac256df1","Mika\/VideoViewer":"Mika.build\/VideoViewer.js?7dbe05ea75"},"config":{"Mika\/Mika":{"debug":false,"display_errors":true,"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","language":"EN_CAP","global_event_id":"events_chicago","static_uri":"\/\/results-static.mikatiming.com\/stages\/blue"},"Mika\/Logger":{"debug":false},"Mika\/Quicksearch":{"pid":null,"not_found_string":"Sorry, no results found!"},"Mika\/ImageViewer":{"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","sharerActive":true},"Mika\/VideoViewer":{"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","modalWidth":null},"Mika\/Map\/Map":{"mapProvider":"google"},"Mika\/Sharer\/Sharer":{"pathSharerIcons":"\/\/assets.mikatiming.com\/img\/mt\/sharer\/","buttonSize":"xs"},"Mika\/Map\/Marker\/Person":[]}}</script>
<script type="text/javascript" src="//results-static.mikatiming.com/stages/blue/lib/static/require.js-2.3.6/require.min.js"></script>
<script type="text/javascript" src="//results-static.mikatiming.com/stages/blue/lib/static/Emitter.js"></script>
<meta name="apple-mobile-web-app-capable" content="yes">
<script type="text/javascript">
        // create helper function to handle the image loading errors
        var mikaImageErrorHandler = function (image) {
            require(["Mika/ImageErrorHandler"], function (ImageErrorHandler) {
                var que = ImageErrorHandler.queueImageGeneration(image.dataset.generateSrcUrl, image.dataset.imageHash, image.src);
                setTimeout(function () {
                     ImageErrorHandler.statusMissingImages(que);
                }, 1100);
            })
        };
        require(["Mika/Mika", "require"], function (Mika, require) {
            new Mika();
            require(["Mika/Dialog", "Mika/Popover", "Mika/ImageViewer", "Mika/Timer"]);
        });
    </script>
<script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="//results-static.mikatiming.com/stages/blue/lib/static/webcomponentsjs-0.7.0/webcomponents-lite.js" src="//results-static.mikatiming.com/stages/blue/lib/static/webcomponentsjs-0.7.0/webcomponents-lite.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Mika" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Mika.js?71f1195427"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Tracker" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Tracker.js?e68c5b2784"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Sharer/Sharer" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Sharer/Sharer.js?c7dcac3a10"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Map/LatLng" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Map/LatLng.js?52354fc88e"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Quicksearch" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Quicksearch.js?c0b9e8b89a"></script></head>
<body class="pid-search content-list view-public branch-production site-events_chicago event-MAR_999999107FA31100000000C9">

<header class="hidden-xs">
  <div class="container">
<div class="logo row">
<a href="/2022/?lang=EN_CAP">
<img class="logo-screen" src="//results-static.mikatiming.com/events/chicago/../chicago/styles/responsive_2016/logo.png" alt="">
</a>
<ul class="header-brand">
<li>Race Results</li>
<li>Official Race Results</li>
<li>1996-2021</li>
</ul>
</div>
</div>
</header>
<nav class="navbar navbar-default navbar-top navbar-fixed-top">
  <div class="container">
    <div class="navbar-header">
    <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#navbar" aria-expanded="false">
        <span class="sr-only">Toggle navigation</span>
        <span class="icon-bar"></span>
        <span class="icon-bar"></span>
        <span class="icon-bar"></span>
      </button>
 <a class="navbar-brand" href="/2022/?lang=EN_CAP">
<img class="hidden-sm hidden-md hidden-lg" alt="" src="//results-static.mikatiming.com/events/chicago/../chicago/styles/responsive_2016/logo.png">
 <span class="hidden-xs">Bank of America Chicago Marathon</span>
 </a>
    </div>
 <div id="navbar" class="navbar-collapse collapse">
<ul class="nav navbar-nav hidden-sm hidden-md hidden-lg">
<li class="active"><a class="nav-pid-start" href="/2022/?event=MAR_999999107FA31100000000C9&amp;event_main_group=2019&amp;lang=EN_CAP&amp;num_results=500&amp;pid=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex"><span>Results</span></a></li>
<li><a class="nav-pid-leaderboard" href="/2022/?lang=EN_CAP&amp;pid=leaderboard"><span>Leaderboard</span></a></li>
</ul>

<ul class="nav navbar-nav navbar-right">
<li class="">
<a href="https://results.chicagomarathon.com/2023/" class="" role="button">Results 2023</a>
</li>
<li class="">
<a href="https://www.chicagomarathon.com/" class="" role="button">Back to Homepage</a>
</li>
</ul>
</div>
</div>
</nav>
<!-- header end -->
<!-- main start -->
<script async="" src="https://www.googletagmanager.com/gtag/js"></script>

        <script>

         var mt_tracker = {};

         window.dataLayer = window.dataLayer || [];
            function gtag(){dataLayer.push(arguments);}
            gtag('js', new Date());

            require(['Mika/Tracker'], function(tracker) {
                tracker.setGtagConfig(["G-X7BG41Z7K0"], {"page_title":"search","send_page_view":false,"meeting_id":false,"meeting_name":"Bank of America Chicago Marathon","meeting_year":"2022","results_view":"public"});
                tracker.track('page_view');
                mt_tracker = tracker;
            });

    </script>
          <section class="section-nav container-fluid"><nav class="navbar navbar-default row navbar-main hidden-xs">  <div class="container"><ul class="nav navbar-nav">
            <script type="text/javascript">
                jQuery("#navbar-main-dropdown").dropdown();
                var menuResizeHandler = function () {
                    var container   = jQuery(".navbar-main .container");
                    var navbar   = jQuery(".navbar-main .nav");
                    var currentWidth = 0;
                    var dropdown = navbar.find("li.dropdown");
                    // quickly show it and get the width
                    dropdown.removeClass("hide");
                    var dropdownWidth = dropdown.width();
                    var quicksearchWidth = jQuery(".navbar-main .quicksearch-form").width();
                    currentWidth += quicksearchWidth;
                    var menuEntries = navbar.find("li:not(.dropdown)");
                    menuEntries.each(function (i) {
                        navbar.append(this);
                    });
                    navbar.append(dropdown);
                    dropdown.addClass("hide").removeClass("active");

                    var maxWidth = container.width();
                    menuEntries.each(function (i) {
                        currentWidth += jQuery(this).width();

                        var next = false;
                        if (typeof menuEntries[i+1] !== "undefined") {
                            next = menuEntries[i+1];
                        }
                        var currentIsAboveMaxWidth = (currentWidth > maxWidth);
                        var currentIsNotLastAndPlusDropdownIsAboveMaxWidth = ((currentWidth + dropdownWidth > maxWidth) && i != menuEntries.length-1);
                        var currentPlusNextIsAboveMaxWidth = (next && currentWidth + jQuery(next).width() > maxWidth);
                        //console.log("%s: width: %s, is above: %s, notlast: %s, plusnext: %s", jQuery(this).text(), currentWidth, currentIsAboveMaxWidth, currentIsNotLastAndPlusDropdownIsAboveMaxWidth, currentPlusNextIsAboveMaxWidth)
                        if(currentIsAboveMaxWidth || currentIsNotLastAndPlusDropdownIsAboveMaxWidth || currentPlusNextIsAboveMaxWidth) {
                            jQuery(this).find("a").popover("destroy");
                            dropdown.find("ul").append(this);
                            dropdown.removeClass("hide");
                            if (jQuery(this).hasClass("active")) {
                                dropdown.addClass("active");
                            }
                        }
                    });

                };
                jQuery(document).on("ready", menuResizeHandler);
                var lastWidth = 0;
                jQuery(window).on("resize", function () {
                    lastWidth = window.innerWidth;
                    setTimeout(function () {
                        if (lastWidth == window.innerWidth) {
                            menuResizeHandler();
                        }
                    }, 100);
                });
            </script>
         <li class="active nav-pid-start"><a href="/2022/?lang=EN_CAP&amp;pid=start&amp;pidp=start"><span>Results</span></a></li><li class="nav-pid-leaderboard"><a href="/2022/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=leaderboard"><span>Leaderboard</span></a></li><li class="dropdown hide">
                <a href="javascript:void(0);" class="dropdown-toggle" id="navbar-main-dropdown" data-toggle="dropdown" aria-haspopup="true" aria-expanded="true">
                    More
                    <span class="caret"></span>
                </a>
                <ul class="dropdown-menu" aria-labelledby="navbar-main-dropdown"></ul></li></ul>
</div>
</nav><!-- menu end -->
</section>
<section class="section-main">
<div class="container" id="main-content">
<div class="row">
<div class="cbox-main pid-search col-xs-12" id="cbox-main">
<!-- cbox include start -->


<div class="row">
<div class="col-xs-10">
<h2> Results: 2019 / Marathon</h2>
</div>
</div>

<ul class="row-xs list-group list-info">
<li class="list-group-item">
45867 Results | Official Results
</li>
</ul>
<div class="col-sm-12 row-xs">
<ul class="list-group list-group-multicolumn">
<li class="  list-group row list-group-item  list-group-header ">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs" style="width: 40px">Place Overall</div>
  <div class=" list-field type-place place-primary" style="width: 40px">Place Gender</div>
  <div class=" list-field type-fullname">Name (CTZ)</div>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-
div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:04</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">478</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">423</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022ADCB&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Turner, Michael (GBR)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>1110</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>50-54</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:04</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">479</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">424</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA3120000237667&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Jones, Sumner (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>1201</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>19 and under</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:05</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">480</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">425</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022B322&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Nielsen, Rene (DEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>3031</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:05</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">481</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">426</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000023760B&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Noguchi, Daisuke (JPN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>1027</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:06</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">482</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">427</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022B338&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Oueslati, Mohamed (FRA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>3056</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:06</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">483</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">56</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022AB91&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Bauer, Caroline (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>373</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:07</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">484</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">428</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022C5FF&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Ward, Chris (GBR)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>7066</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:08</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">485</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">429</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022C953&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Kolarcik, Marek (SVK)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>6033</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:09</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">486</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">430</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022B914&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Tena Solis, Jose (MEX)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>5011</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:09</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">487</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">431</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022C659&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Commons, Lewis (IRL)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>7093</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:09</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">488</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">432</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022BAF8&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Goshorn, Heath (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>8437</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>20-24</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:10</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">489</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">433</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA3120000237504&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Kelly, Christopher (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>13062</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:10</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">490</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">434</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022B315&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Murillo, Jorge Esteban (COL)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>3016</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:11</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">491</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">435</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022D964&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Baldwin, Christopher (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>17158</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:12</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">492</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">436</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022BE9F&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Kostyk, Piotr (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>9051</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:14</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">493</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">437</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022B341&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Muzelle, Charles (FRA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>3066</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:14</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">494</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">438</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022C5F3&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Crawford, George (GBR)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>7053</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:16</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">495</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">439</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022BDF5&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Arpin, Brett (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>9002</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:16</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">496</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">440</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022BEA6&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Maddocks, Jordan (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>9061</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:17</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">497</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">441</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022CBD1&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Rielley, Jeremy (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>14121</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:18</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">498</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">57</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022AC1B&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Woodruff, Julie (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>694</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:18</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">499</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">442</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022DC88&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Sullivan, Richard (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>19120</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:20</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">500</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">443</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA312000022D0D4&amp;lang=EN&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA31100000000C9">Stroupe, David (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>13087</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:44:20</div>
  </div>
</div>
</div>
</li>
</ul>
</div>
<div class="row">
<div class="col-xs-8 col-sm-9 col-md-6">
<div class="btn-toolbar list-actions" role="toolbar" aria-label="">
<div class="btn-group" role="group">
<a class="btn btn-default" href="?pid=start&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">Back / New Search</a>
<a class="btn btn-default hidden-xs" href="?event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">Reload</a>
<a class="btn btn-default hidden-xs" href="#" onclick="open_print('?print=1&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex');">Print</a>
</div>
</div>
</div>
<div class="col-xs-4 col-sm-3 col-md-6">
<div class="pull-right pages">
<ul class="pagination"><li class="hidden-xs hidden-sm active"><a href="?page=1&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">1</a></li><li class="hidden-xs hidden-sm"><a href="?page=2&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">2</a></li><li class="hidden-xs hidden-sm"><a href="?page=3&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">3</a></li><li class="disabled"><a href="#" aria-label="" class="hidden-xs hidden-sm"><span aria-hidden="true">...</span></a></li><li class="hidden-xs hidden-sm"><a href="?page=92&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">92</a></li><li class="pages-nav-button"><a href="?page=2&amp;event=MAR_999999107FA31100000000C9&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">&gt;</a></li></ul>
</div>
</div>
</div>
<!-- cbox include end -->
</div>


</div><!-- row -->
</div><!-- container main-content -->
</section><!-- section-main -->
<!-- main end -->

<!-- footer start -->
  <footer>  <div class="container"><div class="row"><div class="footer-box legal-footer" id="pid-search">

        <div class="col-xs-12">
        <a class="pull-right" href="https://www.mikatiming.com/">mika:timing GmbH © 2023</a> <a href="https://q.r.mikatiming.com/results-legal/en/">Legal Notice</a> | <a href="https://q.r.mikatiming.com/results-privacy-statement/en/">Privacy Policy</a>
        </div>

</div>

</div><!-- row end -->
          </div><!-- container end -->
    </footer><!-- footer section end --><div class="popup-info" style="display:none;" id="popup-info"></div>
<div class="popup" style="display:none;" id="popup"></div>
<div id="cconsent-overlay" style="display:none;"></div>




<input class="hidden" id="identified_1" autocomplete="off" name="537d0120-dc74-2210-abda-19c711a87023" data-last-search-value=""><ul class="dropdown-menu quicksearch-results" style="z-index: 2001;"></ul></body></html>"""

# %%
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
name_nodes = soup.select('.list-field.type-fullname')

# %%
name_nodes = name_nodes[1:]

# %%
name_nodes[0].get_text(strip=True)
# Out:
# 'Cherono, Lawrence (KEN)'

# %%
def get_name(name_node):
  text = name_node.get_text()
  name = text[:text.find("(")].strip()
  return name

def get_country(name_node):
  country_text = name_node.get_text()
  country_item = country_text[country_text.find("(") + 1 : country_text.find(")")]
  return country_item

# %%
list_all_names = []
list_countries = []
for name_node in name_nodes:
  list_all_names.append(get_name(name_node))
  list_countries.append(get_country(name_node))

# %%
overall_nodes = soup.select('.list-field.type-place.place-secondary.hidden-xs.numeric')

# %%
def get_overall(overall_node):
  return overall_node.get_text()

# %%
bib_nodes = soup.select('.list-field.type-field')

# %%
bib_nodes = bib_nodes[1:]

# %%
def get_bib(bib_node):
  return bib_node.get_text()

# %%
time_nodes = soup.select('.list-field.type-time:contains("Finish")')
# Out:
# /usr/local/lib/python3.10/dist-packages/soupsieve/css_parser.py:856: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028

# %%
time_nodes = time_nodes[1:]

# %%
time_node = time_nodes[0].get_text()

# %%
time_node.split('Finish')[-1].strip()
# Out:
# '02:05:45'

# %%
def get_time(time_node):
  return time_node.get_text().split('Finish')[-1].strip()

# %%
division_nodes = soup.select('.list-field.type-age_class')

# %%
def get_division(division_node):
  return division_node.get_text()

# %%
list_overall = []
for overall_node in overall_nodes:
  list_overall.append(get_overall(overall_node))

list_bib = []
for bib_node in bib_nodes:
  list_bib.append(get_bib(bib_node))

list_times = []
for time_node in time_nodes:
  list_times.append(get_time(time_node))

list_divisions = []
for division_node in division_nodes:
  list_divisions.append(get_division(division_node))

# %%
list_divisions = list_divisions[1:]

# %%
data = {
    'Name': list_all_names,
    'Division': list_divisions,
    'Country': list_countries,
    'BIB': list_bib,
    'Overall Place': list_overall,
    'Time': list_times
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                   Name       Division Country       BIB Overall Place  \
# 0    Cherono, Lawrence  Division30-34     KEN      BIB4             1
# 1       Debela, Dejene  Division20-24     ETH     BIB38             2
# 2       Mengstu, Asefa  Division30-34     ETH      BIB5             3
# 3        Karoki, Bedan  Division25-29     KEN      BIB9             4
# 4         Abdi, Bashir  Division30-34     BEL     BIB10             5
# ..                 ...            ...     ...       ...           ...
# 495   Maddocks, Jordan  Division30-34     USA   BIB9061           496
# 496    Rielley, Jeremy  Division30-34     USA  BIB14121           497
# 497    Woodruff, Julie  Division30-34     USA    BIB694           498
# 498  Sullivan, Richard  Division40-44     USA  BIB19120           499
# 499     Stroupe, David  Division35-39     USA  BIB13087           500
#
#          Time
# 0    02:05:45
# 1    02:05:46
# 2    02:05:48
# 3    02:05:53
# 4    02:06:14
# ..        ...
# 495  02:44:17
# ...

# %%
# base_url = 'https://results.chicagomarathon.com/2022/'

# runner_links = [link['href'] for link in soup.select('.type-fullname a') if link.has_attr('href')]

# def get_runner_gender(detail_url):
#     full_url = base_url + detail_url
#     response = requests.get(full_url)
#     detail_soup = BeautifulSoup(response.content, 'html.parser')
#     gender_element = detail_soup.select_one('td.f-sex.last')
#     return gender_element.get_text().strip() if gender_element else None

# def scrape_runner_genders(runner_links):
#     genders = []
#     for link in runner_links:
#         gender = get_runner_gender(link)
#         genders.append(gender)
#     return genders

# genders_list = scrape_runner_genders(runner_links)
# print(genders_list)

# %%
# len(genders_list)

# %%
# df['Gender'] = genders_list

# %%
# df.to_csv('Chicago_Marathon2023.csv', index=False)

# %%
# chicago2023 = pd.read_csv('https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/chicago_data/Chicago_Marathon2023.csv')

# %%
df['Division'] = df['Division'].str.replace('Division', '')

# %%
df
# Out:
#                   Name Division Country       BIB Overall Place      Time
# 0    Cherono, Lawrence    30-34     KEN      BIB4             1  02:05:45
# 1       Debela, Dejene    20-24     ETH     BIB38             2  02:05:46
# 2       Mengstu, Asefa    30-34     ETH      BIB5             3  02:05:48
# 3        Karoki, Bedan    25-29     KEN      BIB9             4  02:05:53
# 4         Abdi, Bashir    30-34     BEL     BIB10             5  02:06:14
# ..                 ...      ...     ...       ...           ...       ...
# 495   Maddocks, Jordan    30-34     USA   BIB9061           496  02:44:17
# 496    Rielley, Jeremy    30-34     USA  BIB14121           497  02:44:18
# 497    Woodruff, Julie    30-34     USA    BIB694           498  02:44:18
# 498  Sullivan, Richard    40-44     USA  BIB19120           499  02:44:20
# 499     Stroupe, David    35-39     USA  BIB13087           500  02:44:20
#
# [500 rows x 6 columns]

# %%
# df['Gender'] = df['Gender'].str.replace('Male', 'M')
# df['Gender'] = df['Gender'].str.replace('Female', 'F')
# df['Gender'] = df['Gender'].str.replace('Non-binary', 'NB')

# %%
df['BIB'] = df['BIB'].str.replace('BIB', '')

# %%
df
# Out:
#                   Name Division Country    BIB Overall Place      Time
# 0    Cherono, Lawrence    30-34     KEN      4             1  02:05:45
# 1       Debela, Dejene    20-24     ETH     38             2  02:05:46
# 2       Mengstu, Asefa    30-34     ETH      5             3  02:05:48
# 3        Karoki, Bedan    25-29     KEN      9             4  02:05:53
# 4         Abdi, Bashir    30-34     BEL     10             5  02:06:14
# ..                 ...      ...     ...    ...           ...       ...
# 495   Maddocks, Jordan    30-34     USA   9061           496  02:44:17
# 496    Rielley, Jeremy    30-34     USA  14121           497  02:44:18
# 497    Woodruff, Julie    30-34     USA    694           498  02:44:18
# 498  Sullivan, Richard    40-44     USA  19120           499  02:44:20
# 499     Stroupe, David    35-39     USA  13087           500  02:44:20
#
# [500 rows x 6 columns]

# %%
df['Year'] = year

# %%
df
# Out:
#                   Name Division Country    BIB Overall Place      Time  Year
# 0    Cherono, Lawrence    30-34     KEN      4             1  02:05:45  2019
# 1       Debela, Dejene    20-24     ETH     38             2  02:05:46  2019
# 2       Mengstu, Asefa    30-34     ETH      5             3  02:05:48  2019
# 3        Karoki, Bedan    25-29     KEN      9             4  02:05:53  2019
# 4         Abdi, Bashir    30-34     BEL     10             5  02:06:14  2019
# ..                 ...      ...     ...    ...           ...       ...   ...
# 495   Maddocks, Jordan    30-34     USA   9061           496  02:44:17  2019
# 496    Rielley, Jeremy    30-34     USA  14121           497  02:44:18  2019
# 497    Woodruff, Julie    30-34     USA    694           498  02:44:18  2019
# 498  Sullivan, Richard    40-44     USA  19120           499  02:44:20  2019
# 499     Stroupe, David    35-39     USA  13087           500  02:44:20  2019
#
# [500 rows x 7 columns]

# %%
def time_to_seconds(time_str):
    try:
        return pd.to_timedelta(time_str).total_seconds()
    except ValueError:
        return time_str.hour * 3600 + time_str.minute * 60 + time_str.second

# %%
df['seconds'] = df['Time'].apply(time_to_seconds)
df
# Out:
#                   Name Division Country    BIB Overall Place      Time  Year  \
# 0    Cherono, Lawrence    30-34     KEN      4             1  02:05:45  2019
# 1       Debela, Dejene    20-24     ETH     38             2  02:05:46  2019
# 2       Mengstu, Asefa    30-34     ETH      5             3  02:05:48  2019
# 3        Karoki, Bedan    25-29     KEN      9             4  02:05:53  2019
# 4         Abdi, Bashir    30-34     BEL     10             5  02:06:14  2019
# ..                 ...      ...     ...    ...           ...       ...   ...
# 495   Maddocks, Jordan    30-34     USA   9061           496  02:44:17  2019
# 496    Rielley, Jeremy    30-34     USA  14121           497  02:44:18  2019
# 497    Woodruff, Julie    30-34     USA    694           498  02:44:18  2019
# 498  Sullivan, Richard    40-44     USA  19120           499  02:44:20  2019
# 499     Stroupe, David    35-39     USA  13087           500  02:44:20  2019
#
#      seconds
# 0     7545.0
# 1     7546.0
# ...

# %%
df[['Last Name', 'First Name']] = df['Name'].str.split(', ', expand=True)
df.drop('Name', axis=1, inplace=True)
df
# Out:
#     Division Country    BIB Overall Place      Time  Year  seconds Last Name  \
# 0      30-34     KEN      4             1  02:05:45  2019   7545.0   Cherono
# 1      20-24     ETH     38             2  02:05:46  2019   7546.0    Debela
# 2      30-34     ETH      5             3  02:05:48  2019   7548.0   Mengstu
# 3      25-29     KEN      9             4  02:05:53  2019   7553.0    Karoki
# 4      30-34     BEL     10             5  02:06:14  2019   7574.0      Abdi
# ..       ...     ...    ...           ...       ...   ...      ...       ...
# 495    30-34     USA   9061           496  02:44:17  2019   9857.0  Maddocks
# 496    30-34     USA  14121           497  02:44:18  2019   9858.0   Rielley
# 497    30-34     USA    694           498  02:44:18  2019   9858.0  Woodruff
# 498    40-44     USA  19120           499  02:44:20  2019   9860.0  Sullivan
# 499    35-39     USA  13087           500  02:44:20  2019   9860.0   Stroupe
#
#     First Name
# 0     Lawrence
# ...

# %%
column_order = ['Last Name', 'First Name', 'Division', 'Country', 'BIB', 'Overall Place', 'Time', 'seconds', 'Year']
df = df[column_order]

df.head()
# Out:
#   Last Name First Name Division Country BIB Overall Place      Time  seconds  \
# 0   Cherono   Lawrence    30-34     KEN   4             1  02:05:45   7545.0
# 1    Debela     Dejene    20-24     ETH  38             2  02:05:46   7546.0
# 2   Mengstu      Asefa    30-34     ETH   5             3  02:05:48   7548.0
# 3    Karoki      Bedan    25-29     KEN   9             4  02:05:53   7553.0
# 4      Abdi     Bashir    30-34     BEL  10             5  02:06:14   7574.0
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
df
# Out:
#     Last Name First Name Division Country    BIB Overall Place      Time  \
# 0     Cherono   Lawrence    30-34     KEN      4             1  02:05:45
# 1      Debela     Dejene    20-24     ETH     38             2  02:05:46
# 2     Mengstu      Asefa    30-34     ETH      5             3  02:05:48
# 3      Karoki      Bedan    25-29     KEN      9             4  02:05:53
# 4        Abdi     Bashir    30-34     BEL     10             5  02:06:14
# ..        ...        ...      ...     ...    ...           ...       ...
# 495  Maddocks     Jordan    30-34     USA   9061           496  02:44:17
# 496   Rielley     Jeremy    30-34     USA  14121           497  02:44:18
# 497  Woodruff      Julie    30-34     USA    694           498  02:44:18
# 498  Sullivan    Richard    40-44     USA  19120           499  02:44:20
# 499   Stroupe      David    35-39     USA  13087           500  02:44:20
#
#      seconds  Year
# 0     7545.0  2019
# 1     7546.0  2019
# 2     7548.0  2019
# ...

# %%
gender_csv = pd.read_csv(url, header=None)
gender_csv.columns = ['Division']
gender_csv
# Out:
#     Division
# 0     M30-34
# 1     M20-24
# 2     M30-34
# 3     M25-29
# 4     M30-34
# ..       ...
# 295   M30-34
# 296   M45-49
# 297   M40-44
# 298   M45-49
# 299   M35-39
#
# [300 rows x 1 columns]

# %%
gender_csv['Gender'] = gender_csv['Division'].str[0]
gender_csv
# Out:
#     Division Gender
# 0     M30-34      M
# 1     M20-24      M
# 2     M30-34      M
# 3     M25-29      M
# 4     M30-34      M
# ..       ...    ...
# 295   M30-34      M
# 296   M45-49      M
# 297   M40-44      M
# 298   M45-49      M
# 299   M35-39      M
#
# [300 rows x 2 columns]

# %%
df['Gender'] = gender_csv['Gender']
df = df[:300]
df
# Out:
# <ipython-input-52-a706b26d6f90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = gender_csv['Gender']
#     Last Name  First Name Division Country    BIB Overall Place      Time  \
# 0     Cherono    Lawrence    30-34     KEN      4             1  02:05:45
# 1      Debela      Dejene    20-24     ETH     38             2  02:05:46
# 2     Mengstu       Asefa    30-34     ETH      5             3  02:05:48
# 3      Karoki       Bedan    25-29     KEN      9             4  02:05:53
# 4        Abdi      Bashir    30-34     BEL     10             5  02:06:14
# ..        ...         ...      ...     ...    ...           ...       ...
# 295    Kimura        Kyle    30-34     CAN   2564           296  02:39:16
# ...

# %%
df.to_csv('Chicago_Marathon2019.csv', index=False)
