# %% [markdown]
# <a href="https://colab.research.google.com/github/snwnkang/CS171_Final_vis_Marathon/blob/main/Chicago_Marathon_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from IPython.display import HTML
import html

# %%
year = "2023"

# %%
raw_html2023 = """<html><head><style>body {transition: opacity ease-in 0.2s; }
body[unresolved] {opacity: 0; display: block; overflow: hidden; position: relative; }
</style>
<title>Bank of America Chicago Marathon</title>
<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
<meta name="apple-mobile-web-app-status-bar-style" content="black">
<link rel="apple-touch-icon" href="//results-static.mikatiming.com/2023/chicago/../../stages/blue/images/apple-touch-icon.png">
<meta name="viewport" content="width=device-width, initial-scale=1">
<meta property="fb:app_id" content="198023663696085">
<meta property="og:image" content="https://results-static.mikatiming.com/2023/chicago/styles/responsive_2016/logo_fb.png">
<meta property="og:image:width" content="630">
<meta property="og:image:height" content="315">
<meta property="og:type" content="website">
<meta property="og:site_name" content="Mika timing">
<meta property="og:url" content="https://results.chicagomarathon.com/2023/?event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">
<meta property="og:title" content="Bank of America Chicago Marathon: Results">
<link rel="stylesheet" href="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/css/bootstrap.css">
<link rel="stylesheet" href="//results-static.mikatiming.com/stages/blue/lib/static/styles.build/responsive_2016/style.css">
<link href="/2023/?content=css_event&amp;theme=responsive&amp;event=2023_chicago&amp;style=responsive_2016" rel="stylesheet" type="text/css">
<link rel="shortcut icon" href="//results-static.mikatiming.com/stages/blue/images/favicon.ico">
<script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-X7BG41Z7K0&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" src="//assets.mikatiming.com/lib/jquery/1.11.3/jquery.min.js"></script>
<script src="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/js/bootstrap.min.js"></script>
<script type="text/javascript" src="/2023/?content=ajax2&amp;client=js"></script>
<script type="text/javascript"> var require = {"baseUrl":"\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static","deps":["\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static\/webcomponentsjs-0.7.0\/webcomponents-lite.js"],"paths":{"d3":"d3-3.4.13\/d3","c3":"c3-0.4.8\/c3","moment":"moment.js-2.9.0\/moment-with-locales.min","GDouglasPeuker":"GDouglasPeuker","Mika":"Mika.build","async":"require.js-plugins-1.0.3\/async","combokeys":"combokeys-2.3.0\/dist\/combokeys","videojs":"..\/..\/node_modules\/video.js\/dist\/video.min","hls2":"videojs5-hlsjs-source-handler\/dist\/videojs5-hlsjs-source-handler","nouislider":"noUiSlider-9.2.0\/nouislider.min","screenfull":"screenfull.js-4.0.0\/screenfull","lodashIsEqual":"lodash\/isEqual","Mika\/Cookie":"Mika.build\/Cookie.js?ff716e5556","Mika\/Dialog":"Mika.build\/Dialog.js?c4ce14ed92","Mika\/Environment":"Mika.build\/Environment.js?c29942fcfd","Mika\/FavoriteColorMapper":"Mika.build\/FavoriteColorMapper.js?c9630670ac","Mika\/ImageErrorHandler":"Mika.build\/ImageErrorHandler.js?ee9286242b","Mika\/ImageViewer":"Mika.build\/ImageViewer.js?c06c87b4c1","Mika\/Log
457","Mika\/Results\/Plugins\/pacegraph":"Mika.build\/Results\/Plugins\/pacegraph.js?d5a298929c","Mika\/Results\/Plugins\/race_flow_table":"Mika.build\/Results\/Plugins\/race_flow_table.js?b1a49d7944","Mika\/Results\/Plugins\/remote_content":"Mika.build\/Results\/Plugins\/remote_content.js?66ab0ba871","Mika\/Results\/Plugins\/strings":"Mika.build\/Results\/Plugins\/strings.js?be3574f716","Mika\/Results\/Requester":"Mika.build\/Results\/Requester.js?e08e2c3a1b","Mika\/SearchProvider":"Mika.build\/SearchProvider.js?119e90ba1f","Mika\/Sharer\/Networks\/base":"Mika.build\/Sharer\/Networks\/base.js?5e512e5688","Mika\/Sharer\/Networks\/facebook":"Mika.build\/Sharer\/Networks\/facebook.js?0d6fa0375a","Mika\/Sharer\/Networks\/googleplus":"Mika.build\/Sharer\/Networks\/googleplus.js?3beb6aba2b","Mika\/Sharer\/Networks\/twitter":"Mika.build\/Sharer\/Networks\/twitter.js?aa24183cf7","Mika\/Sharer\/Networks\/whatsapp":"Mika.build\/Sharer\/Networks\/whatsapp.js?4033c2aa8c","Mika\/Sharer\/Networks\/xing":"Mika.build\/Sharer\/Networks\/xing.js?39187fc831","Mika\/Sharer\/Sharer":"Mika.build\/Sharer\/Sharer.js?c7dcac3a10","Mika\/Ticker":"Mika.build\/Ticker.js?141ff57f2e","Mika\/Timer":"Mika.build\/Timer.js?260b39f15c","Mika\/Tools":"Mika.build\/Tools.js?370394a8e7","Mika\/Tracker":"Mika.build\/Tracker.js?e68c5b2784","Mika\/Uploader":"Mika.build\/Uploader.js?68ac256df1","Mika\/VideoViewer":"Mika.build\/VideoViewer.js?7dbe05ea75"},"config":{"Mika\/Mika":{"debug":false,"display_errors":true,"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","language":"EN_CAP","global_event_id":"2023_chicago","static_uri":"\/\/results-static.mikatiming.com\/stages\/blue"},"Mika\/Logger":{"debug":false},"Mika\/Quicksearch":{"pid":null,"not_found_string":"Sorry, no results found!"},"Mika\/ImageViewer":{"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","sharerActive":true},"Mika\/VideoViewer":{"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","modalWidth":null},"Mika\/Map\/Map":{"mapProvider":"here"},"Mika\/Sharer\/Sharer":{"pathSharerIcons":"\/\/assets.mikatiming.com\/img\/mt\/sharer\/","buttonSize":"xs"},"Mika\/Map\/Marker\/Person":[]}}</script>
<script type="text/javascript" src="//results-static.mikatiming.com/stages/blue/lib/static/require.js-2.3.6/require.min.js"></script>
<script type="text/javascript" src="//results-static.mikatiming.com/stages/blue/lib/static/Emitter.js"></script>
<meta name="apple-mobile-web-app-capable" content="yes">
<script type="text/javascript">
        // create helper function to handle the image loading errors
        var mikaImageErrorHandler = function (image) {
            require(["Mika/ImageErrorHandler"], function (ImageErrorHandler) {
                var que = ImageErrorHandler.queueImageGeneration(image.dataset.generateSrcUrl, image.dataset.imageHash, image.src);
                setTimeout(function () {
                     ImageErrorHandler.statusMissingImages(que);
                }, 1100);
            })
        };
        require(["Mika/Mika", "require"], function (Mika, require) {
            new Mika();
            require(["Mika/Dialog", "Mika/Popover", "Mika/ImageViewer", "Mika/Timer"]);
        });
    </script>
<script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="//results-static.mikatiming.com/stages/blue/lib/static/webcomponentsjs-0.7.0/webcomponents-lite.js" src="//results-static.mikatiming.com/stages/blue/lib/static/webcomponentsjs-0.7.0/webcomponents-lite.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Mika" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Mika.js?71f1195427"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Tracker" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Tracker.js?e68c5b2784"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Logger" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Logger.js?e1107568f4"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Tools" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Tools.js?370394a8e7"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Map/LatLng" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Map/LatLng.js?52354fc88e"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Sharer/Sharer" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Sharer/Sharer.js?c7dcac3a10"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Quicksearch" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Quicksearch.js?c0b9e8b89a"></script></head>
<body class="pid-search content-list view-public branch-production site-2023_chicago event-MAR">

<header class="hidden-xs">
  <div class="container">
<div class="logo row">
<a href="/2023/">
<img class="logo-screen" src="//results-static.mikatiming.com/2023/chicago/../chicago/styles/responsive_2016/logo.png" alt="">
</a>
<ul class="header-brand">
<li>Race Results</li>
<li>Unofficial Race Results</li>
<li>Start Time: 07:30:00</li>
</ul>
</div>
</div>
</header>
<nav class="navbar navbar-default navbar-top navbar-fixed-top">
  <div class="container">
    <div class="navbar-header">
    <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#navbar" aria-expanded="false">
        <span class="sr-only">Toggle navigation</span>
        <span class="icon-bar"></span>
        <span class="icon-bar"></span>
        <span class="icon-bar"></span>
      </button>
 <a class="navbar-brand" href="/2023/">
<img class="hidden-sm hidden-md hidden-lg" alt="" src="//results-static.mikatiming.com/2023/chicago/../chicago/styles/responsive_2016/logo.png">
 <span class="hidden-xs">Bank of America Chicago Marathon 2023</span>
 </a>
    </div>
 <div id="navbar" class="navbar-collapse collapse">
<ul class="nav navbar-nav hidden-sm hidden-md hidden-lg">
<li class="active"><a class="nav-pid-start" href="/2023/?event=MAR&amp;num_results=500&amp;pid=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex"><span>Results</span></a></li>
<li><a class="nav-pid-leaderboard" href="/2023/?pid=leaderboard"><span>Leaderboard</span></a></li>
<li><a class="nav-pid-leaderboard_sprint" href="/2023/?pid=leaderboard_sprint"><span>Bonus Competition</span></a></li>
<li><a class="nav-pid-tracking" href="/2023/?pid=tracking"><span>Tracking</span></a></li>
<li><a class="nav-pid-favorites" href="/2023/?pid=favorites"><span>My Runners</span></a></li>
</ul>

<ul class="nav navbar-nav navbar-right">
<li class="">
<a href="https://chicago-history.r.mikatiming.com/" class="" role="button">to Results 1996-2022</a>
</li>
<li class="">
<a href="http://www.chicagomarathon.com/" class="" role="button">Back to Homepage</a>
</li>
</ul>
</div>
</div>
</nav>
<!-- header end -->
<!-- main start -->
<script async="" src="https://www.googletagmanager.com/gtag/js"></script>

        <script>

         var mt_tracker = {};

         window.dataLayer = window.dataLayer || [];
            function gtag(){dataLayer.push(arguments);}
            gtag('js', new Date());

            require(['Mika/Tracker'], function(tracker) {
                tracker.setGtagConfig(["G-X7BG41Z7K0"], {"page_title":"search","send_page_view":false,"meeting_id":"9TGG963812D","meeting_name":"Bank of America Chicago Marathon 2023","meeting_year":"2023","results_view":"public"});
                tracker.track('page_view');
                mt_tracker = tracker;
            });

    </script>
          <section class="section-nav container-fluid"><nav class="navbar navbar-default row navbar-main hidden-xs">  <div class="container"><ul class="nav navbar-nav">
            <script type="text/javascript">
                jQuery("#navbar-main-dropdown").dropdown();
                var menuResizeHandler = function () {
                    var container   = jQuery(".navbar-main .container");
                    var navbar   = jQuery(".navbar-main .nav");
                    var currentWidth = 0;
                    var dropdown = navbar.find("li.dropdown");
                    // quickly show it and get the width
                    dropdown.removeClass("hide");
                    var dropdownWidth = dropdown.width();
                    var quicksearchWidth = jQuery(".navbar-main .quicksearch-form").width();
                    currentWidth += quicksearchWidth;
                    var menuEntries = navbar.find("li:not(.dropdown)");
                    menuEntries.each(function (i) {
                        navbar.append(this);
                    });
                    navbar.append(dropdown);
                    dropdown.addClass("hide").removeClass("active");

                    var maxWidth = container.width();
                    menuEntries.each(function (i) {
                        currentWidth += jQuery(this).width();

                        var next = false;
                        if (typeof menuEntries[i+1] !== "undefined") {
                            next = menuEntries[i+1];
                        }
                        var currentIsAboveMaxWidth = (currentWidth > maxWidth);
                        var currentIsNotLastAndPlusDropdownIsAboveMaxWidth = ((currentWidth + dropdownWidth > maxWidth) && i != menuEntries.length-1);
                        var currentPlusNextIsAboveMaxWidth = (next && currentWidth + jQuery(next).width() > maxWidth);
                        //console.log("%s: width: %s, is above: %s, notlast: %s, plusnext: %s", jQuery(this).text(), currentWidth, currentIsAboveMaxWidth, currentIsNotLastAndPlusDropdownIsAboveMaxWidth, currentPlusNextIsAboveMaxWidth)
                        if(currentIsAboveMaxWidth || currentIsNotLastAndPlusDropdownIsAboveMaxWidth || currentPlusNextIsAboveMaxWidth) {
                            jQuery(this).find("a").popover("destroy");
                            dropdown.find("ul").append(this);
                            dropdown.removeClass("hide");
                            if (jQuery(this).hasClass("active")) {
                                dropdown.addClass("active");
                            }
                        }
                    });

                };
                jQuery(document).on("ready", menuResizeHandler);
                var lastWidth = 0;
                jQuery(window).on("resize", function () {
                    lastWidth = window.innerWidth;
                    setTimeout(function () {
                        if (lastWidth == window.innerWidth) {
                            menuResizeHandler();
                        }
                    }, 100);
                });
            </script>
         <li class="active nav-pid-start"><a href="/2023/?pid=start&amp;pidp=start"><span>Results</span></a></li><li class="nav-pid-leaderboard"><a href="/2023/?pid=leaderboard&amp;pidp=leaderboard"><span>Leaderboard</span></a></li><li class="nav-pid-leaderboard_sprint"><a href="/2023/?pid=leaderboard_sprint&amp;pidp=leaderboard_sprint"><span>Bonus Competition</span></a></li><li class="nav-pid-tracking"><a href="/2023/?pid=tracking&amp;pidp=tracking"><span>Tracking</span></a></li><li class="nav-pid-favorites"><a href="/2023/?pid=favorites&amp;pidp=favorites"><span>My Runners</span></a></li><li class="dropdown hide">
                <a href="javascript:void(0);" class="dropdown-toggle" id="navbar-main-dropdown" data-toggle="dropdown" aria-haspopup="true" aria-expanded="true">
                    More
                    <span class="caret"></span>
                </a>
                <ul class="dropdown-menu" aria-labelledby="navbar-main-dropdown"></ul></li></ul>
</div>
</nav><!-- menu end -->
</section>
<section class="section-main">
<div class="container" id="main-content">
<div class="row">
<div class="cbox-main pid-search col-xs-12" id="cbox-main">
<!-- cbox include start -->


<div class="row">
<div class="col-xs-10">
<h2> Results: Marathon</h2>
</div>
</div>

<ul class="row-xs list-group list-info">
<li class="list-group-item">
Unofficial Results
</li>
</ul>
<div class="col-sm-12 row-xs">
<ul class="list-group list-group-multicolumn">
<li class="  list-group row list-group-item  list-group-header ">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs" style="width: 40px">Place Overall</div>
  <div class=" list-field type-place place-primary" style="width: 40px">Place Gender</div>
  <div class=" list-field type-fullname">Name (CTZ)</div>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7  hidden-xs hidden-sm list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>BIB</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>Division</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>HALF</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>Finish</div>
  <div class=" list-field type-favorite" style="width: 13px"></div>
  </div>
</div>
</div>
</li>
<li class="favorite list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">1</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">1</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFFB&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Kiptum, Kelvin (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>2</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>20-24</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:00:48</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:00:35</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_remove=9TGG963828AFFB" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/delete.svg" alt="Remove Runner from 'My Runners'" title="Remove Runner from 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">2</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">2</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFE5&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Kipruto, Benson (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>1</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:02:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:04:02</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFE5" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">3</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">3</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828B00D&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Abdi, Bashir (BEL)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>3</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:02:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:04:32</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828B00D" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">4</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">4</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFE7&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Korir, John (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>7</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:02:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:05:09</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFE7" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">5</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">5</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFFE&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Tura Abdiwak, Seifu (ETH)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>6</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:02:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:05:29</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFFE" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">6</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">6</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFDD&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Mantz, Conner (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>10</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:03:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:07:47</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFDD" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">7</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">7</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFF6&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Young, Clayton (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>25</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:03:42</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:08:00</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFF6" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">8</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">8</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828B000&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Rupp, Galen (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>9</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:03:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:08:48</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828B000" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">9</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">9</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFE4&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Chelanga, Sam (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>29</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:03:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:08:50</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFE4" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">10</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">10</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828B00C&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Ichida, Takashi (JPN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>12</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:03:21</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:08:57</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828B00C" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">11</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">11</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFEB&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Shrader, Brian (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>27</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:04:35</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:09:46</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFEB" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">12</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">12</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFDE&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Kiptoo, Wesley (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>31</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>20-24</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:03:18</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:10:28</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFDE" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">13</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">13</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFFD&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">McDonald, Matt (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>16</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:04:35</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:10:34</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFFD" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">14</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">14</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFE2&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Reichow, Joel (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>26</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:04:41</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:10:37</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFE2" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">15</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">15</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828B00A&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Colley, Andrew (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>22</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:04:35</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:11:22</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828B00A" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">16</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">16</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFF9&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Salvano, Kevin (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>24</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:04:35</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:11:26</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFF9" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">17</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">17</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828B006&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Wolde, Dawit (ETH)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>5</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:02:20</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:11:33</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828B006" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">18</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">18</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828B005&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Lara, Frank (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>23</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:03:55</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:12:57</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828B005" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">19</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">19</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFEE&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Gusman, Jordan (MLT)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>33</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:05:54</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:13:13</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFEE" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">20</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">20</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828679C&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Kiselev, Stepan (RUS)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>611</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:05:09</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:13:26</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828679C" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">21</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">1</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828AFFA&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Hassan, Sifan (NED)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>108</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:05:48</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:13:44</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828AFFA" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">22</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px
div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828775C&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">De Knijff, Dennis (NED)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>4121</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:22:24</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:03</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828775C" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">488</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">31</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828887B&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Mathieu, Jeannette (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>657</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:18:26</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:03</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828887B" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">489</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">457</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG9638281109&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Lavedrine, Mathieu (FRA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>25491</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:16:20</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:05</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG9638281109" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">490</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">458</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963827D0BA&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Soares, Nuno (POR)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>25394</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:19:36</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:05</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963827D0BA" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">491</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">459</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963827C089&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Preston, Scott (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>22065</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:19:22</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:07</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963827C089" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">492</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">460</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828829D&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Villegas, Juan (CRC)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>21016</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:20:05</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:08</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828829D" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">493</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">461</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG9638282FD1&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Calderón, Boris (MEX)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>7360</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:20:26</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:10</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG9638282FD1" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">494</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">462</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG9638284C0B&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">He, Yong (SGP)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>25402</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:18:11</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:10</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG9638284C0B" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">495</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">463</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG9638283E66&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Leung, Chi Ho (GBR)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>6041</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:18:40</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:11</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG9638283E66" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">496</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">2</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963828203A&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Grant, Jonah (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>9164</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:19:54</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:12</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963828203A" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">497</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">464</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963827D779&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Marshall, Richard (CAN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>2156</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>35-39</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:18:35</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:12</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963827D779" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">498</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">465</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG9638280E6E&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Tipping, Luke (GBR)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>6038</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:18:42</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:13</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG9638280E6E" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">499</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">466</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG9638287CBC&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Webber, Robert (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>6066</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:18:44</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:14</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG9638287CBC" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">500</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">467</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=9TGG963827F382&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR">Finnigan, Sean (USA)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>524</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>40-44</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">HALF</div>01:18:23</div>
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:39:18</div>
  <div class=" list-field type-favorite text-right" style="width: 13px"><a href="?num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex&amp;event=MAR&amp;favorite_add=9TGG963827F382" class="icon l"><img src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" alt="Add runner to 'My Runners'" title="Add runner to 'My Runners'"></a></div>
  </div>
</div>
</div>
</li>
</ul>
</div>
<div class="row">
<div class="col-xs-8 col-sm-9 col-md-6">
<div class="btn-toolbar list-actions" role="toolbar" aria-label="">
<div class="btn-group" role="group">
<a class="btn btn-default" href="?pid=start&amp;event=MAR&amp;num_results=500&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">Back / New Search</a>
<a class="btn btn-default hidden-xs" href="?event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">Reload</a>
<a class="btn btn-default hidden-xs" href="#" onclick="open_print('?print=1&amp;event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex');">Print</a>
</div>
</div>
</div>
<div class="col-xs-4 col-sm-3 col-md-6">
<div class="pull-right pages">
<ul class="pagination"><li class="hidden-xs hidden-sm active"><a href="?page=1&amp;event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">1</a></li><li class="hidden-xs hidden-sm"><a href="?page=2&amp;event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">2</a></li><li class="hidden-xs hidden-sm"><a href="?page=3&amp;event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">3</a></li><li class="disabled"><a href="#" aria-label="" class="hidden-xs hidden-sm"><span aria-hidden="true">...</span></a></li><li class="hidden-xs hidden-sm"><a href="?page=97&amp;event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">97</a></li><li class="pages-nav-button"><a href="?page=2&amp;event=MAR&amp;num_results=500&amp;pid=search&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search%5Bstate%5D=%25&amp;search_sort=place_nosex">&gt;</a></li></ul>
</div>
</div>
</div>
<!-- cbox include end -->
</div>


</div><!-- row -->
</div><!-- container main-content -->
</section><!-- section-main -->
<!-- main end -->

<!-- footer start -->
  <footer>  <div class="container"><div class="row"><div class="footer-box legal-footer" id="pid-search">

        <div class="col-xs-12">
        <a class="pull-right" href="https://www.mikatiming.com/">mika:timing GmbH © 2023</a> <a href="https://q.r.mikatiming.com/results-legal/en/">Legal Notice</a> | <a href="https://q.r.mikatiming.com/results-privacy-statement/en/">Privacy Policy</a>
        </div>

</div>

</div><!-- row end -->
          </div><!-- container end -->
    </footer><!-- footer section end --><div class="popup-info" style="display:none;" id="popup-info"></div>
<div class="popup" style="display:none;" id="popup"></div>
<div id="cconsent-overlay" style="display:none;"></div>




<input class="hidden" id="identified_1" autocomplete="off" name="b7dd1fc3-6825-1b4a-f56f-0a4a5ca4fe7a" data-last-search-value=""><ul class="dropdown-menu quicksearch-results" style="z-index: 2001;"></ul></body></html>"""

# %%
soup = BeautifulSoup(raw_html2023, 'html.parser')

# %%
name_nodes = soup.select('.list-field.type-fullname')

# %%
name_nodes = name_nodes[1:]

# %%
name_nodes[0].get_text(strip=True)
# Out:
# 'Kiptum, Kelvin (KEN)'

# %%
def get_name(name_node):
  text = name_node.get_text()
  name = text[:text.find("(")].strip()
  return name

def get_country(name_node):
  country_text = name_node.get_text()
  country_item = country_text[country_text.find("(") + 1 : country_text.find(")")]
  return country_item

# %%
list_all_names = []
list_countries = []
for name_node in name_nodes:
  list_all_names.append(get_name(name_node))
  list_countries.append(get_country(name_node))

# %%
overall_nodes = soup.select('.list-field.type-place.place-secondary.hidden-xs.numeric')

# %%
def get_overall(overall_node):
  return overall_node.get_text()

# %%
bib_nodes = soup.select('.list-field.type-field')

# %%
bib_nodes = bib_nodes[1:]

# %%
def get_bib(bib_node):
  return bib_node.get_text()

# %%
time_nodes = soup.select('.list-field.type-time:contains("Finish")')
# Out:
# /usr/local/lib/python3.10/dist-packages/soupsieve/css_parser.py:856: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028

# %%
time_nodes = time_nodes[1:]

# %%
time_node = time_nodes[0].get_text()

# %%
time_node.split('Finish')[-1].strip()
# Out:
# '02:00:35'

# %%
def get_time(time_node):
  return time_node.get_text().split('Finish')[-1].strip()

# %%
division_nodes = soup.select('.list-field.type-age_class')

# %%
def get_division(division_node):
  return division_node.get_text()

# %%
list_overall = []
for overall_node in overall_nodes:
  list_overall.append(get_overall(overall_node))

list_bib = []
for bib_node in bib_nodes:
  list_bib.append(get_bib(bib_node))

list_times = []
for time_node in time_nodes:
  list_times.append(get_time(time_node))

list_divisions = []
for division_node in division_nodes:
  list_divisions.append(get_division(division_node))

# %%
list_divisions = list_divisions[1:]

# %%
data = {
    'Name': list_all_names,
    'Division': list_divisions,
    'Country': list_countries,
    'BIB': list_bib,
    'Overall Place': list_overall,
    'Time': list_times
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                     Name       Division Country      BIB Overall Place  \
# 0         Kiptum, Kelvin  Division20-24     KEN     BIB2             1
# 1        Kipruto, Benson  Division30-34     KEN     BIB1             2
# 2           Abdi, Bashir  Division30-34     BEL     BIB3             3
# 3            Korir, John  Division25-29     KEN     BIB7             4
# 4    Tura Abdiwak, Seifu  Division25-29     ETH     BIB6             5
# ..                   ...            ...     ...      ...           ...
# 495         Grant, Jonah  Division25-29     USA  BIB9164           496
# 496    Marshall, Richard  Division35-39     CAN  BIB2156           497
# 497        Tipping, Luke  Division30-34     GBR  BIB6038           498
# 498       Webber, Robert  Division30-34     USA  BIB6066           499
# 499       Finnigan, Sean  Division40-44     USA   BIB524           500
#
#          Time
# 0    02:00:35
# 1    02:04:02
# 2    02:04:32
# 3    02:05:09
# 4    02:05:29
# ..        ...
# ...

# %%
base_url = 'https://results.chicagomarathon.com/2023/'

runner_links = [link['href'] for link in soup.select('.type-fullname a') if link.has_attr('href')]

def get_runner_gender(detail_url):
    full_url = base_url + detail_url
    response = requests.get(full_url)
    detail_soup = BeautifulSoup(response.content, 'html.parser')
    gender_element = detail_soup.select_one('td.f-sex.last')
    return gender_element.get_text().strip() if gender_element else None

def scrape_runner_genders(runner_links):
    genders = []
    for link in runner_links:
        gender = get_runner_gender(link)
        genders.append(gender)
    return genders

genders_list = scrape_runner_genders(runner_links)
print(genders_list)
# Out:
# ['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Ma
# ...

# %%
len(genders_list)
# Out:
# 500

# %%
df['Gender'] = genders_list

# %%
df
# Out:
#                     Name       Division Country      BIB Overall Place  \
# 0         Kiptum, Kelvin  Division20-24     KEN     BIB2             1
# 1        Kipruto, Benson  Division30-34     KEN     BIB1             2
# 2           Abdi, Bashir  Division30-34     BEL     BIB3             3
# 3            Korir, John  Division25-29     KEN     BIB7             4
# 4    Tura Abdiwak, Seifu  Division25-29     ETH     BIB6             5
# ..                   ...            ...     ...      ...           ...
# 495         Grant, Jonah  Division25-29     USA  BIB9164           496
# 496    Marshall, Richard  Division35-39     CAN  BIB2156           497
# 497        Tipping, Luke  Division30-34     GBR  BIB6038           498
# 498       Webber, Robert  Division30-34     USA  BIB6066           499
# 499       Finnigan, Sean  Division40-44     USA   BIB524           500
#
#          Time      Gender
# 0    02:00:35        Male
# 1    02:04:02        Male
# 2    02:04:32        Male
# ...

# %%
df.to_csv('Chicago_Marathon2023.csv', index=False)
