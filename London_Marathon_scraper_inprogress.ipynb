# %% [markdown]
# <a href="https://colab.research.google.com/github/snwnkang/CS171_Final_vis_Marathon/blob/main/London_Marathon_scraper_inprogress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from IPython.display import HTML
import html

# %%
year = "2014"
url = "https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/chicago_data/gendercsv/2014gender.csv"

# %%
raw_html = """<html><head><style>body {transition: opacity ease-in 0.2s; }
body[unresolved] {opacity: 0; display: block; overflow: hidden; position: relative; }
</style>
<title>Bank of America Chicago Marathon</title>
<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
<meta name="apple-mobile-web-app-status-bar-style" content="black">
<link rel="apple-touch-icon" href="//results-static.mikatiming.com/events/chicago/../../stages/blue/images/apple-touch-icon.png">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/css/bootstrap.css">
<link rel="stylesheet" href="//results-static.mikatiming.com/stages/blue/lib/static/styles.build/responsive_2016/style.css">
<link href="/2022/?content=css_event&amp;theme=responsive&amp;event=events_chicago&amp;style=responsive_2016" rel="stylesheet" type="text/css">
<link rel="shortcut icon" href="//results-static.mikatiming.com/stages/blue/images/favicon.ico">
<script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-X7BG41Z7K0&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" src="//assets.mikatiming.com/lib/jquery/1.11.3/jquery.min.js"></script>
<script src="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/js/bootstrap.min.js"></script>
<script type="text/javascript" src="/2022/?content=ajax2&amp;client=js"></script>
<script type="text/javascript"> var require = {"baseUrl":"\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static","deps":["\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static\/webcomponentsjs-0.7.0\/webcomponents-lite.js"],"paths":{"d3":"d3-3.4.13\/d3","c3":"c3-0.4.8\/c3","moment":"moment.js-2.9.0\/moment-with-locales.min","GDouglasPeuker":"GDouglasPeuker","Mika":"Mika.build","async":"require.js-plugins-1.0.3\/async","combokeys":"combokeys-2.3.0\/dist\/combokeys","videojs":"..\/..\/node_modules\/video.js\/dist\/video.min","hls2":"videojs5-hlsjs-source-handler\/dist\/videojs5-hlsjs-source-handler","nouislider":"noUiSlider-9.2.0\/nouislider.min","screenfull":"screenfull.js-4.0.0\/screenfull","lodashIsEqual":"lodash\/isEqual","Mika\/Cookie":"Mika.build\/Cookie.js?ff716e5556","Mika\/Dialog":"Mika.build\/Dialog.js?c4ce14ed92","Mika\/Environment":"Mika.build\/Environment.js?c29942fcfd","Mika\/FavoriteColorMapper":"Mika.build\/FavoriteColorMapper.js?c9630670ac","Mika\/ImageErrorHandler":"Mika.build\/ImageErrorHandler.js?ee9286242b","Mika\/ImageViewer":"Mika.build\/ImageViewer.js?c06c87b4c1","Mika\/Logger":"Mika.build\/Logger.js?e1107568f4","Mika\/Map\/FavoriteBar":"Mika.build\/Map\/FavoriteBar.js?3ea7f5c014","Mika\/Map\/LatLng":"Mika.build\/Map\/LatLng.js?52354fc88e","Mika\/Map\/LatLngBounds":"Mika.build\/Map\/LatLngBounds.js?1dfacf85e0","Mika\/Map\/Map":"Mika.build\/Map\/Map.js?4f877dc9d8","Mika\/Map\/Marker\/Cluster\/Cluster":"Mika.build\/Map\/Marker\/Cluster\/Cluster.js?9d663798b5","Mika\/Map\/Marker\/Cluster\/Icon":"Mika.build\/Map\/Marker\/Cluster\/Icon.js?760db97eac","Mika\/Map\/Marker\/Cluster\/MarkerCluster":"Mika.build\/Map\/Marker\/Cluster\/MarkerCluster.js?74facae188","Mika\/Map\/Marker\/CollisionSupressor":"Mika.build\/Map\/Marker\/CollisionSupressor.js?c4ce53292e","Mika\/Map\/Marker\/CustomImage":"Mika.build\/Map\/Marker\/CustomImage.js?388a6d995f","Mika\/Map\/Marker\/Flag":"Mika.build\/Map\/Marker\/Flag.js?a07e8bf012","Mika\/Map\/Marker\/Icons":"Mika.build\/Map\/Marker\/Icons.js?f82b755835","Mika\/Map\/Marker\/Km":"Mika.build\/Map\/Marker\/Km.js?82e293c641","Mika\/Map\/Marker\/Overlay":"Mika.build\/Map\/Marker\/Overlay.js?ae15904211","Mika\/Map\/Marker\/OverlayImage":"Mika.build\/Map\/Marker\/OverlayImage.js?243c09e42c","Mika\/Map\/Marker\/Person":"Mika.build\/Map\/Marker\/Person.js?ffeb0b2784","Mika\/Map\/Object\/Circle":"Mika.build\/Map\/Object\/Circle.js?05cd4972be","Mika\/Map\/Polyline":"Mika.build\/Map\/Polyline.js?c5c43f51bc","Mika\/Mika":"Mika.build\/Mika.js?71f1195427","Mika\/PolylineEditor":"Mika.build\/PolylineEditor.js?72eb0e6511","Mika\/Popover":"Mika.build\/Popover.js?4e7d1c290d","Mika\/Quicksearch":"Mika.build\/Quicksearch.js?c0b9e8b89a","Mika\/Results\/Board":"Mika.build\/Results\/Board.js?fba8687d7c","Mika\/Results\/Plugins\/favorite_display":"Mika.build\/Results\/Plugins\/favorite_display.js?66d3b96320","Mika\/Results\/Plugins\/favorites":"Mika.build\/Results\/Plugins\/favorites.js?59d7f710e3","Mika\/Results\/Plugins\/global_option_bar":"Mika.build\/Results\/Plugins\/global_option_bar.js?6d60242b49","Mika\/Results\/Plugins\/graph":"Mika.build\/Results\/Plugins\/graph.js?34677aebe4","Mika\/Results\/Plugins\/list":"Mika.build\/Results\/Plugins\/list.js?75427b6c42","Mika\/Results\/Plugins\/list_responsive":"Mika.build\/Results\/Plugins\/list_responsive.js?b4bfd71e0b","Mika\/Results\/Plugins\/main_buttons":"Mika.build\/Results\/Plugins\/main_buttons.js?730f1cd329","Mika\/Results\/Plugins\/map":"Mika.build\/Results\/Plugins\/map.js?94097b963a","Mika\/Results\/Plugins\/overlays":"Mika.build\/Results\/Plugins\/overlays.js?2fb2b0d457","Mika\/Results\/Plugins\/pacegraph":"Mika.build\/Results\/Plugins\/pacegraph.js?d5a298929c","Mika\/Results\/Plugins\/race_flow_table":"Mika.build\/Results\/Plugins\/race_flow_table.js?b1a49d7944","Mika\/Results\/Plugins\/remote_content":"Mika.build\/Results\/Plugins\/remote_content.js?66ab0ba871","Mika\/Results\/Plugins\/strings":"Mika.build\/Results\/Plugins\/strings.js?be3574f716","Mika\/Results\/Requester":"Mika.build\/Results\/Requester.js?e08e2c3a1b","Mika\/SearchProvider":"Mika.build\/SearchProvider.js?119e90ba1f","Mika\/Sharer\/Networks\/base":"Mika.build\/Sharer\/Networks\/base.js?5e512e5688","Mika\/Sharer\/Networks\/facebook":"Mika.build\/Sharer\/Networks\/facebook.js?0d6fa0375a","Mika\/Sharer\/Networks\/googleplus":"Mika.build\/Sharer\/Networks\/googleplus.js?3beb6aba2b","Mika\/Sharer\/Networks\/twitter":"Mika.build\/Sharer\/Networks\/twitter.js?aa24183cf7","Mika\/Sharer\/Networks\/whatsapp":"Mika.build\/Sharer\/Networks\/whatsapp.js?4033c2aa8c","Mika\/Sharer\/Networks\/xing":"Mika.build\/Sharer\/Networks\/xing.js?39187fc831","Mika\/Sharer\/Sharer":"Mika.build\/Sharer\/Sharer.js?c7dcac3a10","Mika\/Ticker":"Mika.build\/Ticker.js?141ff57f2e","Mika\/Timer":"Mika.build\/Timer.js?260b39f15c","Mika\/Tools":"Mika.build\/Tools.js?370394a8e7","Mika\/Tracker":"Mika.build\/Tracker.js?e68c5b2784","Mika\/Uploader":"Mika.build\/Uploader.js?68ac256df1","Mika\/VideoViewer":"Mika.build\/VideoViewer.js?7dbe05ea75"},"config":{"Mika\/Mika":{"debug":false,"display_errors":true,"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","language":"EN_CAP","global_event_id":"events_chicago","static_uri":"\/\/results-static.mikatiming.com\/stages\/blue"},"Mika\/Logger":{"debug":false},"Mika\/Quicksearch":{"pid":null,"not_found_string":"Sorry, no results found!"},"Mika\/ImageViewer":{"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","sharerActive":true},"Mika\/VideoViewer":{"pathIcons":"\/\/assets.mikatiming.com\/img\/mt\/results\/default","modalWidth":null},"Mika\/Map\/Map":{"mapProvider":"google"},"Mika\/Sharer\/Sharer":{"pathSharerIcons":"\/\/assets.mikatiming.com\/img\/mt\/sharer\/","buttonSize":"xs"},"Mika\/Map\/Marker\/Person":[]}}</script>
<script type="text/javascript" src="//results-static.mikatiming.com/stages/blue/lib/static/require.js-2.3.6/require.min.js"></script>
<script type="text/javascript" src="//results-static.mikatiming.com/stages/blue/lib/static/Emitter.js"></script>
<meta name="apple-mobile-web-app-capable" content="yes">
<script type="text/javascript">
        // create helper function to handle the image loading errors
        var mikaImageErrorHandler = function (image) {
            require(["Mika/ImageErrorHandler"], function (ImageErrorHandler) {
                var que = ImageErrorHandler.queueImageGeneration(image.dataset.generateSrcUrl, image.dataset.imageHash, image.src);
                setTimeout(function () {
                     ImageErrorHandler.statusMissingImages(que);
                }, 1100);
            })
        };
        require(["Mika/Mika", "require"], function (Mika, require) {
            new Mika();
            require(["Mika/Dialog", "Mika/Popover", "Mika/ImageViewer", "Mika/Timer"]);
        });
    </script>
<script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="//results-static.mikatiming.com/stages/blue/lib/static/webcomponentsjs-0.7.0/webcomponents-lite.js" src="//results-static.mikatiming.com/stages/blue/lib/static/webcomponentsjs-0.7.0/webcomponents-lite.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Mika" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Mika.js?71f1195427"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Tracker" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Tracker.js?e68c5b2784"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Map/LatLng" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Map/LatLng.js?52354fc88e"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Sharer/Sharer" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Sharer/Sharer.js?c7dcac3a10"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="Mika/Quicksearch" src="//results-static.mikatiming.com/stages/blue/lib/static/Mika.build/Quicksearch.js?c0b9e8b89a"></script></head>
<body class="pid-search content-list view-public branch-production site-events_chicago event-MAR_999999107FA3090000000065">

<header class="hidden-xs">
  <div class="container">
<div class="logo row">
<a href="/2022/?lang=EN_CAP&amp;pidp=start">
<img class="logo-screen" src="//results-static.mikatiming.com/events/chicago/../chicago/styles/responsive_2016/logo.png" alt="">
</a>
<ul class="header-brand">
<li>Race Results</li>
<li>Official Race Results</li>
<li>1996-2021</li>
</ul>
</div>
</div>
</header>
<nav class="navbar navbar-default navbar-top navbar-fixed-top">
  <div class="container">
    <div class="navbar-header">
    <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#navbar" aria-expanded="false">
        <span class="sr-only">Toggle navigation</span>
        <span class="icon-bar"></span>
        <span class="icon-bar"></span>
        <span class="icon-bar"></span>
      </button>
 <a class="navbar-brand" href="/2022/?lang=EN_CAP&amp;pidp=start">
<img class="hidden-sm hidden-md hidden-lg" alt="" src="//results-static.mikatiming.com/events/chicago/../chicago/styles/responsive_2016/logo.png">
 <span class="hidden-xs">Bank of America Chicago Marathon</span>
 </a>
    </div>
 <div id="navbar" class="navbar-collapse collapse">
<ul class="nav navbar-nav hidden-sm hidden-md hidden-lg">
<li class="active"><a class="nav-pid-start" href="/2022/?event=MAR_999999107FA3090000000065&amp;event_main_group=2014&amp;lang=EN_CAP&amp;num_results=500&amp;pid=start&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex"><span>Results</span></a></li>
<li><a class="nav-pid-leaderboard" href="/2022/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=start"><span>Leaderboard</span></a></li>
</ul>

<ul class="nav navbar-nav navbar-right">
<li class="">
<a href="https://results.chicagomarathon.com/2023/" class="" role="button">Results 2023</a>
</li>
<li class="">
<a href="https://www.chicagomarathon.com/" class="" role="button">Back to Homepage</a>
</li>
</ul>
</div>
</div>
</nav>
<!-- header end -->
<!-- main start -->
<script async="" src="https://www.googletagmanager.com/gtag/js"></script>

        <script>

         var mt_tracker = {};

         window.dataLayer = window.dataLayer || [];
            function gtag(){dataLayer.push(arguments);}
            gtag('js', new Date());

            require(['Mika/Tracker'], function(tracker) {
                tracker.setGtagConfig(["G-X7BG41Z7K0"], {"page_title":"search","send_page_view":false,"meeting_id":false,"meeting_name":"Bank of America Chicago Marathon","meeting_year":"2022","results_view":"public"});
                tracker.track('page_view');
                mt_tracker = tracker;
            });

    </script>
          <section class="section-nav container-fluid"><nav class="navbar navbar-default row navbar-main hidden-xs">  <div class="container"><ul class="nav navbar-nav">
            <script type="text/javascript">
                jQuery("#navbar-main-dropdown").dropdown();
                var menuResizeHandler = function () {
                    var container   = jQuery(".navbar-main .container");
                    var navbar   = jQuery(".navbar-main .nav");
                    var currentWidth = 0;
                    var dropdown = navbar.find("li.dropdown");
                    // quickly show it and get the width
                    dropdown.removeClass("hide");
                    var dropdownWidth = dropdown.width();
                    var quicksearchWidth = jQuery(".navbar-main .quicksearch-form").width();
                    currentWidth += quicksearchWidth;
                    var menuEntries = navbar.find("li:not(.dropdown)");
                    menuEntries.each(function (i) {
                        navbar.append(this);
                    });
                    navbar.append(dropdown);
                    dropdown.addClass("hide").removeClass("active");

                    var maxWidth = container.width();
                    menuEntries.each(function (i) {
                        currentWidth += jQuery(this).width();

                        var next = false;
                        if (typeof menuEntries[i+1] !== "undefined") {
                            next = menuEntries[i+1];
                        }
                        var currentIsAboveMaxWidth = (currentWidth > maxWidth);
                        var currentIsNotLastAndPlusDropdownIsAboveMaxWidth = ((currentWidth + dropdownWidth > maxWidth) && i != menuEntries.length-1);
                        var currentPlusNextIsAboveMaxWidth = (next && currentWidth + jQuery(next).width() > maxWidth);
                        //console.log("%s: width: %s, is above: %s, notlast: %s, plusnext: %s", jQuery(this).text(), currentWidth, currentIsAboveMaxWidth, currentIsNotLastAndPlusDropdownIsAboveMaxWidth, currentPlusNextIsAboveMaxWidth)
                        if(currentIsAboveMaxWidth || currentIsNotLastAndPlusDropdownIsAboveMaxWidth || currentPlusNextIsAboveMaxWidth) {
                            jQuery(this).find("a").popover("destroy");
                            dropdown.find("ul").append(this);
                            dropdown.removeClass("hide");
                            if (jQuery(this).hasClass("active")) {
                                dropdown.addClass("active");
                            }
                        }
                    });

                };
                jQuery(document).on("ready", menuResizeHandler);
                var lastWidth = 0;
                jQuery(window).on("resize", function () {
                    lastWidth = window.innerWidth;
                    setTimeout(function () {
                        if (lastWidth == window.innerWidth) {
                            menuResizeHandler();
                        }
                    }, 100);
                });
            </script>
         <li class="active nav-pid-start"><a href="/2022/?lang=EN_CAP&amp;pid=start&amp;pidp=start"><span>Results</span></a></li><li class="nav-pid-leaderboard"><a href="/2022/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=leaderboard"><span>Leaderboard</span></a></li><li class="dropdown hide">
                <a href="javascript:void(0);" class="dropdown-toggle" id="navbar-main-dropdown" data-toggle="dropdown" aria-haspopup="true" aria-expanded="true">
                    More
                    <span class="caret"></span>
                </a>
                <ul class="dropdown-menu" aria-labelledby="navbar-main-dropdown"></ul></li></ul>
</div>
</nav><!-- menu end -->
</section>
<section class="section-main">
<div class="container" id="main-content">
<div class="row">
<div class="cbox-main pid-search col-xs-12" id="cbox-main">
<!-- cbox include start -->


<div class="row">
<div class="col-xs-10">
<h2> Results: 2014 / Marathon</h2>
</div>
</div>

<ul class="row-xs list-group list-info">
<li class="list-group-item">
40605 Results | Official Results
</li>
</ul>
<div class="col-sm-12 row-xs">
<ul class="list-group list-group-multicolumn">
<li class="  list-group row list-group-item  list-group-header ">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs" style="width: 40px">Place Overall</div>
  <div class=" list-field type-place place-primary" style="width: 40px">Place Gender</div>
  <div class=" list-field type-fullname">Name (CTZ)</div>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7  hidden-xs hidden-sm list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>BIB</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>Division</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>Finish</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">1</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">1</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA309000013ADEF&amp;lang=EN&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA3090000000065">Kipchoge, Eliud (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>2</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:04:11</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">2</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">2</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA309000013ADF0&amp;lang=EN&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA3090000000065">Kitwara, Sammy (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>6</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:04:28</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">3</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">3</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA309000013ADEA&amp;lang=EN&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA3090000000065">Chumba, Dickson (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>7</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:04:32</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">4</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">4</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA309000013ADE9&amp;lang=EN&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA3090000000065">Bekele, Kenenisa (ETH)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>1</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>30-34</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:05:51</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">5</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">5</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA309000013ADF1&amp;lang=EN&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA3090000000065">Koech, Bernard (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>5</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>25-29</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:08:30</div>
  </div>
</div>
</div>
</li>
<li class=" list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">6</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">6</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA309000013AE23&amp;lang=EN&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA3090000000065">Ghebreslassie, Ghirmay (ERI)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div>51</div>
  <div class=" list-field type-age_class" style="width: 90px"><div class="visible-xs-block visible-sm-block list-label">Division</div>19 and under</div>
  </div>
</div>
<div class="pull-right">
  <div class="row">
  <div class=" list-field type-time"><div class="visible-xs-block visible-sm-block list-label">Finish</div>02:09:08</div>
  </div>
</div>
</div>
</li>
<li class=" list-active list-group-item row">
<div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
  <div class="row">
  <div class=" list-field type-place place-secondary hidden-xs numeric" style="width: 40px">7</div>
  <div class=" list-field type-place place-primary numeric" style="width: 40px">7</div>
  <h4 class=" list-field type-fullname"><a href="?content=detail&amp;fpid=search&amp;pid=search&amp;idp=999999107FA309000013BDE4&amp;lang=EN&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex&amp;search_event=MAR_999999107FA3090000000065">Rutto, Lani (KEN)</a></h4>
  </div>
</div>
<div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
<div class="pull-left">
  <div class="row">
  <div class=" list-field type-field" style="width: 45px"><div class="visible-xs-block visible-sm-block list-label">BIB</div
amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">82</a></li><li class="pages-nav-button"><a href="?page=2&amp;event=MAR_999999107FA3090000000065&amp;lang=EN_CAP&amp;num_results=500&amp;pid=search&amp;pidp=start&amp;search%5Bage_class%5D=%25&amp;search%5Bsex%5D=%25&amp;search%5Bnation%5D=%25&amp;search_sort=place_nosex">&gt;</a></li></ul>
</div>
</div>
</div>
<!-- cbox include end -->
</div>


</div><!-- row -->
</div><!-- container main-content -->
</section><!-- section-main -->
<!-- main end -->

<!-- footer start -->
  <footer>  <div class="container"><div class="row"><div class="footer-box legal-footer" id="pid-search">

        <div class="col-xs-12">
        <a class="pull-right" href="https://www.mikatiming.com/">mika:timing GmbH © 2023</a> <a href="https://q.r.mikatiming.com/results-legal/en/">Legal Notice</a> | <a href="https://q.r.mikatiming.com/results-privacy-statement/en/">Privacy Policy</a>
        </div>

</div>

</div><!-- row end -->
          </div><!-- container end -->
    </footer><!-- footer section end --><div class="popup-info" style="display:none;" id="popup-info"></div>
<div class="popup" style="display:none;" id="popup"></div>
<div id="cconsent-overlay" style="display:none;"></div>




<input class="hidden" id="identified_1" autocomplete="off" name="ff54426a-f679-5fe7-c7ff-0f3e2b566063" data-last-search-value=""><ul class="dropdown-menu quicksearch-results" style="z-index: 2001;"></ul></body></html>"""

# %%
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
name_nodes = soup.select('.list-field.type-fullname')

# %%
name_nodes = name_nodes[1:]

# %%
name_nodes[0].get_text(strip=True)
# Out:
# 'Kipchoge, Eliud (KEN)'

# %%
def get_name(name_node):
  text = name_node.get_text()
  name = text[:text.find("(")].strip()
  return name

def get_country(name_node):
  country_text = name_node.get_text()
  country_item = country_text[country_text.find("(") + 1 : country_text.find(")")]
  return country_item

# %%
list_all_names = []
list_countries = []
for name_node in name_nodes:
  list_all_names.append(get_name(name_node))
  list_countries.append(get_country(name_node))

# %%
overall_nodes = soup.select('.list-field.type-place.place-secondary.hidden-xs.numeric')

# %%
def get_overall(overall_node):
  return overall_node.get_text()

# %%
bib_nodes = soup.select('.list-field.type-field')

# %%
bib_nodes = bib_nodes[1:]

# %%
def get_bib(bib_node):
  return bib_node.get_text()

# %%
time_nodes = soup.select('.list-field.type-time:contains("Finish")')
# Out:
# /usr/local/lib/python3.10/dist-packages/soupsieve/css_parser.py:856: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028

# %%
time_nodes = time_nodes[1:]

# %%
time_node = time_nodes[0].get_text()

# %%
time_node.split('Finish')[-1].strip()
# Out:
# '02:04:11'

# %%
def get_time(time_node):
  return time_node.get_text().split('Finish')[-1].strip()

# %%
division_nodes = soup.select('.list-field.type-age_class')

# %%
def get_division(division_node):
  return division_node.get_text()

# %%
list_overall = []
for overall_node in overall_nodes:
  list_overall.append(get_overall(overall_node))

list_bib = []
for bib_node in bib_nodes:
  list_bib.append(get_bib(bib_node))

list_times = []
for time_node in time_nodes:
  list_times.append(get_time(time_node))

list_divisions = []
for division_node in division_nodes:
  list_divisions.append(get_division(division_node))

# %%
list_divisions = list_divisions[1:]

# %%
data = {
    'Name': list_all_names,
    'Division': list_divisions,
    'Country': list_countries,
    'BIB': list_bib,
    'Overall Place': list_overall,
    'Time': list_times
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                      Name       Division Country      BIB Overall Place  \
# 0         Kipchoge, Eliud  Division25-29     KEN     BIB2             1
# 1          Kitwara, Sammy  Division25-29     KEN     BIB6             2
# 2         Chumba, Dickson  Division25-29     KEN     BIB7             3
# 3        Bekele, Kenenisa  Division30-34     ETH     BIB1             4
# 4          Koech, Bernard  Division25-29     KEN     BIB5             5
# ..                    ...            ...     ...      ...           ...
# 495     De Simone, Flavio  Division40-44     ITA  BIB1346           496
# 496        Marshall, Andy  Division20-24     USA   BIB825           497
# 497         Harris, Ethan  Division20-24     USA  BIB3276           498
# 498          Smith, Scott  Division25-29     USA  BIB1910           499
# 499  Livensparger, Elliot  Division20-24     USA   BIB582           500
#
#          Time
# 0    02:04:11
# 1    02:04:28
# 2    02:04:32
# 3    02:05:51
# 4    02:08:30
# ...

# %%
# base_url = 'https://results.chicagomarathon.com/2022/'

# runner_links = [link['href'] for link in soup.select('.type-fullname a') if link.has_attr('href')]

# def get_runner_gender(detail_url):
#     full_url = base_url + detail_url
#     response = requests.get(full_url)
#     detail_soup = BeautifulSoup(response.content, 'html.parser')
#     gender_element = detail_soup.select_one('td.f-sex.last')
#     return gender_element.get_text().strip() if gender_element else None

# def scrape_runner_genders(runner_links):
#     genders = []
#     for link in runner_links:
#         gender = get_runner_gender(link)
#         genders.append(gender)
#     return genders

# genders_list = scrape_runner_genders(runner_links)
# print(genders_list)

# %%
# len(genders_list)

# %%
# df['Gender'] = genders_list

# %%
# df.to_csv('Chicago_Marathon2023.csv', index=False)

# %%
# chicago2023 = pd.read_csv('https://raw.githubusercontent.com/snwnkang/CS171_Final_vis_Marathon/main/data/chicago_data/Chicago_Marathon2023.csv')

# %%
df['Division'] = df['Division'].str.replace('Division', '')

# %%
df
# Out:
#                      Name Division Country      BIB Overall Place      Time
# 0         Kipchoge, Eliud    25-29     KEN     BIB2             1  02:04:11
# 1          Kitwara, Sammy    25-29     KEN     BIB6             2  02:04:28
# 2         Chumba, Dickson    25-29     KEN     BIB7             3  02:04:32
# 3        Bekele, Kenenisa    30-34     ETH     BIB1             4  02:05:51
# 4          Koech, Bernard    25-29     KEN     BIB5             5  02:08:30
# ..                    ...      ...     ...      ...           ...       ...
# 495     De Simone, Flavio    40-44     ITA  BIB1346           496  02:52:04
# 496        Marshall, Andy    20-24     USA   BIB825           497  02:52:10
# 497         Harris, Ethan    20-24     USA  BIB3276           498  02:52:10
# 498          Smith, Scott    25-29     USA  BIB1910           499  02:52:13
# 499  Livensparger, Elliot    20-24     USA   BIB582           500  02:52:15
#
# [500 rows x 6 columns]

# %%
# df['Gender'] = df['Gender'].str.replace('Male', 'M')
# df['Gender'] = df['Gender'].str.replace('Female', 'F')
# df['Gender'] = df['Gender'].str.replace('Non-binary', 'NB')

# %%
df['BIB'] = df['BIB'].str.replace('BIB', '')

# %%
df
# Out:
#                      Name Division Country   BIB Overall Place      Time
# 0         Kipchoge, Eliud    25-29     KEN     2             1  02:04:11
# 1          Kitwara, Sammy    25-29     KEN     6             2  02:04:28
# 2         Chumba, Dickson    25-29     KEN     7             3  02:04:32
# 3        Bekele, Kenenisa    30-34     ETH     1             4  02:05:51
# 4          Koech, Bernard    25-29     KEN     5             5  02:08:30
# ..                    ...      ...     ...   ...           ...       ...
# 495     De Simone, Flavio    40-44     ITA  1346           496  02:52:04
# 496        Marshall, Andy    20-24     USA   825           497  02:52:10
# 497         Harris, Ethan    20-24     USA  3276           498  02:52:10
# 498          Smith, Scott    25-29     USA  1910           499  02:52:13
# 499  Livensparger, Elliot    20-24     USA   582           500  02:52:15
#
# [500 rows x 6 columns]

# %%
df['Year'] = year

# %%
df
# Out:
#                      Name Division Country   BIB Overall Place      Time  Year
# 0         Kipchoge, Eliud    25-29     KEN     2             1  02:04:11  2014
# 1          Kitwara, Sammy    25-29     KEN     6             2  02:04:28  2014
# 2         Chumba, Dickson    25-29     KEN     7             3  02:04:32  2014
# 3        Bekele, Kenenisa    30-34     ETH     1             4  02:05:51  2014
# 4          Koech, Bernard    25-29     KEN     5             5  02:08:30  2014
# ..                    ...      ...     ...   ...           ...       ...   ...
# 495     De Simone, Flavio    40-44     ITA  1346           496  02:52:04  2014
# 496        Marshall, Andy    20-24     USA   825           497  02:52:10  2014
# 497         Harris, Ethan    20-24     USA  3276           498  02:52:10  2014
# 498          Smith, Scott    25-29     USA  1910           499  02:52:13  2014
# 499  Livensparger, Elliot    20-24     USA   582           500  02:52:15  2014
#
# [500 rows x 7 columns]

# %%
def time_to_seconds(time_str):
    try:
        return pd.to_timedelta(time_str).total_seconds()
    except ValueError:
        return time_str.hour * 3600 + time_str.minute * 60 + time_str.second

# %%
df['seconds'] = df['Time'].apply(time_to_seconds)
df
# Out:
#                      Name Division Country   BIB Overall Place      Time  \
# 0         Kipchoge, Eliud    25-29     KEN     2             1  02:04:11
# 1          Kitwara, Sammy    25-29     KEN     6             2  02:04:28
# 2         Chumba, Dickson    25-29     KEN     7             3  02:04:32
# 3        Bekele, Kenenisa    30-34     ETH     1             4  02:05:51
# 4          Koech, Bernard    25-29     KEN     5             5  02:08:30
# ..                    ...      ...     ...   ...           ...       ...
# 495     De Simone, Flavio    40-44     ITA  1346           496  02:52:04
# 496        Marshall, Andy    20-24     USA   825           497  02:52:10
# 497         Harris, Ethan    20-24     USA  3276           498  02:52:10
# 498          Smith, Scott    25-29     USA  1910           499  02:52:13
# 499  Livensparger, Elliot    20-24     USA   582           500  02:52:15
#
#      Year  seconds
# 0    2014   7451.0
# 1    2014   7468.0
# 2    2014   7472.0
# ...

# %%
df[['Last Name', 'First Name']] = df['Name'].str.split(', ', expand=True)
df.drop('Name', axis=1, inplace=True)
df
# Out:
#     Division Country   BIB Overall Place      Time  Year  seconds  \
# 0      25-29     KEN     2             1  02:04:11  2014   7451.0
# 1      25-29     KEN     6             2  02:04:28  2014   7468.0
# 2      25-29     KEN     7             3  02:04:32  2014   7472.0
# 3      30-34     ETH     1             4  02:05:51  2014   7551.0
# 4      25-29     KEN     5             5  02:08:30  2014   7710.0
# ..       ...     ...   ...           ...       ...   ...      ...
# 495    40-44     ITA  1346           496  02:52:04  2014  10324.0
# 496    20-24     USA   825           497  02:52:10  2014  10330.0
# 497    20-24     USA  3276           498  02:52:10  2014  10330.0
# 498    25-29     USA  1910           499  02:52:13  2014  10333.0
# 499    20-24     USA   582           500  02:52:15  2014  10335.0
#
#         Last Name First Name
# 0        Kipchoge      Eliud
# 1         Kitwara      Sammy
# 2          Chumba    Dickson
# 3          Bekele   Kenenisa
# ...

# %%
column_order = ['Last Name', 'First Name', 'Division', 'Country', 'BIB', 'Overall Place', 'Time', 'seconds', 'Year']
df = df[column_order]

df.head()
# Out:
#   Last Name First Name Division Country BIB Overall Place      Time  seconds  \
# 0  Kipchoge      Eliud    25-29     KEN   2             1  02:04:11   7451.0
# 1   Kitwara      Sammy    25-29     KEN   6             2  02:04:28   7468.0
# 2    Chumba    Dickson    25-29     KEN   7             3  02:04:32   7472.0
# 3    Bekele   Kenenisa    30-34     ETH   1             4  02:05:51   7551.0
# 4     Koech    Bernard    25-29     KEN   5             5  02:08:30   7710.0
#
#    Year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %%
df
# Out:
#         Last Name First Name Division Country   BIB Overall Place      Time  \
# 0        Kipchoge      Eliud    25-29     KEN     2             1  02:04:11
# 1         Kitwara      Sammy    25-29     KEN     6             2  02:04:28
# 2          Chumba    Dickson    25-29     KEN     7             3  02:04:32
# 3          Bekele   Kenenisa    30-34     ETH     1             4  02:05:51
# 4           Koech    Bernard    25-29     KEN     5             5  02:08:30
# ..            ...        ...      ...     ...   ...           ...       ...
# 495     De Simone     Flavio    40-44     ITA  1346           496  02:52:04
# 496      Marshall       Andy    20-24     USA   825           497  02:52:10
# 497        Harris      Ethan    20-24     USA  3276           498  02:52:10
# 498         Smith      Scott    25-29     USA  1910           499  02:52:13
# 499  Livensparger     Elliot    20-24     USA   582           500  02:52:15
#
#      seconds  Year
# 0     7451.0  2014
# ...

# %%
gender_csv = pd.read_csv(url, header=None)
gender_csv.columns = ['Division']
gender_csv
# Out:
#     Division
# 0     M25-29
# 1     M25-29
# 2     M25-29
# 3     M30-34
# 4     M25-29
# ..       ...
# 295   M25-29
# 296   M50-54
# 297   M16-19
# 298   M30-34
# 299   M45-49
#
# [300 rows x 1 columns]

# %%
gender_csv['Gender'] = gender_csv['Division'].str[0]
gender_csv
# Out:
#     Division Gender
# 0     M25-29      M
# 1     M25-29      M
# 2     M25-29      M
# 3     M30-34      M
# 4     M25-29      M
# ..       ...    ...
# 295   M25-29      M
# 296   M50-54      M
# 297   M16-19      M
# 298   M30-34      M
# 299   M45-49      M
#
# [300 rows x 2 columns]

# %%
df['Gender'] = gender_csv['Gender']
df = df[:300]
df
# Out:
# <ipython-input-47-a706b26d6f90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = gender_csv['Gender']
#        Last Name First Name Division Country   BIB Overall Place      Time  \
# 0       Kipchoge      Eliud    25-29     KEN     2             1  02:04:11
# 1        Kitwara      Sammy    25-29     KEN     6             2  02:04:28
# 2         Chumba    Dickson    25-29     KEN     7             3  02:04:32
# 3         Bekele   Kenenisa    30-34     ETH     1             4  02:05:51
# 4          Koech    Bernard    25-29     KEN     5             5  02:08:30
# ..           ...        ...      ...     ...   ...           ...       ...
# 295      Nielsen    Kenneth    30-34     DEN  1229           296  02:45:10
# ...

# %%
df.to_csv('Chicago_Marathon2014.csv', index=False)
